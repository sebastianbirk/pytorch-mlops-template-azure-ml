# %%
import azureml.core
import matplotlib.pyplot as plt
import numpy as np
import os
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

from azureml.core import Dataset, Environment, Experiment, Model, ScriptRunConfig, Workspace
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException
from azureml.core.model import InferenceConfig 
from azureml.widgets import RunDetails

# %%
print(azureml.core.VERSION)
# Out:
# 1.19.0

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root="./data", train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root="./data", train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)

classes = ("plane", "car", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck")
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(HTML(value=''), FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0…
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# ## Take a look at the data
# In the following cell, you have some python code that displays the first batch of 4 CIFAR10 images:

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
#  ship  bird truck  deer

# %%
ws = Workspace.from_config() # this automatically looks for a directory .azureml
# ws.get_details()

datastore = ws.get_default_datastore()
datastore.upload(src_dir="./data", target_path="data/cifar10", overwrite=True)
# Out:
# Uploading an estimated of 9 files
# Uploading ./data/cifar-10-batches-py/batches.meta
# Uploaded ./data/cifar-10-batches-py/batches.meta, 1 files out of an estimated total of 9
# Uploading ./data/cifar-10-batches-py/readme.html
# Uploaded ./data/cifar-10-batches-py/readme.html, 2 files out of an estimated total of 9
# Uploading ./data/cifar-10-batches-py/test_batch
# Uploaded ./data/cifar-10-batches-py/test_batch, 3 files out of an estimated total of 9
# Uploading ./data/cifar-10-batches-py/data_batch_4
# Uploaded ./data/cifar-10-batches-py/data_batch_4, 4 files out of an estimated total of 9
# Uploading ./data/cifar-10-batches-py/data_batch_3
# Uploaded ./data/cifar-10-batches-py/data_batch_3, 5 files out of an estimated total of 9
# Uploading ./data/cifar-10-batches-py/data_batch_1
# Uploaded ./data/cifar-10-batches-py/data_batch_1, 6 files out of an estimated total of 9
# Uploading ./data/cifar-10-batches-py/data_batch_5
# Uploaded ./data/cifar-10-batches-py/data_batch_5, 7 files out of an estimated total of 9
# Uploading ./data/cifar-10-batches-py/data_batch_2
# Uploaded ./data/cifar-10-batches-py/data_batch_2, 8 files out of an estimated total of 9
# Uploading ./data/cifar-10-python.tar.gz
# Uploaded ./data/cifar-10-python.tar.gz, 9 files out of an estimated total of 9
# Uploaded 9 files
# $AZUREML_DATAREFERENCE_da34348af6a349e1a303beddd127c72f

# %%
# Choose a name for your CPU cluster
cpu_cluster_name = "msai-ds3v2-04"

# Verify that cluster does not exist already
try:
    cpu_cluster = ComputeTarget(workspace=ws, name=cpu_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',
                                                            max_nodes=4, 
                                                            idle_seconds_before_scaledown=2400)
    cpu_cluster = ComputeTarget.create(ws, cpu_cluster_name, compute_config)

cpu_cluster.wait_for_completion(show_output=True)
# Out:
# Creating
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# # Set up Training Scripts

# %%
training_folder = os.path.join(os.getcwd(), "training")
os.makedirs(training_folder, exist_ok=True)

# %%
# %%writefile $training_folder/train.py
import os
import argparse
import torch
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

from model import Net
from azureml.core import Run

run = Run.get_context()

if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument(
        '--data_path',
        type=str,
        help='Path to the training data'
    )
    parser.add_argument(
        '--learning_rate',
        type=float,
        default=0.001,
        help='Learning rate for SGD'
    )
    parser.add_argument(
        '--momentum',
        type=float,
        default=0.9,
        help='Momentum for SGD'
    )

    args = parser.parse_args()

    print("===== DATA =====")
    print("DATA PATH: " + args.data_path)
    print("LIST FILES IN DATA PATH...")
    print(os.listdir(args.data_path))
    print("================")

    # prepare DataLoader for CIFAR10 data
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
    trainset = torchvision.datasets.CIFAR10(
        root=args.data_path,
        train=True,
        download=False,
        transform=transform,
    )
    trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=4,
        shuffle=True,
        num_workers=2
    )

    # define convolutional network
    net = Net()

    # set up pytorch loss /  optimizer
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = optim.SGD(
        net.parameters(),
        lr=args.learning_rate,
        momentum=args.momentum,
    )

    # train the network
    for epoch in range(2):

        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # unpack the data
            inputs, labels = data

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            if i % 2000 == 1999:
                loss = running_loss / 2000
                run.log('loss', loss)  # log loss metric to AML
                print(f'epoch={epoch + 1}, batch={i + 1:5}: loss {loss:.2f}')
                running_loss = 0.0

    print("Finished Training")

    PATH = "cifar_net.pt"
    torch.save(net.state_dict(), PATH)
    run.upload_file(name=PATH, path_or_stream=PATH)
# Out:
# Overwriting /mnt/batch/tasks/shared/LS_root/mounts/clusters/sbirk-ci/code/Users/s.birk/pytorch-use-cases-azure-ml/stanford_dogs_image_classification/training/train.py

# %% [markdown]
# # Set up Pytorch Environment

# %%
# Display AML Curated Environments
# Curated environments are backed by cached Docker images, reducing the run preparation cost.
envs = Environment.list(workspace=ws)

for env in envs:
    if env.startswith("AzureML"):
        print("Name", env)
        print("packages", envs[env].python.conda_dependencies.serialize_to_string())
# Out:
# Name AzureML-AutoML
# packages channels:
# - anaconda
# - conda-forge
# - pytorch
# dependencies:
# - python=3.6.2
# - pip=20.2.4
# - pip:
#   - azureml-core==1.19.0
#   - azureml-pipeline-core==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-interpret==1.19.0
#   - azureml-automl-core==1.19.0
#   - azureml-automl-runtime==1.19.0
#   - azureml-train-automl-client==1.19.0
#   - azureml-train-automl-runtime==1.19.0
#   - azureml-dataset-runtime==1.19.0
#   - inference-schema
#   - py-cpuinfo==5.0.0
#   - boto3==1.15.18
#   - botocore==1.18.18
# - numpy~=1.18.0
# - scikit-learn==0.22.1
# - pandas~=0.25.0
# - py-xgboost<=0.90
# - fbprophet==0.5
# - holidays==0.9.11
# - setuptools-git
# - psutil>5.0.0,<6.0.0
# name: azureml_8eff28b157f42edcd2424a5aae6c8074
#
# Name AzureML-PyTorch-1.0-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - torch==1.0
#   - torchvision==0.2.1
#   - mkl==2018.0.3
#   - horovod==0.16.1
# name: azureml_05cdd7fc9b238a159a456dc22c87f026
#
# Name AzureML-Scikit-learn-0.20.3
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - scikit-learn==0.20.3
#   - scipy==1.2.1
#   - joblib==0.13.2
# name: azureml_bcd70ff6547af73d6de4e3c50f2235b8
#
# Name AzureML-TensorFlow-1.12-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - tensorflow==1.12
#   - horovod==0.15.2
# name: azureml_1cb37132b1778aa3c467af6d823e49bd
#
# Name AzureML-PyTorch-1.2-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - torch==1.2
#   - torchvision==0.4.0
#   - mkl==2018.0.3
#   - horovod==0.16.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_7e3429bb2b1ede094ce1947f29ee322f
#
# Name AzureML-TensorFlow-2.0-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - tensorflow-gpu==2.0.0
#   - horovod==0.18.1
# name: azureml_76e7f3cfc18c2e3053179283c174e74f
#
# Name AzureML-TensorFlow-2.0-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - tensorflow==2.0
#   - horovod==0.18.1
# name: azureml_21c7d56e994a09539dd5cc776f81ce65
#
# Name AzureML-Chainer-5.1.0-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - chainer==5.1.0
#   - cupy-cuda90==5.1.0
#   - mpi4py==3.0.0
# name: azureml_572c1da11f9a94e3b7a6e6e6a2e63943
#
# Name AzureML-TensorFlow-1.13-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - tensorflow==1.13.1
#   - horovod==0.16.1
# name: azureml_cf77ce9add884431274e1212cfdc4800
#
# Name AzureML-Minimal
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
# name: azureml_f7834da2edca74e44d923018c85f9f6f
#
# Name AzureML-Chainer-5.1.0-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - chainer==5.1.0
#   - mpi4py==3.0.0
# name: azureml_9203abdb18d345501e3959f945e1eb62
#
# Name AzureML-PyTorch-1.4-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - torch==1.4.0
#   - torchvision==0.5.0
#   - mkl==2018.0.3
#   - horovod==0.18.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_157aba5c5ab50a033db2e6186e5aa485
#
# Name AzureML-PySpark-MmlSpark-0.15
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
# name: azureml_134c9cb62f6e12ef481666393ce929de
#
# Name AzureML-PyTorch-1.3-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - torch==1.3
#   - torchvision==0.4.1
#   - mkl==2018.0.3
#   - horovod==0.18.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_2cf46d0a4f94e54fc2a2377c20b861fa
#
# Name AzureML-PyTorch-1.1-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - torch==1.1
#   - torchvision==0.2.1
#   - mkl==2018.0.3
#   - horovod==0.16.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_6e145d82f92c27509a9b9e457edff086
#
# Name AzureML-TensorFlow-1.10-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - tensorflow-gpu==1.10.0
#   - horovod==0.15.2
# name: azureml_dc023e98f7e8ec44741010682e15ee4f
#
# Name AzureML-PyTorch-1.2-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - torch==1.2
#   - torchvision==0.4.0
#   - mkl==2018.0.3
#   - horovod==0.16.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_7e3429bb2b1ede094ce1947f29ee322f
#
# Name AzureML-TensorFlow-1.13-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - tensorflow-gpu==1.13.1
#   - horovod==0.16.1
# name: azureml_2e953a155ad9bb4934a5c5fc29c94461
#
# Name AzureML-TensorFlow-1.10-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - tensorflow==1.10
#   - horovod==0.15.2
# name: azureml_933357b2310f331c5e879b79bc6da6e5
#
# Name AzureML-PyTorch-1.3-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - torch==1.3
#   - torchvision==0.4.1
#   - mkl==2018.0.3
#   - horovod==0.18.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_2cf46d0a4f94e54fc2a2377c20b861fa
#
# Name AzureML-Tutorial
# packages channels:
# - anaconda
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - azureml-widgets==1.19.0
#   - azureml-pipeline-core==1.19.0
#   - azureml-pipeline-steps==1.19.0
#   - azureml-opendatasets==1.19.0
#   - azureml-automl-core==1.19.0
#   - azureml-automl-runtime==1.19.0
#   - azureml-train-automl-client==1.19.0
#   - azureml-train-automl-runtime==1.19.0
#   - azureml-train-automl==1.19.0
#   - azureml-train==1.19.0
#   - azureml-sdk==1.19.0
#   - azureml-interpret==1.19.0
#   - azureml-tensorboard==1.19.0
#   - azureml-mlflow==1.19.0
#   - mlflow
#   - sklearn-pandas
# - pandas
# - numpy
# - tqdm
# - scikit-learn
# - matplotlib
# name: azureml_a1736710baabf05d37337a101fa8d6d1
#
# Name AzureML-PyTorch-1.0-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - torch==1.0
#   - torchvision==0.2.1
#   - mkl==2018.0.3
#   - horovod==0.16.1
# name: azureml_05cdd7fc9b238a159a456dc22c87f026
#
# Name AzureML-PyTorch-1.1-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - torch==1.1
#   - torchvision==0.2.1
#   - mkl==2018.0.3
#   - horovod==0.16.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_6e145d82f92c27509a9b9e457edff086
#
# Name AzureML-TensorFlow-1.12-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - tensorflow-gpu==1.12.0
#   - horovod==0.15.2
# name: azureml_f6e3ae7a94102e911365066d2221cd25
#
# Name AzureML-Designer-VowpalWabbit
# packages channels:
# - conda-forge
# - defaults
# dependencies:
# - pip=20.2
# - python=3.6.8
# - vowpalwabbit=8.8.1
# - pip:
#   - azureml-designer-vowpal-wabbit-modules==0.0.18
# name: azureml_b94d57a2018dc96b58b983cbbca08ead
#
# Name AzureML-TensorFlow-2.2-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - tensorflow-gpu==2.2.0
#   - horovod==0.19.5
# name: azureml_435a769981e94c0a7763212da4ffcfb3
#
# Name AzureML-TensorFlow-2.2-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - tensorflow==2.2.0
#   - horovod==0.19.5
# name: azureml_2ad4dcadddaf31412493a1dbb6c58d1a
#
# Name AzureML-PyTorch-1.6-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.18.0.post1
#   - azureml-defaults==1.18.0
#   - azureml-telemetry==1.18.0
#   - azureml-train-restclients-hyperdrive==1.18.0
#   - azureml-train-core==1.18.0
#   - cmake==3.18.2
#   - torch==1.6.0
#   - torchvision==0.5.0
#   - mkl==2018.0.3
#   - horovod==0.20.0
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_9d2a515d5c77954f2d0562cc5eb8a1fc
#
# Name AzureML-PyTorch-1.6-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.18.0.post1
#   - azureml-defaults==1.18.0
#   - azureml-telemetry==1.18.0
#   - azureml-train-restclients-hyperdrive==1.18.0
#   - azureml-train-core==1.18.0
#   - cmake==3.18.2
#   - torch==1.6.0
#   - torchvision==0.5.0
#   - mkl==2018.0.3
#   - horovod==0.20.0
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_9d2a515d5c77954f2d0562cc5eb8a1fc
#
# Name AzureML-Triton
# packages channels:
# - conda-forge
# dependencies:
# - python=3.7.9
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults[async]
#   - azureml-contrib-services==1.19.0
#   - numpy
#   - inference-schema[numpy-support]
#   - grpcio-tools
#   - geventhttpclient
#   - https://developer.download.nvidia.com/compute/redist/tritonclient/tritonclient-2.4.0-py3-none-manylinux1_x86_64.whl
# name: azureml_b92a7b47de175f9e362d86b49657a9f1
#
# Name AzureML-TensorFlow-2.3-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.18.0.post1
#   - azureml-defaults==1.18.0
#   - azureml-telemetry==1.18.0
#   - azureml-train-restclients-hyperdrive==1.18.0
#   - azureml-train-core==1.18.0
#   - tensorflow==2.3.0
#   - cmake==3.18.2
#   - horovod==0.20.0
# name: azureml_8e3321c66ae65459b91538aff75fe159
#
# Name AzureML-TensorFlow-2.3-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.18.0.post1
#   - azureml-defaults==1.18.0
#   - azureml-telemetry==1.18.0
#   - azureml-train-restclients-hyperdrive==1.18.0
#   - azureml-train-core==1.18.0
#   - tensorflow-gpu==2.3.0
#   - cmake==3.18.2
#   - horovod==0.20.0
# name: azureml_60ad88840fdbe40e31e03ddbbc134dec
#
# Name AzureML-DeepSpeed-0.3-GPU
# packages channels:
# - pytorch
# - conda-forge
# dependencies:
# - python=3.6.2
# - cudatoolkit-dev=10.1.243
# - cudatoolkit=10.1
# - pytorch==1.6.0
# - torchvision==0.7.0
# - gxx_linux-64
# - pip<=20.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - azureml-mlflow==1.19.0
#   - azureml-dataprep
#   - cmake==3.18.2
#   - mkl==2018.0.3
#   - tensorboard==1.14.0
#   - future==0.17.1
#   - matplotlib
#   - boto3
#   - h5py
#   - sklearn
#   - scipy
#   - pillow
#   - tqdm
#   - cupy-cuda101
#   - mpi4py
#   - deepspeed==0.3.*
# name: azureml_cbae9014d00ec9d2c3e9c1f2c3c53f67
#
# Name AzureML-Sidecar
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# name: base
#
# Name AzureML-Dask-CPU
# packages channels:
# - conda-forge
# - pytorch
# - defaults
# dependencies:
# - python=3.6.9
# - pip:
#   - adlfs
#   - azureml-core==1.18.0.post1
#   - azureml-dataset-runtime==1.18.0
#   - dask[complete]
#   - dask-ml[complete]
#   - distributed
#   - fastparquet
#   - fsspec
#   - joblib
#   - jupyterlab
#   - lz4
#   - mpi4py
#   - notebook
#   - pyarrow
# name: azureml_d407e2694bdeecd1113b9f2a6efdddf7
#
# Name AzureML-Dask-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.9
# - pip:
#   - azureml-defaults==1.18.0
#   - adlfs
#   - azureml-core==1.18.0.post1
#   - dask[complete]
#   - dask-ml[complete]
#   - distributed
#   - fastparquet
#   - fsspec
#   - joblib
#   - jupyterlab
#   - lz4
#   - mpi4py
#   - notebook
#   - pyarrow
# - matplotlib
# name: azureml_d093a03b8baffa8a67905fca27c6dbe0
#
# Name AzureML-TensorFlow-2.1-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - tensorflow-gpu==2.1.0
#   - horovod==0.19.1
# name: azureml_8a1e16fe295cbc2ac768249b6490e4e6
#
# Name AzureML-PyTorch-1.5-GPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.18.0.post1
#   - azureml-defaults==1.18.0
#   - azureml-telemetry==1.18.0
#   - azureml-train-restclients-hyperdrive==1.18.0
#   - azureml-train-core==1.18.0
#   - torch==1.5.0
#   - torchvision==0.5.0
#   - mkl==2018.0.3
#   - horovod==0.19.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_ab9d7b443a26cb52530f191d3e282ee6
#
# Name AzureML-PyTorch-1.5-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.18.0.post1
#   - azureml-defaults==1.18.0
#   - azureml-telemetry==1.18.0
#   - azureml-train-restclients-hyperdrive==1.18.0
#   - azureml-train-core==1.18.0
#   - torch==1.5.0
#   - torchvision==0.5.0
#   - mkl==2018.0.3
#   - horovod==0.19.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_ab9d7b443a26cb52530f191d3e282ee6
#
# Name AzureML-TensorFlow-2.1-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - tensorflow==2.1.0
#   - horovod==0.19.1
# name: azureml_5ef513fc702e73dace673d5a3635b4d2
#
# Name AzureML-AutoML-DNN-Vision-GPU
# packages dependencies:
# - python=3.7
# - pip=20.2.4
# - pip:
#   - azureml-core==1.19.0
#   - azureml-dataset-runtime==1.19.0
#   - azureml-contrib-dataset==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-automl-core==1.19.0
#   - azureml-automl-runtime==1.19.0
#   - azureml-train-automl-client==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-interpret==1.19.0
#   - azureml-train-automl-runtime==1.19.0
#   - azureml-train-automl==1.19.0
#   - azureml-contrib-automl-dnn-vision==1.19.0
# name: azureml_44c04382d9b6d84bc157b9fe5bf20160
#
# Name AzureML-Hyperdrive-ForecastDNN
# packages dependencies:
# - python=3.7
# - pip=20.2.4
# - pip:
#   - azureml-core==1.19.0
#   - azureml-pipeline-core==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-automl-core==1.19.0
#   - azureml-automl-runtime==1.19.0
#   - azureml-train-automl-client==1.19.0
#   - azureml-train-automl-runtime==1.19.0
#   - azureml-contrib-automl-dnn-forecasting==1.19.0
# name: azureml_3708e228a333d099fe40af587ee47743
#
# Name AzureML-PyTorch-1.4-CPU
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-train-restclients-hyperdrive==1.19.0
#   - azureml-train-core==1.19.0
#   - torch==1.4.0
#   - torchvision==0.5.0
#   - mkl==2018.0.3
#   - horovod==0.18.1
#   - tensorboard==1.14.0
#   - future==0.17.1
# name: azureml_157aba5c5ab50a033db2e6186e5aa485
#
# Name AzureML-AutoML-DNN
# packages channels:
# - anaconda
# - conda-forge
# - pytorch
# dependencies:
# - python=3.6.2
# - pip=20.2.4
# - pip:
#   - azureml-core==1.19.0
#   - azureml-pipeline-core==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-interpret==1.19.0
#   - azureml-automl-core==1.19.0
#   - azureml-automl-runtime==1.19.0
#   - azureml-train-automl-client==1.19.0
#   - azureml-train-automl-runtime==1.19.0
#   - azureml-dataset-runtime==1.19.0
#   - inference-schema
#   - pytorch-transformers==1.0.0
#   - spacy==2.1.8
#   - https://aka.ms/automl-resources/packages/en_core_web_sm-2.1.0.tar.gz
#   - py-cpuinfo==5.0.0
#   - boto3==1.15.18
#   - botocore==1.18.18
# - numpy~=1.18.0
# - scikit-learn==0.22.1
# - pandas~=0.25.0
# - py-xgboost<=0.90
# - fbprophet==0.5
# - holidays==0.9.11
# - setuptools-git
# - pytorch=1.4.0
# - cudatoolkit=10.0.130
# - psutil>5.0.0,<6.0.0
# name: azureml_107c229f03ae0129e9349394e50148a8
#
# Name AzureML-VowpalWabbit-8.8.0
# packages channels:
# - conda-forge
# dependencies:
# - python=3.6.2
# - pip:
#   - azureml-core==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-dataset-runtime[fuse,pandas]
# name: azureml_769be4b756b756954fa484d1287d5153
#
# Name AzureML-AutoML-DNN-GPU
# packages channels:
# - anaconda
# - conda-forge
# - pytorch
# dependencies:
# - python=3.6.2
# - pip=20.2.4
# - pip:
#   - werkzeug==0.16.1
#   - azureml-core==1.19.0
#   - azureml-pipeline-core==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-interpret==1.19.0
#   - azureml-automl-core==1.19.0
#   - azureml-automl-runtime==1.19.0
#   - azureml-train-automl-client==1.19.0
#   - azureml-train-automl-runtime==1.19.0
#   - azureml-dataset-runtime==1.19.0
#   - inference-schema
#   - horovod==0.19.4
#   - pytorch-transformers==1.0.0
#   - spacy==2.1.8
#   - https://aka.ms/automl-resources/packages/en_core_web_sm-2.1.0.tar.gz
#   - py-cpuinfo==5.0.0
#   - boto3==1.15.18
#   - botocore==1.18.18
# - numpy~=1.18.0
# - scikit-learn==0.22.1
# - pandas~=0.25.0
# - fbprophet==0.5
# - holidays==0.9.11
# - setuptools-git
# - pytorch=1.4.0
# - cudatoolkit=10.0.130
# - psutil>5.0.0,<6.0.0
# name: azureml_7bdc8a0b50c6fea1890b99b2c3692a13
#
# Name AzureML-AutoML-GPU
# packages channels:
# - anaconda
# - conda-forge
# - pytorch
# dependencies:
# - python=3.6.2
# - pip=20.2.4
# - pip:
#   - azureml-core==1.19.0
#   - azureml-pipeline-core==1.19.0
#   - azureml-telemetry==1.19.0
#   - azureml-defaults==1.19.0
#   - azureml-interpret==1.19.0
#   - azureml-automl-core==1.19.0
#   - azureml-automl-runtime==1.19.0
#   - azureml-train-automl-client==1.19.0
#   - azureml-train-automl-runtime==1.19.0
#   - azureml-dataset-runtime==1.19.0
#   - inference-schema
#   - py-cpuinfo==5.0.0
#   - boto3==1.15.18
#   - botocore==1.18.18
# - numpy~=1.18.0
# - scikit-learn==0.22.1
# - pandas~=0.25.0
# - fbprophet==0.5
# - holidays==0.9.11
# - setuptools-git
# - psutil>5.0.0,<6.0.0
# name: azureml_21a55bb777255b4a59b1462d50a96839
#
# Name AzureML-Designer-Score
# packages channels:
# - defaults
# dependencies:
# - python=3.6.8
# - pip:
#   - azureml-designer-score-modules==0.0.16
# name: azureml_18573b1d77e5ef62bcbe8903c11ceafe
#
# Name AzureML-Designer-PyTorch-Train
# packages channels:
# - defaults
# dependencies:
# - pip=20.2
# - python=3.6.8
# - pip:
#   - azureml-designer-pytorch-modules==0.0.27
# name: azureml_574539f46b20d3e5109d6e2b5baaa373
#
# Name AzureML-Designer-IO
# packages channels:
# - defaults
# dependencies:
# - pip=20.2
# - python=3.6.8
# - pip:
#   - azureml-dataset-runtime>=1.6
#   - azureml-designer-dataio-modules==0.0.50
# name: azureml_c79560ec553067468b92913e2bdba11a
#
# Name AzureML-Designer-Transform
# packages channels:
# - defaults
# dependencies:
# - pip=20.2
# - python=3.6.8
# - pip:
#   - azureml-designer-datatransform-modules==0.0.67
# name: azureml_623c3e0e76142af63711f8a502fa9f43
#
# Name AzureML-Designer-Recommender
# packages channels:
# - defaults
# dependencies:
# - pip=20.2
# - python=3.6.8
# - pip:
#   - azureml-designer-recommender-modules==0.0.23
# name: azureml_7c1e6e633f5c5d74edb71620a25923e2
#
# Name AzureML-Designer-CV
# packages channels:
# - defaults
# dependencies:
# - pip=20.2
# - python=3.6.8
# - pip:
#   - azureml-designer-cv-modules==0.0.24
# name: azureml_a405cfb567cc72d7bfb5f5c308ee3fae
#
# Name AzureML-Designer-NLP
# packages channels:
# - defaults
# dependencies:
# - python=3.6.8
# - pip:
#   - azureml-designer-classic-modules==0.0.121
#   - https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm
#   - spacy==2.1.7
# name: azureml_3bf90115af8eef18f3792699faaed002
#
# Name AzureML-Designer-PyTorch
# packages channels:
# - defaults
# dependencies:
# - pip=20.2
# - python=3.6.8
# - pip:
#   - azureml-designer-pytorch-modules==0.0.27
# name: azureml_574539f46b20d3e5109d6e2b5baaa373
#
# Name AzureML-Designer-CV-Transform
# packages channels:
# - defaults
# dependencies:
# - pip=20.2
# - python=3.6.8
# - pip:
#   - azureml-designer-cv-modules[pytorch]==0.0.24
# name: azureml_c67aaae7e813cbf26f18175058ac4ccd
#
# Name AzureML-Designer
# packages channels:
# - conda-forge
# dependencies:
# - pip=20.2
# - python=3.6.8
# - scikit-surprise=1.0.6
# - pip:
#   - azureml-designer-classic-modules==0.0.144
#   - https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm
#   - spacy==2.1.7
# name: azureml_dd368fc869617e417e17e35f21e4f1d5
#
# Name AzureML-Designer-R
# packages channels:
# - conda-forge
# dependencies:
# - pip=20.2
# - python=3.6.8
# - r-caret=6.0
# - r-catools=1.17.1
# - r-cluster=2.1.0
# - r-dplyr=0.8.5
# - r-e1071=1.7
# - r-forcats=0.5.0
# - r-forecast=8.12
# - r-glmnet=2.0
# - r-igraph=1.2.4
# - r-matrix=1.2
# - r-mclust=5.4.6
# - r-mgcv=1.8
# - r-nlme=3.1
# - r-nnet=7.3
# - r-plyr=1.8.6
# - r-randomforest=4.6
# - r-reticulate=1.12
# - r-rocr=1.0
# - r-rodbc=1.3
# - r-rpart=4.1
# - r-stringr=1.4.0
# - r-tidyverse=1.2.1
# - r-timedate=3043.102
# - r-tseries=0.10
# - r=3.5.1
# - pip:
#   - azureml-designer-classic-modules==0.0.144
# name: azureml_2eca47bbf9bbba54fe7fe74b03624508

# %%
for name,env in ws.environments.items():
    print(f"Name {name} \t version {env.version}")

# restored_environment = Environment.get(workspace=ws,name="myenv",version="1")

print("Attributes of restored environment")
# restored_environment
# Out:
# Name tutorial-env 	 version 3
# Name pytorch-aml-env 	 version 1
# Name AzureML-AutoML 	 version 50
# Name AzureML-PyTorch-1.0-GPU 	 version 44
# Name AzureML-Scikit-learn-0.20.3 	 version 43
# Name AzureML-TensorFlow-1.12-CPU 	 version 42
# Name AzureML-PyTorch-1.2-GPU 	 version 44
# Name AzureML-TensorFlow-2.0-GPU 	 version 42
# Name AzureML-TensorFlow-2.0-CPU 	 version 41
# Name AzureML-Chainer-5.1.0-GPU 	 version 44
# Name AzureML-TensorFlow-1.13-CPU 	 version 43
# Name AzureML-Minimal 	 version 44
# Name AzureML-Chainer-5.1.0-CPU 	 version 43
# Name AzureML-PyTorch-1.4-GPU 	 version 34
# Name AzureML-PySpark-MmlSpark-0.15 	 version 39
# Name AzureML-PyTorch-1.3-CPU 	 version 39
# Name AzureML-PyTorch-1.1-GPU 	 version 44
# Name AzureML-TensorFlow-1.10-GPU 	 version 44
# Name AzureML-PyTorch-1.2-CPU 	 version 43
# Name AzureML-TensorFlow-1.13-GPU 	 version 44
# Name AzureML-TensorFlow-1.10-CPU 	 version 43
# Name AzureML-PyTorch-1.3-GPU 	 version 41
# Name AzureML-Tutorial 	 version 60
# Name AzureML-PyTorch-1.0-CPU 	 version 43
# Name AzureML-PyTorch-1.1-CPU 	 version 43
# Name AzureML-TensorFlow-1.12-GPU 	 version 44
# Name AzureML-Designer-VowpalWabbit 	 version 14
# Name AzureML-TensorFlow-2.2-GPU 	 version 11
# Name AzureML-TensorFlow-2.2-CPU 	 version 11
# Name AzureML-PyTorch-1.6-CPU 	 version 10
# Name AzureML-PyTorch-1.6-GPU 	 version 10
# Name AzureML-Triton 	 version 9
# Name AzureML-TensorFlow-2.3-CPU 	 version 5
# Name AzureML-TensorFlow-2.3-GPU 	 version 4
# Name AzureML-DeepSpeed-0.3-GPU 	 version 2
# Name AzureML-Sidecar 	 version 27
# Name AzureML-Dask-CPU 	 version 28
# Name AzureML-Dask-GPU 	 version 26
# Name AzureML-TensorFlow-2.1-GPU 	 version 19
# Name AzureML-PyTorch-1.5-GPU 	 version 24
# Name AzureML-PyTorch-1.5-CPU 	 version 23
# Name AzureML-TensorFlow-2.1-CPU 	 version 18
# Name AzureML-AutoML-DNN-Vision-GPU 	 version 29
# Name AzureML-Hyperdrive-ForecastDNN 	 version 45
# Name AzureML-PyTorch-1.4-CPU 	 version 34
# Name AzureML-AutoML-DNN 	 version 48
# Name AzureML-VowpalWabbit-8.8.0 	 version 32
# Name AzureML-AutoML-DNN-GPU 	 version 39
# Name AzureML-AutoML-GPU 	 version 38
# Name AzureML-Designer-Score 	 version 12
# Name AzureML-Designer-PyTorch-Train 	 version 15
# Name AzureML-Designer-IO 	 version 26
# Name AzureML-Designer-Transform 	 version 26
# Name AzureML-Designer-Recommender 	 version 28
# Name AzureML-Designer-CV 	 version 18
# Name AzureML-Designer-NLP 	 version 16
# Name AzureML-Designer-PyTorch 	 version 19
# Name AzureML-Designer-CV-Transform 	 version 18
# Name AzureML-Designer 	 version 27
# Name AzureML-Designer-R 	 version 27
# Attributes of restored environment

# %%
curated_env = Environment.get(workspace=ws, name="AzureML-PyTorch-1.3-CPU")
print(curated_env.docker.base_image)
# Out:
# mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1

# %%
# On the first run in given environment, Azure ML spends some time building the environment.
# On the subsequent runs, Azure ML keeps track of changes and uses the existing environment, 
# resulting in faster run completion.

env = Environment.from_conda_specification(name="pytorch-aml-env",
                                           file_path="environment.yml")

env.docker.enabled = True
# Attribute docker.enabled controls whether to use Docker container or host OS for execution.
# This is only relevant for local execution as execution on AML Compute Cluster will always use Docker container.

# Use Python dependencies from your Docker image (as opposed to from conda specification)
# env.python.user_managed_dependencies=True

# OPTION 1: Use mcr base image
env.docker.base_image = "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1"

# OPTION 2: Use custom base image
#env.docker.base_image = "myregistry.azurecr.io/mycustomimage:1.0"
#env.docker.base_image_registry.address = "myregistry.azurecr.io"
#env.docker.base_image_registry.username = "username"
#env.docker.base_image_registry.password = "password"

env.environment_variables = {"MESSAGE": "Hello from Azure Machine Learning"}
# This can be retrieved in training script with os.environ.get("MESSAGE")

env.register(workspace=ws)
# Out:
# {
#     "databricks": {
#         "eggLibraries": [],
#         "jarLibraries": [],
#         "mavenLibraries": [],
#         "pypiLibraries": [],
#         "rcranLibraries": []
#     },
#     "docker": {
#         "arguments": [],
#         "baseDockerfile": null,
#         "baseImage": "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1",
#         "baseImageRegistry": {
#             "address": null,
#             "password": null,
#             "registryIdentity": null,
#             "username": null
#         },
#         "enabled": true,
#         "platform": {
#             "architecture": "amd64",
#             "os": "Linux"
#         },
#         "sharedVolumes": true,
#         "shmSize": null
#     },
#     "environmentVariables": {
#         "MESSAGE": "Hello from Azure Machine Learning"
#     },
#     "inferencingStackVersion": null,
#     "name": "pytorch-aml-env",
#     "python": {
#         "baseCondaEnvironment": null,
#         "condaDependencies": {
#             "channels": [
#                 "pytorch"
#             ],
#             "dependencies": [
#                 "python=3.7.1",
#                 "pytorch::pytorch=1.7.0",
#                 "pytorch::torchvision=0.8.1",
#                 {
#                     "pip": [
#                         "azureml-defaults",
#                         "azureml-sdk",
#                         "azureml-widgets"
#                     ]
#                 }
#             ],
#             "name": "azureml_ee9b10de42be281b146461e2fba517f5"
#         },
#         "condaDependenciesFile": null,
#         "interpreterPath": "python",
#         "userManagedDependencies": false
#     },
#     "r": null,
#     "spark": {
#         "packages": [],
#         "precachePackages": true,
#         "repositories": []
#     },
#     "version": "1"
# }

# %%
dataset = Dataset.File.from_files(path=(datastore, "data/cifar10"))
dataset = dataset.register(workspace=ws,
                           name="cifar10-dataset",
                           description="cifar10 training dataset",
                           create_new_version=True)

experiment = Experiment(workspace=ws, 
                        name="cifar-image-classification-pytorch")

config = ScriptRunConfig(source_directory="training",
                         script="train.py",
                         compute_target=cpu_cluster_name,
                         arguments=[
                             "--data_path", dataset.as_named_input("input").as_mount(),
                             "--learning_rate", 0.003,
                             "--momentum", 0.92])

config.run_config.environment = env

run = experiment.submit(config)
RunDetails(run).show()
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %%
run.wait_for_completion(show_output=False)
# Out:
# {'runId': 'cifar-image-classification-pytorch_1610017830_827f96e5',
#  'target': 'msai-ds3v2-04',
#  'status': 'Completed',
#  'startTimeUtc': '2021-01-07T11:14:42.908047Z',
#  'endTimeUtc': '2021-01-07T11:22:47.090807Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'dfc5a6b2-13ea-412f-8e38-24bdc1fedddd',
#   'azureml.git.repository_uri': 'https://github.com/sebastianbirk/pytorch-use-cases-azure-ml.git',
#   'mlflow.source.git.repoURL': 'https://github.com/sebastianbirk/pytorch-use-cases-azure-ml.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': '64e144109297b506ee7093f724f0b6dfc75058ce',
#   'mlflow.source.git.commit': '64e144109297b506ee7093f724f0b6dfc75058ce',
#   'azureml.git.dirty': 'True',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': 'a4419805-67b6-443d-a2b5-38fc5ae1daaf'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input', 'mechanism': 'Mount'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'train.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--data_path',
#    'DatasetConsumptionConfig:input',
#    '--learning_rate',
#    '0.003',
#    '--momentum',
#    '0.92'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'msai-ds3v2-04',
#   'dataReferences': {},
#   'data': {'input': {'dataLocation': {'dataset': {'id': 'a4419805-67b6-443d-a2b5-38fc5ae1daaf',
#       'name': 'cifar10-dataset',
#       'version': '1'},
#      'dataPath': None},
#     'mechanism': 'Mount',
#     'environmentVariableName': 'input',
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'outputData': {},
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'credentialPassthrough': False,
#   'environment': {'name': 'pytorch-aml-env',
#    'version': '1',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['pytorch'],
#      'dependencies': ['python=3.7.1',
#       'pytorch::pytorch=1.7.0',
#       'pytorch::torchvision=0.8.1',
#       {'pip': ['azureml-defaults', 'azureml-sdk', 'azureml-widgets']}],
#      'name': 'azureml_ee9b10de42be281b146461e2fba517f5'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'MESSAGE': 'Hello from Azure Machine Learning'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': None,
#    'frameworkImage': None,
#    'imageVersion': None,
#    'location': None,
#    'aiSuperComputerStorageData': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []}},
#  'logFiles': {'azureml-logs/55_azureml-execution-tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d.txt': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/azureml-logs/55_azureml-execution-tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d.txt?sv=2019-02-02&sr=b&sig=rmA4vSGtQk3fOnVl6XkJZsI6pep%2F8JmLaWPR3IqgdAw%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d.txt': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/azureml-logs/65_job_prep-tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d.txt?sv=2019-02-02&sr=b&sig=STTtBSW%2FgNqFhnboUv16QL66g2C7yLDMWuDT%2BZmYW9g%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=OiyxmFtEW%2BuWVUE3%2Fg60TfHdPCjWgxLeUPOlJFEjG8c%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d.txt': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/azureml-logs/75_job_post-tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d.txt?sv=2019-02-02&sr=b&sig=Zi46u%2BoaW0AgPtK6NzIV%2FLvOdZFfU1RsfTGeOQHOkaM%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'azureml-logs/process_info.json': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=yzmR9Soyh6dfM%2FU5P3OlfDrNqPUnlyhKPbrAqXI8LNI%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'azureml-logs/process_status.json': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=BlERTQVA7a4BamtQGc0%2BldzaUlo8%2Frk0tGaOpCsSiGw%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'logs/azureml/78_azureml.log': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/logs/azureml/78_azureml.log?sv=2019-02-02&sr=b&sig=zF9IfOmA4LPFCja5xTScQ4tWfccJz4zCDEXq%2FyXeHow%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/logs/azureml/dataprep/backgroundProcess.log?sv=2019-02-02&sr=b&sig=q8wRu2KYDEw8rxPvmPs9idClxDQXsW7qgUR7GDAYv%2Fg%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-02-02&sr=b&sig=e0jyf5z6wN8JiTgxjeUg3BVO4ldqgA0AtkaVExawSAQ%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'logs/azureml/dataprep/engine_spans_c6b29a15-f595-457a-82fe-61549bb2f81b.jsonl': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/logs/azureml/dataprep/engine_spans_c6b29a15-f595-457a-82fe-61549bb2f81b.jsonl?sv=2019-02-02&sr=b&sig=E%2B4udQRZq7boqvZwlSzfjhLL1MbQAzk8vdUq%2Bj4jtQU%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'logs/azureml/dataprep/engine_spans_e99d9267-848d-4c3c-a6c9-ca86a7a75012.jsonl': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/logs/azureml/dataprep/engine_spans_e99d9267-848d-4c3c-a6c9-ca86a7a75012.jsonl?sv=2019-02-02&sr=b&sig=Cozuwz7RPlAEaTJhKsVaYLKEEyl3fUjAQce%2BHifEZAE%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'logs/azureml/dataprep/python_span_06bc02fb-78f0-4306-97c6-ea3534665620.jsonl': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/logs/azureml/dataprep/python_span_06bc02fb-78f0-4306-97c6-ea3534665620.jsonl?sv=2019-02-02&sr=b&sig=9acD1Gsgn1D2l6C6zajJx4ohBShjxKfRKhH9RlZLgP0%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'logs/azureml/dataprep/python_span_c6b29a15-f595-457a-82fe-61549bb2f81b.jsonl': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/logs/azureml/dataprep/python_span_c6b29a15-f595-457a-82fe-61549bb2f81b.jsonl?sv=2019-02-02&sr=b&sig=UCm2gKceIWC9eKxAF1YR7SqvnzkdgFHGr3FDeZ1v%2F5M%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'logs/azureml/dataprep/python_span_e99d9267-848d-4c3c-a6c9-ca86a7a75012.jsonl': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/logs/azureml/dataprep/python_span_e99d9267-848d-4c3c-a6c9-ca86a7a75012.jsonl?sv=2019-02-02&sr=b&sig=Umrnw7SOAvQNbLCWw6WIRj17SZyhJvPL3FJNBHob6Gk%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=up7AvKmPcAa8ozix54ZxPAuLzWkvN4hgX1QQGA1SJqI%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=Ch378bEjV31NopPSCxhzRrCGGc7brxFDXMoG7gGL1PM%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'logs/azureml/sidecar/tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d/all.log': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/logs/azureml/sidecar/tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d/all.log?sv=2019-02-02&sr=b&sig=nWOhbLnYDoObGJoI018DT7EHJk0Tf1AFAJiABJHnnAI%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'logs/azureml/sidecar/tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d/task.enter_contexts.log': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/logs/azureml/sidecar/tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d/task.enter_contexts.log?sv=2019-02-02&sr=b&sig=AY5uBTBQrigEg0vAu8qXvfMS0NvnvSl2Caw3HeUHlRM%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r',
#   'logs/azureml/sidecar/tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d/task.exit_contexts.log': 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/logs/azureml/sidecar/tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d/task.exit_contexts.log?sv=2019-02-02&sr=b&sig=BMfKVbSGJITLh%2FkpAOqheCXC2Z18r7urMvgU0tWDljU%3D&st=2021-01-07T11%3A12%3A55Z&se=2021-01-07T19%3A22%3A55Z&sp=r'}}

# %%
print(run.get_metrics())
print(run.get_file_names())
# Out:
# {'loss': [2.0343978877365587, 1.728910364329815, 1.6327583638578653, 1.5752813300900161, 1.5334343602061271, 1.5086002700924874, 1.4592548685595392, 1.4613496852368117, 1.4508758111223579, 1.4436908447742463, 1.4515875704437495, 1.4369140582941473]}
# ['azureml-logs/55_azureml-execution-tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d.txt', 'azureml-logs/65_job_prep-tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d.txt', 'azureml-logs/70_driver_log.txt', 'azureml-logs/75_job_post-tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d.txt', 'azureml-logs/process_info.json', 'azureml-logs/process_status.json', 'cifar_net.pt', 'logs/azureml/78_azureml.log', 'logs/azureml/dataprep/backgroundProcess.log', 'logs/azureml/dataprep/backgroundProcess_Telemetry.log', 'logs/azureml/dataprep/engine_spans_c6b29a15-f595-457a-82fe-61549bb2f81b.jsonl', 'logs/azureml/dataprep/engine_spans_e99d9267-848d-4c3c-a6c9-ca86a7a75012.jsonl', 'logs/azureml/dataprep/python_span_06bc02fb-78f0-4306-97c6-ea3534665620.jsonl', 'logs/azureml/dataprep/python_span_c6b29a15-f595-457a-82fe-61549bb2f81b.jsonl', 'logs/azureml/dataprep/python_span_e99d9267-848d-4c3c-a6c9-ca86a7a75012.jsonl', 'logs/azureml/job_prep_azureml.log', 'logs/azureml/job_release_azureml.log', 'logs/azureml/sidecar/tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d/all.log', 'logs/azureml/sidecar/tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d/task.enter_contexts.log', 'logs/azureml/sidecar/tvmps_ec309f5369480ae188dbe21dd1d08f102d0b585dcf63f5ccf7ccd9a7a981c9df_d/task.exit_contexts.log']

# %%
PATH = "cifar_net.pt"

model = run.register_model(model_name="cifar10-model",
                           model_path=PATH,
                           model_framework=Model.Framework.PYTORCH,
                           description="cifar10 model")

# %%
env.inferencing_stack_version = "latest"
# This will install the inference specific apt packages.

# %%
deployment_folder = os.path.join(os.getcwd(), "deployment")
os.makedirs(deployment_folder, exist_ok=True)

# %%
# %%writefile $deployment_folder/score.py
import os
import torch
import json
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


def init():
    global net
    global classes

    model_filename = "cifar_net.pt"
    model_path = os.path.join(os.environ['AZUREML_MODEL_DIR'], model_filename)
    net = Net()
    net.load_state_dict(torch.load(model_path))
    classes = ('plane', 'car', 'bird', 'cat',
               'deer', 'dog', 'frog', 'horse', 'ship', 'truck')


def run(data):
    data = json.loads(data)
    images = torch.FloatTensor(data['data'])
    outputs = net(images)

    _, predicted = torch.max(outputs, 1)

    result = [classes[predicted[j]] for j in range(4)]
    result_json = json.dumps({"predictions": result})

    # You can return any JSON-serializable object.
    return result_json
# Out:
# Overwriting /mnt/batch/tasks/shared/LS_root/mounts/clusters/sbirk-ci/code/Users/s.birk/pytorch-use-cases-azure-ml/stanford_dogs_image_classification/deployment/score.py

# %%
# Create Inference Config
inference_config = InferenceConfig(entry_script="deployment/score.py",
                                   environment=env)

# Creating package
package = Model.package(ws, 
                        [model], 
                        inference_config=inference_config, 
                        generate_dockerfile=False,
                        image_name="cifar10-pytorch",
                        image_label="1.0")

package.wait_for_creation(show_output=True)

# Download the image. This can only be used if generate_dockerfile is set to False
package.pull()

# Download the dockerfile. This can only be used if generate_dockerfile is set to True
package.save("./docker")
# Out:
# 2021/01/07 11:23:25 Downloading source code...
# 2021/01/07 11:23:26 Finished downloading source code
# 2021/01/07 11:23:27 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/01/07 11:23:27 Successfully set up Docker network: acb_default_network
# 2021/01/07 11:23:27 Setting up Docker configuration...
# 2021/01/07 11:23:28 Successfully set up Docker configuration
# 2021/01/07 11:23:28 Logging in to registry: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io
# 2021/01/07 11:23:29 Successfully logged into eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io
# 2021/01/07 11:23:29 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/07 11:23:29 Launching container with name: acb_step_0
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /acb/home/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# 2021/01/07 11:23:31 Successfully executed container: acb_step_0
# 2021/01/07 11:23:31 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/07 11:23:31 Scanning for dependencies...
# 2021/01/07 11:23:32 Successfully scanned dependencies
# 2021/01/07 11:23:32 Launching container with name: acb_step_1
# Sending build context to Docker daemon  65.54kB
# Step 1/7 : FROM eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# latest: Pulling from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 2c11b7cecaa5: Already exists
# 04637fa56252: Already exists
# d6e6af23a0f3: Already exists
# b4a424de92ad: Already exists
# 3e5d9ee64909: Pulling fs layer
# 3a846111ff22: Pulling fs layer
# 93a5020c6e19: Pulling fs layer
# 360b353e68fd: Pulling fs layer
# ea4e2e1810f8: Pulling fs layer
# def12cf7de15: Pulling fs layer
# 3ae6adfbdb11: Pulling fs layer
# 2a21fbf2232e: Pulling fs layer
# 072c7a864bda: Pulling fs layer
# 8f970caa7c1a: Pulling fs layer
# fcdd1849b49a: Pulling fs layer
# bd1c00c6e3a2: Pulling fs layer
# e933cf3d3c6e: Pulling fs layer
# d9bac286ee43: Pulling fs layer
# 1a8c9799c9cb: Pulling fs layer
# 71b40a2bfa13: Pulling fs layer
# ecbdedeb1747: Pulling fs layer
# def12cf7de15: Waiting
# 3ae6adfbdb11: Waiting
# 2a21fbf2232e: Waiting
# 072c7a864bda: Waiting
# 8f970caa7c1a: Waiting
# fcdd1849b49a: Waiting
# bd1c00c6e3a2: Waiting
# e933cf3d3c6e: Waiting
# d9bac286ee43: Waiting
# 1a8c9799c9cb: Waiting
# 71b40a2bfa13: Waiting
# ecbdedeb1747: Waiting
# 360b353e68fd: Waiting
# ea4e2e1810f8: Waiting
# 93a5020c6e19: Download complete
# 3a846111ff22: Verifying Checksum
# 3a846111ff22: Download complete
# 3e5d9ee64909: Verifying Checksum
# 3e5d9ee64909: Download complete
# 360b353e68fd: Verifying Checksum
# 360b353e68fd: Download complete
# ea4e2e1810f8: Verifying Checksum
# ea4e2e1810f8: Download complete
# def12cf7de15: Verifying Checksum
# def12cf7de15: Download complete
# 2a21fbf2232e: Verifying Checksum
# 2a21fbf2232e: Download complete
# 3ae6adfbdb11: Verifying Checksum
# 3ae6adfbdb11: Download complete
# 072c7a864bda: Download complete
# 8f970caa7c1a: Verifying Checksum
# 8f970caa7c1a: Download complete
# e933cf3d3c6e: Verifying Checksum
# e933cf3d3c6e: Download complete
# d9bac286ee43: Verifying Checksum
# d9bac286ee43: Download complete
# fcdd1849b49a: Verifying Checksum
# fcdd1849b49a: Download complete
# bd1c00c6e3a2: Verifying Checksum
# bd1c00c6e3a2: Download complete
# 1a8c9799c9cb: Verifying Checksum
# 1a8c9799c9cb: Download complete
# ecbdedeb1747: Verifying Checksum
# ecbdedeb1747: Download complete
# 3e5d9ee64909: Pull complete
# 3a846111ff22: Pull complete
# 93a5020c6e19: Pull complete
# 360b353e68fd: Pull complete
# ea4e2e1810f8: Pull complete
# def12cf7de15: Pull complete
# 3ae6adfbdb11: Pull complete
# 2a21fbf2232e: Pull complete
# 072c7a864bda: Pull complete
# 8f970caa7c1a: Pull complete
# fcdd1849b49a: Pull complete
# bd1c00c6e3a2: Pull complete
# e933cf3d3c6e: Pull complete
# d9bac286ee43: Pull complete
# 1a8c9799c9cb: Pull complete
# 71b40a2bfa13: Verifying Checksum
# 71b40a2bfa13: Download complete
# 71b40a2bfa13: Pull complete
# ecbdedeb1747: Pull complete
# Digest: sha256:f0065b3c7e1c18adf2acac332dd07da82f8a00773c0d500980f606d680c73339
# Status: Downloaded newer image for eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45:latest
#  ---> a50280c65cc3
# Step 2/7 : ENV AZUREML_MODEL_DIR=azureml-models/cifar10-model/6
#  ---> Running in f3ff25957c1b
# Removing intermediate container f3ff25957c1b
#  ---> aac52747871b
# Step 3/7 : RUN mkdir -p '/var/azureml-app' && /var/azureml-util/download_asset.sh 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/LocalUpload/71564660/tmpaz_ds0ju.py?sv=2019-02-02&sr=b&sig=s94SIz1udi%2FQp%2FbSJWa9DYNEh4pDp8x%2BNcF4I9Vl294%3D&st=2021-01-07T11%3A13%3A21Z&se=2021-01-07T19%3A23%3A21Z&sp=r' '/var/azureml-app/tmpaz_ds0ju.py' && /var/azureml-util/download_asset.sh 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/LocalUpload/790d1ab1/score.py?sv=2019-02-02&sr=b&sig=%2BXx%2F99nWsTwR7bMgtddVh3Q72D%2BLuuF2iRD6KOHN1MM%3D&st=2021-01-07T11%3A13%3A21Z&se=2021-01-07T19%3A23%3A21Z&sp=r' '/var/azureml-app/score.py'
#  ---> Running in 24e9f752b426
# Downloading https://sbirkamlws3782852688.blob.core.windows.net/azureml/LocalUpload/71564660/tmpaz_ds0ju.py?sv=2019-02-02&sr=b&sig=s94SIz1udi%2FQp%2FbSJWa9DYNEh4pDp8x%2BNcF4I9Vl294%3D&st=2021-01-07T11%3A13%3A21Z&se=2021-01-07T19%3A23%3A21Z&sp=r as /var/azureml-app/tmpaz_ds0ju.py
# --2021-01-07 11:25:58--  https://sbirkamlws3782852688.blob.core.windows.net/azureml/LocalUpload/71564660/tmpaz_ds0ju.py?sv=2019-02-02&sr=b&sig=s94SIz1udi%2FQp%2FbSJWa9DYNEh4pDp8x%2BNcF4I9Vl294%3D&st=2021-01-07T11%3A13%3A21Z&se=2021-01-07T19%3A23%3A21Z&sp=r
# Resolving sbirkamlws3782852688.blob.core.windows.net (sbirkamlws3782852688.blob.core.windows.net)... 52.166.80.100
# Connecting to sbirkamlws3782852688.blob.core.windows.net (sbirkamlws3782852688.blob.core.windows.net)|52.166.80.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1064 (1.0K) [application/octet-stream]
# Saving to: ‘/var/azureml-app/tmpaz_ds0ju.py’
#
#      0K                                    100%  132M=0s
#
# 2021-01-07 11:25:58 (132 MB/s) - ‘/var/azureml-app/tmpaz_ds0ju.py’ saved [1064/1064]
#
# Downloading https://sbirkamlws3782852688.blob.core.windows.net/azureml/LocalUpload/790d1ab1/score.py?sv=2019-02-02&sr=b&sig=%2BXx%2F99nWsTwR7bMgtddVh3Q72D%2BLuuF2iRD6KOHN1MM%3D&st=2021-01-07T11%3A13%3A21Z&se=2021-01-07T19%3A23%3A21Z&sp=r as /var/azureml-app/score.py
# --2021-01-07 11:25:58--  https://sbirkamlws3782852688.blob.core.windows.net/azureml/LocalUpload/790d1ab1/score.py?sv=2019-02-02&sr=b&sig=%2BXx%2F99nWsTwR7bMgtddVh3Q72D%2BLuuF2iRD6KOHN1MM%3D&st=2021-01-07T11%3A13%3A21Z&se=2021-01-07T19%3A23%3A21Z&sp=r
# Resolving sbirkamlws3782852688.blob.core.windows.net (sbirkamlws3782852688.blob.core.windows.net)... 52.166.80.100
# Connecting to sbirkamlws3782852688.blob.core.windows.net (sbirkamlws3782852688.blob.core.windows.net)|52.166.80.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1352 (1.3K) [application/octet-stream]
# Saving to: ‘/var/azureml-app/score.py’
#
#      0K                                    100%  177M=0s
#
# 2021-01-07 11:25:58 (177 MB/s) - ‘/var/azureml-app/score.py’ saved [1352/1352]
#
# Removing intermediate container 24e9f752b426
#  ---> 36ceb289d9df
# Step 4/7 : RUN mkdir -p '/var/azureml-app/azureml-models/cifar10-model/6' && /var/azureml-util/download_asset.sh 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/cifar_net.pt?sv=2019-02-02&sr=b&sig=I80gefNBcGy2oGMjpm9WBe6xGrRDAHUqwgWc8CZhQLE%3D&st=2021-01-07T11%3A13%3A21Z&se=2021-01-07T19%3A23%3A21Z&sp=r' '/var/azureml-app/azureml-models/cifar10-model/6/cifar_net.pt'
#  ---> Running in 976e2461c4b8
# Downloading https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/cifar_net.pt?sv=2019-02-02&sr=b&sig=I80gefNBcGy2oGMjpm9WBe6xGrRDAHUqwgWc8CZhQLE%3D&st=2021-01-07T11%3A13%3A21Z&se=2021-01-07T19%3A23%3A21Z&sp=r as /var/azureml-app/azureml-models/cifar10-model/6/cifar_net.pt
# --2021-01-07 11:26:01--  https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/cifar_net.pt?sv=2019-02-02&sr=b&sig=I80gefNBcGy2oGMjpm9WBe6xGrRDAHUqwgWc8CZhQLE%3D&st=2021-01-07T11%3A13%3A21Z&se=2021-01-07T19%3A23%3A21Z&sp=r
# Resolving sbirkamlws3782852688.blob.core.windows.net (sbirkamlws3782852688.blob.core.windows.net)... 52.166.80.100
# Connecting to sbirkamlws3782852688.blob.core.windows.net (sbirkamlws3782852688.blob.core.windows.net)|52.166.80.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 251401 (246K) [application/octet-stream]
# Saving to: ‘/var/azureml-app/azureml-models/cifar10-model/6/cifar_net.pt’
#
#      0K                                    100% 57.6M=0.004s
#
# 2021-01-07 11:26:01 (57.6 MB/s) - ‘/var/azureml-app/azureml-models/cifar10-model/6/cifar_net.pt’ saved [251401/251401]
#
# Removing intermediate container 976e2461c4b8
#  ---> 51168711fdbf
# Step 5/7 : RUN mkdir -p '/var/azureml-app' && echo ... | base64 --decode > /var/azureml-app/model_config_map.json
#  ---> Running in 3438baa6e6a9
# Removing intermediate container 3438baa6e6a9
#  ---> d8f33469c153
# Step 6/7 : RUN mv '/var/azureml-app/tmpaz_ds0ju.py' /var/azureml-app/main.py
#  ---> Running in 1551c73d0859
# Removing intermediate container 1551c73d0859
#  ---> 4328fc1f3d1e
# Step 7/7 : CMD ["runsvdir","/var/runit"]
#  ---> Running in 77e44877247c
# Removing intermediate container 77e44877247c
#  ---> 3f56df8306b5
# Successfully built 3f56df8306b5
# Successfully tagged eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_9145509ef6c9d87108dc30965282b3f1:latest
# 2021/01/07 11:26:15 Successfully executed container: acb_step_1
# 2021/01/07 11:26:15 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/07 11:26:15 Pushing image: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_9145509ef6c9d87108dc30965282b3f1:latest, attempt 1
# The push refers to repository [eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_9145509ef6c9d87108dc30965282b3f1]
# fc0fd290cdef: Preparing
# d93901d9e47c: Preparing
# 3278aa33db26: Preparing
# a0bee54a17e9: Preparing
# be0db5a7dfaa: Preparing
# 3929911ec7dc: Preparing
# 50eabbd7fd50: Preparing
# 8f3959e64535: Preparing
# 4fba244d355f: Preparing
# 63a9983f49c8: Preparing
# 7e23d0d88ed6: Preparing
# 33105dd0d176: Preparing
# 3d5382572410: Preparing
# 630330099f1e: Preparing
# 26346e33e93c: Preparing
# 65fd26c61dec: Preparing
# 8b72eff884fd: Preparing
# f06675a4a69e: Preparing
# 7117e7689e0f: Preparing
# d56ca49dab62: Preparing
# 09304b9c7c13: Preparing
# 9edaa71ce233: Preparing
# 62fdddf6a67c: Preparing
# eff16de3ff64: Preparing
# 61727f5e6796: Preparing
# 26346e33e93c: Waiting
# 65fd26c61dec: Waiting
# 3929911ec7dc: Waiting
# 8b72eff884fd: Waiting
# 50eabbd7fd50: Waiting
# f06675a4a69e: Waiting
# 8f3959e64535: Waiting
# 7117e7689e0f: Waiting
# 4fba244d355f: Waiting
# 63a9983f49c8: Waiting
# d56ca49dab62: Waiting
# 7e23d0d88ed6: Waiting
# 09304b9c7c13: Waiting
# 9edaa71ce233: Waiting
# 33105dd0d176: Waiting
# 62fdddf6a67c: Waiting
# 3d5382572410: Waiting
# 630330099f1e: Waiting
# 61727f5e6796: Waiting
# eff16de3ff64: Waiting
# be0db5a7dfaa: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# fc0fd290cdef: Pushed
# 3278aa33db26: Pushed
# a0bee54a17e9: Pushed
# d93901d9e47c: Pushed
# 8f3959e64535: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 3929911ec7dc: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 50eabbd7fd50: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 4fba244d355f: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 63a9983f49c8: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 7e23d0d88ed6: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 33105dd0d176: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 630330099f1e: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 3d5382572410: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 8b72eff884fd: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 26346e33e93c: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 65fd26c61dec: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# f06675a4a69e: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 09304b9c7c13: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 9edaa71ce233: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 7117e7689e0f: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# d56ca49dab62: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 62fdddf6a67c: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# eff16de3ff64: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# 61727f5e6796: Mounted from azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
# latest: digest: sha256:b8117c3b9015ae1a87b107a713b75d1afbe3d582fbffaafdf873e392e9deac2a size: 5559
# 2021/01/07 11:26:29 Successfully pushed image: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_9145509ef6c9d87108dc30965282b3f1:latest
# 2021/01/07 11:26:29 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 1.278039)
# 2021/01/07 11:26:29 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 163.794506)
# 2021/01/07 11:26:29 Populating digests for step ID: acb_step_1...
# 2021/01/07 11:26:32 Successfully populated digests for step ID: acb_step_1
# 2021/01/07 11:26:32 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 14.446370)
# 2021/01/07 11:26:32 The following dependencies were found:
# 2021/01/07 11:26:32
# - image:
#     registry: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io
#     repository: azureml/azureml_9145509ef6c9d87108dc30965282b3f1
#     tag: latest
#     digest: sha256:b8117c3b9015ae1a87b107a713b75d1afbe3d582fbffaafdf873e392e9deac2a
#   runtime-dependency:
#     registry: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io
#     repository: azureml/azureml_3b345ad9f8e61a70a9b66bd5c5550d45
#     tag: latest
#     digest: sha256:f0065b3c7e1c18adf2acac332dd07da82f8a00773c0d500980f606d680c73339
#   git: {}
#
# Run ID: cbh was successful after 3m9s
# Package creation Succeeded
# Pulling image from ACR (this may take a few minutes depending on image size)...
#
# sha256:b8117c3b9015ae1a87b107a713b75d1afbe3d582fbffaafdf873e392e9deac2a: Pulling from cifar10-pytorch
# 2c11b7cecaa5: Already exists
# 04637fa56252: Already exists
# d6e6af23a0f3: Already exists
# b4a424de92ad: Already exists
# 3e5d9ee64909: Already exists
# 3a846111ff22: Already exists
# 93a5020c6e19: Already exists
# 360b353e68fd: Already exists
# ea4e2e1810f8: Already exists
# def12cf7de15: Already exists
# 3ae6adfbdb11: Already exists
# 2a21fbf2232e: Already exists
# 072c7a864bda: Already exists
# 8f970caa7c1a: Already exists
# fcdd1849b49a: Already exists
# bd1c00c6e3a2: Already exists
# e933cf3d3c6e: Already exists
# d9bac286ee43: Already exists
# 1a8c9799c9cb: Already exists
# 71b40a2bfa13: Already exists
# ecbdedeb1747: Already exists
# 5f82e14ade4e: Pulling fs layer
# 9ab73276ab4f: Pulling fs layer
# d794c913dba9: Pulling fs layer
# 763d244b9419: Pulling fs layer
# 763d244b9419: Waiting
# 5f82e14ade4e: Downloading
# 5f82e14ade4e: Verifying Checksum
# 5f82e14ade4e: Download complete
# 5f82e14ade4e: Extracting
# 5f82e14ade4e: Extracting
# 5f82e14ade4e: Pull complete
# 763d244b9419: Download complete
# 9ab73276ab4f: Downloading
# 9ab73276ab4f: Download complete
# 9ab73276ab4f: Extracting
# 9ab73276ab4f: Extracting
# 9ab73276ab4f: Extracting
# d794c913dba9: Downloading
# d794c913dba9: Verifying Checksum
# d794c913dba9: Download complete
# 9ab73276ab4f: Pull complete
# d794c913dba9: Extracting
# d794c913dba9: Extracting
# d794c913dba9: Pull complete
# 763d244b9419: Extracting
# 763d244b9419: Extracting
# 763d244b9419: Pull complete
# Digest: sha256:b8117c3b9015ae1a87b107a713b75d1afbe3d582fbffaafdf873e392e9deac2a
# Status: Downloaded newer image for eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/cifar10-pytorch@sha256:b8117c3b9015ae1a87b107a713b75d1afbe3d582fbffaafdf873e392e9deac2a
# ---------------------------------------------------------------------------
# WebserviceException                       Traceback (most recent call last)
# <ipython-input-20-a68e0e9ceed9> in <module>
#      17
#      18 # Download the dockerfile. This can only be used if generate_dockerfile is set to True
# ---> 19 package.save("./docker")
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/core/model.py in save(self, output_directory)
#    2574         """
#    2575         if not self.generate_dockerfile:
# -> 2576             raise WebserviceException('Docker images cannot be saved to a local directory. Use pull() instead.')
#    2577
#    2578         if os.path.exists(output_directory) and not os.path.isdir(output_directory):
#
# WebserviceException: WebserviceException:
# 	Message: Docker images cannot be saved to a local directory. Use pull() instead.
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Docker images cannot be saved to a local directory. Use pull() instead."
#     }
# }

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/tutorials/get-started-day1/day1-part4-data.png)

# %%
# !python training/train.py --data_path ./data --learning_rate 0.003 --momentum 0.92
# Out:
# Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception (pyOpenSSL 20.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (pyOpenSSL 20.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception (pyOpenSSL 20.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception (pyOpenSSL 20.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception (pyOpenSSL 20.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('pyopenssl<20.0.0'), {'azureml-core'}).
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (pyOpenSSL 20.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('pyopenssl<20.0.0')).
# ===== DATA =====
# DATA PATH: ./data
# LIST FILES IN DATA PATH...
# ['cifar-10-batches-py', 'cifar-10-python.tar.gz']
# ================
# Attempted to log scalar metric loss:
# 2.0259851259589197
# epoch=1, batch= 2000: loss 2.03
# Attempted to log scalar metric loss:
# 1.740342852383852
# epoch=1, batch= 4000: loss 1.74
# Attempted to log scalar metric loss:
# 1.6251984751969575
# epoch=1, batch= 6000: loss 1.63
# Attempted to log scalar metric loss:
# 1.5506755608320235
# epoch=1, batch= 8000: loss 1.55
# Attempted to log scalar metric loss:
# 1.5485719104409217
# epoch=1, batch=10000: loss 1.55
# Attempted to log scalar metric loss:
# 1.5301948567777872
# epoch=1, batch=12000: loss 1.53
# Attempted to log scalar metric loss:
# 1.4574734349399805
# epoch=2, batch= 2000: loss 1.46
# Attempted to log scalar metric loss:
# 1.4595430343970657
# epoch=2, batch= 4000: loss 1.46
# Attempted to log scalar metric loss:
# 1.4381724372319877
# epoch=2, batch= 6000: loss 1.44
# Attempted to log scalar metric loss:
# 1.4674658249914647
# epoch=2, batch= 8000: loss 1.47
# Attempted to log scalar metric loss:
# 1.4470414926316588
# epoch=2, batch=10000: loss 1.45
# Attempted to log scalar metric loss:
# 1.4320854246988892
# epoch=2, batch=12000: loss 1.43
# Finished Training
# Attempted to track file cifar_net.pt at cifar_net.pt

# %%
from azureml.core.authentication import InteractiveLoginAuthentication
interactive_auth = InteractiveLoginAuthentication(tenant_id="your-tenant-id")
Additional details on authentication can be found here: https://aka.ms/aml-notebook-auth
# Out:
#   File "<ipython-input-18-aa630af4f9d4>", line 3
#     Additional details on authentication can be found here: https://aka.ms/aml-notebook-auth
#                      ^
# SyntaxError: invalid syntax

# %%
from azureml.core import Dataset
from azureml.opendatasets import MNIST

data_folder = os.path.join(os.getcwd(), 'data')
os.makedirs(data_folder, exist_ok=True)

mnist_file_dataset = MNIST.get_file_dataset()
mnist_file_dataset.download(data_folder, overwrite=True)

mnist_file_dataset = mnist_file_dataset.register(workspace=ws,
                                                 name='mnist_opendataset',
                                                 description='training and test dataset',
                                                 create_new_version=True)

# %%
# %%writefile $script_folder/train.py

import argparse
import os
import numpy as np
import glob

from sklearn.linear_model import LogisticRegression
import joblib

from azureml.core import Run
from utils import load_data

# let user feed in 2 parameters, the dataset to mount or download, and the regularization rate of the logistic regression model
parser = argparse.ArgumentParser()
parser.add_argument('--data-folder', type=str, dest='data_folder', help='data folder mounting point')
parser.add_argument('--regularization', type=float, dest='reg', default=0.01, help='regularization rate')
args = parser.parse_args()

data_folder = args.data_folder
print('Data folder:', data_folder)

# load train and test set into numpy arrays
# note we scale the pixel intensity values to 0-1 (by dividing it with 255.0) so the model can converge faster.
X_train = load_data(glob.glob(os.path.join(data_folder, '**/train-images-idx3-ubyte.gz'), recursive=True)[0], False) / 255.0
X_test = load_data(glob.glob(os.path.join(data_folder, '**/t10k-images-idx3-ubyte.gz'), recursive=True)[0], False) / 255.0
y_train = load_data(glob.glob(os.path.join(data_folder, '**/train-labels-idx1-ubyte.gz'), recursive=True)[0], True).reshape(-1)
y_test = load_data(glob.glob(os.path.join(data_folder, '**/t10k-labels-idx1-ubyte.gz'), recursive=True)[0], True).reshape(-1)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, sep = '\n')

# get hold of the current run
run = Run.get_context()

print('Train a logistic regression model with regularization rate of', args.reg)
clf = LogisticRegression(C=1.0/args.reg, solver="liblinear", multi_class="auto", random_state=42)
clf.fit(X_train, y_train)

print('Predict the test set')
y_hat = clf.predict(X_test)

# calculate accuracy on the prediction
acc = np.average(y_hat == y_test)
print('Accuracy is', acc)

run.log('regularization rate', np.float(args.reg))
run.log('accuracy', np.float(acc))

os.makedirs('outputs', exist_ok=True)
# note file saved in the outputs folder is automatically uploaded into experiment record
joblib.dump(value=clf, filename='outputs/sklearn_mnist_model.pkl')

# %%
from azureml.core import ScriptRunConfig

args = ['--data-folder', mnist_file_dataset.as_mount(), '--regularization', 0.5]

src = ScriptRunConfig(source_directory=script_folder,
                      script='train.py', 
                      arguments=args,
                      compute_target=compute_target,
                      environment=env)

# %%
from azureml.core import Workspace
ws = Workspace.from_config()
datastore = ws.get_default_datastore()
datastore.upload(src_dir='./data', target_path='datasets/cifar10', overwrite=True)

# %% [markdown]
# The `target_path` specifies the path on the datastore where the CIFAR10 data will be uploaded.
#
# ## Submit your machine learning code to Azure Machine Learning
#
# As you have done previously, create a new Python control script:

# %% [markdown]
# ### Understand the control code
#
# The above control code has the following additional code compared to the control code written in [previous tutorial](03-train-model.ipynb)
#
# **`dataset = Dataset.File.from_files(path=(datastore, 'datasets/cifar10'))`**: A Dataset is used to reference the data you uploaded to the Azure Blob Store. Datasets are an abstraction layer on top of your data that are designed to improve reliability and trustworthiness.
#
#
# **`config = ScriptRunConfig(...)`**: We modified the `ScriptRunConfig` to include a list of arguments that will be passed into `train.py`. We also specified `dataset.as_named_input('input').as_mount()`, which means the directory specified will be _mounted_ to the compute target.
#
# ## Inspect the 70_driver_log log file
#
# In the navigate to the 70_driver_log.txt file - you should see the following output:
#
# ```
# Processing 'input'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'datasets/cifar10')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "XXXXX",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='XXXX', subscription_id='XXXX', resource_group='X')"
#   }
# }
# Mounting input to /tmp/tmp9kituvp3.
# Mounted input to /tmp/tmp9kituvp3 as folder.
# Exit __enter__ of DatasetContextManager
# Entering Run History Context Manager.
# Current directory:  /mnt/batch/tasks/shared/LS_root/jobs/dsvm-aml/azureml/tutorial-session-3_1600171983_763c5381/mounts/workspaceblobstore/azureml/tutorial-session-3_1600171983_763c5381
# Preparing to call script [ train.py ] with arguments: ['--data_path', '$input', '--learning_rate', '0.003', '--momentum', '0.92']
# After variable expansion, calling script [ train.py ] with arguments: ['--data_path', '/tmp/tmp9kituvp3', '--learning_rate', '0.003', '--momentum', '0.92']
#
# Script type = None
# ===== DATA =====
# DATA PATH: /tmp/tmp9kituvp3
# LIST FILES IN DATA PATH...
# ['cifar-10-batches-py', 'cifar-10-python.tar.gz']
# ```
#
# Notice:
#
# 1. Azure Machine Learning has mounted the blob store to the compute cluster automatically for you.
# 2. The ``dataset.as_named_input('input').as_mount()`` used in the control script resolves to the mount point
# 3. In the machine learning code we include a line to list the directorys under the data directory - you can see the list above.
#
# ## Clean up resources
#
# The compute cluster will scale down to zero after 40minutes of idle time. When the compute is idle you will not be charged. If you want to delete the cluster use:

# %%
from azureml.core import Workspace

ws = Workspace.from_config()
ct = ws.compute_targets['cpu-cluster']
# ct.delete()

# %% [markdown]
# If you're not going to use what you've created here, delete the resources you just created with this quickstart so you don't incur any charges for storage. In the Azure portal, select and delete your resource group.
#
# ## Next Steps
#
# To learn more about the capabilities of Azure Machine Learning please refer to the following documentation:
#
# * [Azure Machine Learning Pipelines](https://docs.microsoft.com/en-us/azure/machine-learning/concept-ml-pipelines#building-pipelines-with-the-python-sdk)
# * [Deploy models for real-time scoring](https://docs.microsoft.com/en-us/azure/machine-learning/tutorial-deploy-models-with-aml)
# * [Hyper parameter tuning with Azure Machine Learning](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-tune-hyperparameters)
# * [Prep your code for production](https://docs.microsoft.com/azure/machine-learning/tutorial-convert-ml-experiment-to-production)

# %% [markdown]
# ## Test the model service
# In the next cell, you get some unseen data from the test loader:

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(4)))

# %%
import json

input_payload = json.dumps({
    'data': images.tolist()
})

output = service.run(input_payload)
print(output)
