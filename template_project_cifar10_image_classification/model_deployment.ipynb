# %%
import uuid
from azureml.core import Environment, Workspace
from azureml.core.compute import AksCompute, ComputeTarget
from azureml.core.compute_target import ComputeTargetException
from azureml.core.model import InferenceConfig, Model
from azureml.core.webservice import AciWebservice, AksWebservice, Webservice

# %% [markdown]
# # Workspace

# %% [markdown]
# ### Option 1: Create Workspace from Config

# %%
ws = Workspace.from_config()

# %% [markdown]
# ### Option 2: Create Workspace from Connection Info

# %%
# ws = Workspace.get(name="sbirk-aml-ws",
#                    subscription_id="bf088f59-f015-4332-bd36-54b988be7c90",
#                    resource_group="sbirk-aml-rg")

# %% [markdown]
# # Model

# %% [markdown]
# ### Retrieve Registered Model from Workspace

# %%
model_name = "cifar10-model"
model = Model(workspace=ws, name=model_name)

# %% [markdown]
# # Deployment Environment

# %% [markdown]
# ### Option 1: Retrieve Environment from Workspace

# %%
# env_name = "pytorch-aml-env"
# env = Environment.get(workspace=ws, name=env_name)

# %% [markdown]
# ### Option 2: Create New Environment

# %%
# On the first run in given environment, Azure ML spends some time building the environment.
# On the subsequent runs, Azure ML keeps track of changes and uses the existing environment, 
# resulting in faster run completion.

env = Environment.from_conda_specification(name="pytorch-aml-env",
                                           file_path="environment.yml")

# Use Python dependencies from your Docker image (as opposed to from conda specification)
# env.python.user_managed_dependencies=True

## Only uncomment one of the three below options
# OPTION 1: Use mcr base image
#env.docker.base_image = "mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1"

# Option 2: Use custom base image from workspace-native ACR
#env.docker.base_image = "eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/base/pytorch"

# OPTION 3: Use custom base image from standalone ACR. For this you need to enable admin user in the ACR.
env.docker.base_image = "sbirkacr.azurecr.io/base/pytorch"
env.docker.base_image_registry.address = "sbirkacr.azurecr.io"
env.docker.base_image_registry.username = "sbirkacr"
env.docker.base_image_registry.password = "HqAu5Y2We0gZ42IunR5MBXkKc+shf2uj" # replace with Key Vault

# env.environment_variables = {"MESSAGE": "Hello from Azure Machine Learning"}
# This can be retrieved in training script with os.environ.get("MESSAGE")

env.inferencing_stack_version = "latest"
# This will install the inference specific apt packages. This is needed for inferencing images.

# env.register(workspace=ws)

# %% [markdown]
# # Inference Artifacts & Configuration

# %%
# Create Inference Config
inference_config = InferenceConfig(entry_script="deployment/score.py",
                                   environment=env)

# %% [markdown]
# # Deployment

# %% [markdown]
# ## Option 1: Package Models

# %% [markdown]
# [Package a registered model with docker](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-package-models):
#
# In some cases, you might want to create a Docker image without deploying the model (if, for example, you plan to deploy to Azure App Service). Or you might want to download the image and run it on a local Docker installation. You might even want to download the files used to build the image, inspect them, modify them, and build the image manually.
#
# Model packaging enables you to do these things. It packages all the assets needed to host a model as a web service and allows you to download either a fully built Docker image or the files needed to build one. There are two ways to use model packaging:
#
# **Download a packaged model:** Download a Docker image that contains the model and other files needed to host it as a web service.
#
# **Generate a Dockerfile:** Download the Dockerfile, model, entry script, and other assets needed to build a Docker image. You can then inspect the files or make changes before you build the image locally.
#
# Creating a package is similar to deploying a model. You use a registered model and an inference configuration. The following code builds an image, which is registered in the Azure Container Registry for your workspace.

# %%
image_name = "inference/cifar10-pytorch2"
image_label = "1.0" # image tag

# Creating package
package = Model.package(ws, 
                        [model], 
                        inference_config=inference_config, 
                        generate_dockerfile=False,
                        image_name=image_name,
                        image_label=image_label)

package.wait_for_creation(show_output=True)
# Out:
# 2021/01/08 14:09:15 Downloading source code...
# 2021/01/08 14:09:17 Finished downloading source code
# 2021/01/08 14:09:17 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/01/08 14:09:18 Successfully set up Docker network: acb_default_network
# 2021/01/08 14:09:18 Setting up Docker configuration...
# 2021/01/08 14:09:18 Successfully set up Docker configuration
# 2021/01/08 14:09:18 Logging in to registry: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io
# 2021/01/08 14:09:24 Successfully logged into eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io
# 2021/01/08 14:09:24 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/08 14:09:24 Launching container with name: acb_step_0
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /acb/home/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# 2021/01/08 14:09:26 Successfully executed container: acb_step_0
# 2021/01/08 14:09:26 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/08 14:09:26 Scanning for dependencies...
# 2021/01/08 14:09:26 Successfully scanned dependencies
# 2021/01/08 14:09:26 Launching container with name: acb_step_1
# Sending build context to Docker daemon  65.02kB
# Step 1/22 : FROM mcr.microsoft.com/azureml/o16n-base/python-assets:latest AS inferencing-assets
# latest: Pulling from azureml/o16n-base/python-assets
# 4c214b2e9432: Pulling fs layer
# 4c214b2e9432: Verifying Checksum
# 4c214b2e9432: Download complete
# 4c214b2e9432: Pull complete
# Digest: sha256:dd6373d9d31b52869f58057a54a321d43d6adef416f03f98a578277287eda7e8
# Status: Downloaded newer image for mcr.microsoft.com/azureml/o16n-base/python-assets:latest
#  ---> 394986a72682
# Step 2/22 : FROM sbirkacr.azurecr.io/base/pytorch@sha256:c9965db4542714161cec2bb1c7a118e9919a88ce8915e506846e8a831bf130ed
# sha256:c9965db4542714161cec2bb1c7a118e9919a88ce8915e506846e8a831bf130ed: Pulling from base/pytorch
# 2c11b7cecaa5: Already exists
# 04637fa56252: Already exists
# d6e6af23a0f3: Already exists
# b4a424de92ad: Already exists
# 3e5d9ee64909: Pulling fs layer
# 3a846111ff22: Pulling fs layer
# 93a5020c6e19: Pulling fs layer
# 360b353e68fd: Pulling fs layer
# ea4e2e1810f8: Pulling fs layer
# def12cf7de15: Pulling fs layer
# 3ae6adfbdb11: Pulling fs layer
# 2a21fbf2232e: Pulling fs layer
# 360b353e68fd: Waiting
# ea4e2e1810f8: Waiting
# def12cf7de15: Waiting
# 3ae6adfbdb11: Waiting
# 2a21fbf2232e: Waiting
# 3a846111ff22: Verifying Checksum
# 3a846111ff22: Download complete
# 93a5020c6e19: Verifying Checksum
# 93a5020c6e19: Download complete
# 3e5d9ee64909: Verifying Checksum
# 3e5d9ee64909: Download complete
# 360b353e68fd: Verifying Checksum
# 360b353e68fd: Download complete
# 3ae6adfbdb11: Verifying Checksum
# 3ae6adfbdb11: Download complete
# def12cf7de15: Verifying Checksum
# def12cf7de15: Download complete
# 2a21fbf2232e: Verifying Checksum
# 2a21fbf2232e: Download complete
# ea4e2e1810f8: Verifying Checksum
# ea4e2e1810f8: Download complete
# 3e5d9ee64909: Pull complete
# 3a846111ff22: Pull complete
# 93a5020c6e19: Pull complete
# 360b353e68fd: Pull complete
# ea4e2e1810f8: Pull complete
# def12cf7de15: Pull complete
# 3ae6adfbdb11: Pull complete
# 2a21fbf2232e: Pull complete
# Digest: sha256:c9965db4542714161cec2bb1c7a118e9919a88ce8915e506846e8a831bf130ed
# Status: Downloaded newer image for sbirkacr.azurecr.io/base/pytorch@sha256:c9965db4542714161cec2bb1c7a118e9919a88ce8915e506846e8a831bf130ed
#  ---> aec5c40a18a2
# Step 3/22 : USER root
#  ---> Running in c49081bff170
# Removing intermediate container c49081bff170
#  ---> ad679451749c
# Step 4/22 : RUN mkdir -p $HOME/.cache
#  ---> Running in f25ccb975133
# Removing intermediate container f25ccb975133
#  ---> 95223480b11e
# Step 5/22 : WORKDIR /
#  ---> Running in cddaa12015b1
# Removing intermediate container cddaa12015b1
#  ---> 895e4be97c62
# Step 6/22 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 596b1701d693
# Step 7/22 : RUN true
#  ---> Running in 632db4398d42
# Removing intermediate container 632db4398d42
#  ---> 79aac563e26b
# Step 8/22 : COPY --from=inferencing-assets /artifacts /var/
#  ---> d0c250ae337d
# Step 9/22 : RUN /var/requirements/install_system_requirements.sh
#  ---> Running in f96f524fb7b2
# Get:1 http://ppa.launchpad.net/adiscon/v8-stable/ubuntu xenial InRelease [17.5 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu xenial InRelease
# Get:3 http://archive.ubuntu.com/ubuntu xenial-updates InRelease [109 kB]
# Get:4 http://security.ubuntu.com/ubuntu xenial-security InRelease [109 kB]
# Get:5 http://archive.ubuntu.com/ubuntu xenial-backports InRelease [107 kB]
# Get:6 https://packages.microsoft.com/ubuntu/16.04/prod xenial InRelease [4003 B]
# Get:7 http://ppa.launchpad.net/adiscon/v8-stable/ubuntu xenial/main amd64 Packages [8500 B]
# Get:8 http://archive.ubuntu.com/ubuntu xenial-updates/main amd64 Packages [2406 kB]
# Get:9 http://archive.ubuntu.com/ubuntu xenial-updates/universe amd64 Packages [1532 kB]
# Get:10 http://archive.ubuntu.com/ubuntu xenial-updates/multiverse amd64 Packages [26.4 kB]
# Get:11 http://security.ubuntu.com/ubuntu xenial-security/main amd64 Packages [1896 kB]
# Get:12 http://security.ubuntu.com/ubuntu xenial-security/universe amd64 Packages [979 kB]
# Get:13 http://security.ubuntu.com/ubuntu xenial-security/multiverse amd64 Packages [8820 B]
# Get:14 https://packages.microsoft.com/ubuntu/16.04/prod xenial/main amd64 Packages [194 kB]
# Fetched 7397 kB in 1s (6081 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   software-properties-common
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 9504 B of archives.
# After this operation, 193 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu xenial-updates/main amd64 software-properties-common all 0.96.20.10 [9504 B]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 9504 B in 0s (183 kB/s)
# Selecting previously unselected package software-properties-common.
# (Reading database ... 17913 files and directories currently installed.)
# Preparing to unpack .../software-properties-common_0.96.20.10_all.deb ...
# Unpacking software-properties-common (0.96.20.10) ...
# Processing triggers for dbus (1.10.6-1ubuntu3.6) ...
# Setting up software-properties-common (0.96.20.10) ...
# Processing triggers for dbus (1.10.6-1ubuntu3.6) ...
# gpg: keyring `/tmp/tmp3a2zl71w/secring.gpg' created
# gpg: keyring `/tmp/tmp3a2zl71w/pubring.gpg' created
# gpg: requesting key 5234BF2B from hkp server keyserver.ubuntu.com
# gpg: /tmp/tmp3a2zl71w/trustdb.gpg: trustdb created
# gpg: key 5234BF2B: public key "Launchpad PPA for Adiscon" imported
# gpg: Total number processed: 1
# gpg:               imported: 1  (RSA: 1)
# OK
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following packages were automatically installed and are no longer required:
#   dh-python distro-info-data file gir1.2-glib-2.0 iso-codes libapt-inst2.0
#   libdbus-glib-1-2 libgirepository-1.0-1 libmagic1 libmpdec2 libpython3-stdlib
#   libpython3.5-minimal libpython3.5-stdlib lsb-release mime-support
#   powermgmt-base python-apt-common python3 python3-apt python3-dbus python3-gi
#   python3-minimal python3-pycurl python3-software-properties python3.5
#   python3.5-minimal unattended-upgrades
# Use 'apt autoremove' to remove them.
# The following packages will be REMOVED:
#   software-properties-common*
# 0 upgraded, 0 newly installed, 1 to remove and 20 not upgraded.
# After this operation, 193 kB disk space will be freed.
# (Reading database ... 17928 files and directories currently installed.)
# Removing software-properties-common (0.96.20.10) ...
# Purging configuration files for software-properties-common (0.96.20.10) ...
# Processing triggers for dbus (1.10.6-1ubuntu3.6) ...
# Hit:1 http://ppa.launchpad.net/adiscon/v8-stable/ubuntu xenial InRelease
# Hit:2 http://security.ubuntu.com/ubuntu xenial-security InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu xenial InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu xenial-updates InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu xenial-backports InRelease
# Hit:6 https://packages.microsoft.com/ubuntu/16.04/prod xenial InRelease
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libunwind8 is already the newest version (1.1-4.1).
# liblttng-ust0 is already the newest version (2.7.1-1).
# libxml++2.6-2v5 is already the newest version (2.40.1-1).
# runit is already the newest version (2.1.2-3ubuntu1).
# psmisc is already the newest version (22.21-2.1ubuntu0.1).
# wget is already the newest version (1.17.1-1ubuntu1.5).
# nginx-light is already the newest version (1.10.3-0ubuntu0.16.04.5).
# The following packages were automatically installed and are no longer required:
#   dh-python distro-info-data file gir1.2-glib-2.0 iso-codes libapt-inst2.0
#   libdbus-glib-1-2 libgirepository-1.0-1 libmagic1 libmpdec2 libpython3-stdlib
#   libpython3.5-minimal libpython3.5-stdlib lsb-release mime-support
#   powermgmt-base python-apt-common python3 python3-apt python3-dbus python3-gi
#   python3-minimal python3-pycurl python3-software-properties python3.5
#   python3.5-minimal unattended-upgrades
# Use 'apt autoremove' to remove them.
# Suggested packages:
#   rsyslog-mysql | rsyslog-pgsql rsyslog-doc rsyslog-relp rsyslog-elasticsearch
#   rsyslog-mmjsonparse rsyslog-imptcp rsyslog-gnutls rsyslog-openssl
#   rsyslog-udpspoof rsyslog-mmrm1stspace rsyslog-mmutf8fix rsyslog-kafka
#   rsyslog-omstdout apparmor zip
# The following packages will be upgraded:
#   libcurl3 rsyslog unzip
# 3 upgraded, 0 newly installed, 0 to remove and 17 not upgraded.
# Need to get 998 kB of archives.
# After this operation, 14.3 kB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/adiscon/v8-stable/ubuntu xenial/main amd64 rsyslog amd64 8.2012.0-0adiscon1xenial1 [650 kB]
# Get:2 http://archive.ubuntu.com/ubuntu xenial-updates/main amd64 libcurl3 amd64 7.47.0-1ubuntu2.18 [187 kB]
# Get:3 http://archive.ubuntu.com/ubuntu xenial-updates/main amd64 unzip amd64 6.0-20ubuntu1.1 [162 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 998 kB in 0s (10.9 MB/s)
# (Reading database ... 17913 files and directories currently installed.)
# Preparing to unpack .../rsyslog_8.2012.0-0adiscon1xenial1_amd64.deb ...
# Unpacking rsyslog (8.2012.0-0adiscon1xenial1) over (8.2010.0-0adiscon1xenial1) ...
# Preparing to unpack .../libcurl3_7.47.0-1ubuntu2.18_amd64.deb ...
# Unpacking libcurl3:amd64 (7.47.0-1ubuntu2.18) over (7.47.0-1ubuntu2.16) ...
# Preparing to unpack .../unzip_6.0-20ubuntu1.1_amd64.deb ...
# Unpacking unzip (6.0-20ubuntu1.1) over (6.0-20ubuntu1) ...
# Processing triggers for systemd (229-4ubuntu21.29) ...
# Processing triggers for libc-bin (2.23-0ubuntu11.2) ...
# Processing triggers for mime-support (3.59ubuntu1) ...
# Setting up rsyslog (8.2012.0-0adiscon1xenial1) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of restart.
# Setting up libcurl3:amd64 (7.47.0-1ubuntu2.18) ...
# Setting up unzip (6.0-20ubuntu1.1) ...
# Processing triggers for libc-bin (2.23-0ubuntu11.2) ...
# Removing intermediate container f96f524fb7b2
#  ---> e8ee09617e0a
# Step 10/22 : RUN cp /var/configuration/rsyslog.conf /etc/rsyslog.conf && cp /var/configuration/nginx.conf /etc/nginx/sites-available/app && ln -sf /etc/nginx/sites-available/app /etc/nginx/sites-enabled/app && rm -f /etc/nginx/sites-enabled/default
#  ---> Running in 82ea636f4461
# Removing intermediate container 82ea636f4461
#  ---> ec32366341f2
# Step 11/22 : ENV SVDIR=/var/runit
#  ---> Running in 0e3461283723
# Removing intermediate container 0e3461283723
#  ---> 9c0dc1905bcb
# Step 12/22 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 62048117c8d0
# Removing intermediate container 62048117c8d0
#  ---> 44db7d42c655
# Step 13/22 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 514d82064dda
# Step 14/22 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_ee9b10de42be281b146461e2fba517f5 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 66d561850d87
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
# readline-7.0         | 324 KB    | ########## | 100%
# pillow-8.1.0         | 623 KB    | ########## | 100%
# ninja-1.10.2         | 1.4 MB    | ########## | 100%
# pytorch-1.7.0        | 661.4 MB  | #######9   |  80%
# pytorch-1.7.0        | 661.4 MB  | #########9 | 100%
# pytorch-1.7.0        | 661.4 MB  | ########## | 100%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
# libuv-1.40.0         | 736 KB    | ########## | 100%
# freetype-2.10.4      | 596 KB    | ########## | 100%
# certifi-2020.12.5    | 141 KB    | ########## | 100%
# ncurses-6.2          | 817 KB    | ########## | 100%
# lz4-c-1.9.2          | 175 KB    | ########## | 100%
# zlib-1.2.11          | 103 KB    | ########## | 100%
# libpng-1.6.37        | 278 KB    | ########## | 100%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
# cudatoolkit-11.0.221 | 622.9 MB  | #########9 | 100%
# cudatoolkit-11.0.221 | 622.9 MB  | ########## | 100%
# sqlite-3.33.0        | 1.1 MB    | ########## | 100%
# jpeg-9b              | 214 KB    | ########## | 100%
# pip-20.3.3           | 1.8 MB    | ########## | 100%
# openssl-1.1.1i       | 2.5 MB    | ########## | 100%
# lcms2-2.11           | 307 KB    | ########## | 100%
# typing_extensions-3. | 28 KB     | ########## | 100%
# libgcc-ng-9.1.0      | 5.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# xz-5.2.5             | 341 KB    | ########## | 100%
# numpy-1.19.2         | 22 KB     | ########## | 100%
# libffi-3.2.1         | 48 KB     | ########## | 100%
# libtiff-4.1.0        | 449 KB    | ########## | 100%
# olefile-0.46         | 50 KB     | ########## | 100%
# mkl_fft-1.2.0        | 148 KB    | ########## | 100%
# zstd-1.4.5           | 619 KB    | ########## | 100%
# intel-openmp-2020.2  | 786 KB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 3.1 MB    | ########## | 100%
# torchvision-0.8.1    | 18.0 MB   | ########## | 100%
# libedit-3.1.20191231 | 116 KB    | ########## | 100%
# python-3.7.1         | 31.9 MB   | ########## | 100%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
# six-1.15.0           | 27 KB     | ########## | 100%
# wheel-0.36.2         | 33 KB     | ########## | 100%
# mkl_random-1.1.1     | 322 KB    | ########## | 100%
# setuptools-51.0.0    | 711 KB    | ########## | 100%
# blas-1.0             | 6 KB      | ########## | 100%
# ca-certificates-2020 | 121 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... b'By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html\n'
# done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_ee9b10de42be281b146461e2fba517f5/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.r1mbbtin.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.19.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Requirement already satisfied: numpy>=1.13.0 in /azureml-envs/azureml_ee9b10de42be281b146461e2fba517f5/lib/python3.7/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.r1mbbtin.requirements.txt (line 1)) (1.19.2)
# Requirement already satisfied: six>=1.10 in /azureml-envs/azureml_ee9b10de42be281b146461e2fba517f5/lib/python3.7/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.r1mbbtin.requirements.txt (line 1)) (1.15.0)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting adal>=0.4.5
#   Downloading adal-1.2.5-py2.py3-none-any.whl (55 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-core~=1.19.0
#   Downloading azureml_core-1.19.0-py3-none-any.whl (2.1 MB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.0.0-py2.py3-none-any.whl (1.1 MB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.19.0
#   Downloading azureml_dataset_runtime-1.19.0.post1-py3-none-any.whl (3.5 kB)
# Collecting azureml-dataprep<2.7.0a,>=2.6.0a
#   Downloading azureml_dataprep-2.6.4-py3-none-any.whl (39.4 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.9.0-py2.py3-none-any.whl (124 kB)
# Collecting azureml-dataprep-native<27.0.0,>=26.0.0
#   Downloading azureml_dataprep_native-26.0.0-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azureml-dataprep-rslex<1.5.0a,>=1.4.0dev0
#   Downloading azureml_dataprep_rslex-1.4.0-cp37-cp37m-manylinux2010_x86_64.whl (7.9 MB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting cryptography>=1.1.0
#   Downloading cryptography-3.3.1-cp36-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.4-cp37-cp37m-manylinux1_x86_64.whl (402 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp37-cp37m-manylinux1_x86_64.whl (27 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.8.0-py2.py3-none-any.whl (58 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.19-py2.py3-none-any.whl (84 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_ee9b10de42be281b146461e2fba517f5/lib/python3.7/site-packages (from msrest>=0.5.1->azureml-core~=1.19.0->azureml-defaults->-r /azureml-environment-setup/condaenv.r1mbbtin.requirements.txt (line 1)) (2020.12.5)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.2.0-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp37-cp37m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting PyJWT>=1.0.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting pyopenssl<20.0.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting python-dateutil>=2.5.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting pytz>=2017.2
#   Downloading pytz-2020.5-py2.py3-none-any.whl (510 kB)
# Collecting requests>=2.17.3
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.2-cp37-cp37m-manylinux1_x86_64.whl (547 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.2-py2.py3-none-any.whl (136 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.19.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-pipeline~=1.19.0
#   Downloading azureml_pipeline-1.19.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-pipeline-core~=1.19.0
#   Downloading azureml_pipeline_core-1.19.0-py3-none-any.whl (306 kB)
# Collecting azureml-pipeline-steps~=1.19.0
#   Downloading azureml_pipeline_steps-1.19.0-py3-none-any.whl (62 kB)
# Collecting azureml-train~=1.19.0
#   Downloading azureml_train-1.19.0-py3-none-any.whl (3.3 kB)
# Collecting azureml-train-automl-client~=1.19.0
#   Downloading azureml_train_automl_client-1.19.0-py3-none-any.whl (109 kB)
# Collecting azureml-automl-core~=1.19.0
#   Downloading azureml_automl_core-1.19.0-py3-none-any.whl (188 kB)
# Collecting azureml-telemetry~=1.19.0
#   Downloading azureml_telemetry-1.19.0-py3-none-any.whl (30 kB)
# Collecting azureml-train-core~=1.19.0
#   Downloading azureml_train_core-1.19.0-py3-none-any.whl (8.6 MB)
# Collecting azureml-train-restclients-hyperdrive~=1.19.0
#   Downloading azureml_train_restclients_hyperdrive-1.19.0-py3-none-any.whl (19 kB)
# Collecting azureml-widgets
#   Downloading azureml_widgets-1.19.0-py3-none-any.whl (14.1 MB)
# Collecting ipywidgets>=7.0.0
#   Downloading ipywidgets-7.6.3-py2.py3-none-any.whl (121 kB)
# Collecting ipykernel>=4.5.1
#   Downloading ipykernel-5.4.2-py3-none-any.whl (119 kB)
# Collecting ipython>=4.0.0
#   Downloading ipython-7.19.0-py3-none-any.whl (784 kB)
# Requirement already satisfied: setuptools>=18.5 in /azureml-envs/azureml_ee9b10de42be281b146461e2fba517f5/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->azureml-widgets->-r /azureml-environment-setup/condaenv.r1mbbtin.requirements.txt (line 3)) (51.0.0.post20201207)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.0-py2.py3-none-any.whl (1.4 MB)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.0.0-py3-none-any.whl (243 kB)
# Collecting nbformat>=4.2.0
#   Downloading nbformat-5.0.8-py3-none-any.whl (172 kB)
# Collecting jsonschema!=2.5.0,>=2.4
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-20.3.0-py2.py3-none-any.whl (49 kB)
# Collecting parso<0.9.0,>=0.8.0
#   Downloading parso-0.8.1-py2.py3-none-any.whl (93 kB)
# Collecting pexpect>4.3
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.10-py3-none-any.whl (355 kB)
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.17.3.tar.gz (106 kB)
# Collecting tornado>=4.2
#   Downloading tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
# Collecting traitlets>=4.3.1
#   Downloading traitlets-5.0.5-py3-none-any.whl (100 kB)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
# Collecting notebook>=4.4.1
#   Downloading notebook-6.1.6-py3-none-any.whl (9.5 MB)
# Collecting jupyter-client
#   Downloading jupyter_client-6.1.10-py3-none-any.whl (108 kB)
# Collecting jedi>=0.10
#   Downloading jedi-0.17.2-py2.py3-none-any.whl (1.4 MB)
#   Downloading jedi-0.17.1-py2.py3-none-any.whl (1.4 MB)
#   Downloading jedi-0.17.0-py2.py3-none-any.whl (1.1 MB)
# Collecting jupyter-core
#   Downloading jupyter_core-4.7.0-py3-none-any.whl (82 kB)
# Collecting pyzmq>=17
#   Downloading pyzmq-20.0.0-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.9.2-py3-none-any.whl (14 kB)
# Collecting argon2-cffi
#   Downloading argon2_cffi-20.1.0-cp35-abi3-manylinux1_x86_64.whl (97 kB)
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting decorator
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Collecting docker
#   Downloading docker-4.4.1-py2.py3-none-any.whl (146 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-3.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions>=3.6.4 in /azureml-envs/azureml_ee9b10de42be281b146461e2fba517f5/lib/python3.7/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->azureml-widgets->-r /azureml-environment-setup/condaenv.r1mbbtin.requirements.txt (line 3)) (3.7.4.3)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.2-py2.py3-none-any.whl (36 kB)
# Collecting nbconvert
#   Downloading nbconvert-6.0.7-py3-none-any.whl (552 kB)
# Collecting entrypoints>=0.2.2
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting mistune<2,>=0.8.1
#   Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting nbclient<0.6.0,>=0.5.0
#   Downloading nbclient-0.5.1-py3-none-any.whl (65 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.4.3.tar.gz (16 kB)
# Collecting pygments
#   Downloading Pygments-2.7.3-py3-none-any.whl (950 kB)
# Collecting async-generator
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting bleach
#   Downloading bleach-3.2.1-py2.py3-none-any.whl (145 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.6.0-py2.py3-none-any.whl (23 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.4.3-py3-none-any.whl (5.3 kB)
# Collecting packaging
#   Downloading packaging-20.8-py2.py3-none-any.whl (39 kB)
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting prometheus-client
#   Downloading prometheus_client-0.9.0-py2.py3-none-any.whl (53 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.0-py3-none-any.whl (14 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting Send2Trash
#   Downloading Send2Trash-1.5.0-py3-none-any.whl (12 kB)
# Collecting testpath
#   Downloading testpath-0.4.4-py2.py3-none-any.whl (163 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff, pyrsistent, pandocfilters
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=a9a6e2a411e31f7bbb0c4a4829cc624c698916463a1091609c221860a650e43c
#   Stored in directory: /root/.cache/pip/wheels/2b/2c/0b/56aba27cc60071c52f66346a1abc22ee9db8c7376549aa4910
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=b310c92929d779872ede02c254a5176dab1dfedcff83ffed49247e0db587bab7
#   Stored in directory: /root/.cache/pip/wheels/89/07/84/a5ebfafeefbbc56ceda9d6935a54a8be7a4eccf4ea7e9bf980
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11731 sha256=a3d8e5d2e8d01a677e0438eff0e0f2f28b983a838161f1d0e0479c26915bdb42
#   Stored in directory: /root/.cache/pip/wheels/1f/0f/15/332ca86cbebf25ddf98518caaf887945fbe1712b97a0f2493b
#   Building wheel for pyrsistent (setup.py): started
#   Building wheel for pyrsistent (setup.py): finished with status 'done'
#   Created wheel for pyrsistent: filename=pyrsistent-0.17.3-cp37-cp37m-linux_x86_64.whl size=113839 sha256=f7f35ab45811e066463b1c3323b6261c3e678d9566ced5f854e34e928c4684c6
#   Stored in directory: /root/.cache/pip/wheels/a5/52/bf/71258a1d7b3c8cbe1ee53f9314c6f65f20385481eaee573cc5
#   Building wheel for pandocfilters (setup.py): started
#   Building wheel for pandocfilters (setup.py): finished with status 'done'
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.3-py3-none-any.whl size=7992 sha256=72a0bf7701783fecf900419b899c43297e6e8f8f46c0d7cfdc36702db7312b33
#   Stored in directory: /root/.cache/pip/wheels/42/81/34/545dc2fbf0e9137811e901108d37fc04650e81d48f97078000
# Successfully built json-logging-py fusepy liac-arff pyrsistent pandocfilters
# Installing collected packages: pycparser, urllib3, idna, chardet, cffi, requests, PyJWT, oauthlib, cryptography, requests-oauthlib, python-dateutil, isodate, zipp, portalocker, msrest, msal, ipython-genutils, adal, websocket-client, traitlets, ruamel.yaml.clib, pyrsistent, pyopenssl, pyasn1, parso, msrestazure, msal-extensions, jeepney, importlib-metadata, distro, backports.weakref, azure-core, azure-common, attrs, wcwidth, tornado, SecretStorage, ruamel.yaml, pyzmq, pytz, pyparsing, ptyprocess, pathspec, ndg-httpsclient, jupyter-core, jsonschema, jsonpickle, jmespath, jedi, dotnetcore2, docker, contextlib2, cloudpickle, backports.tempfile, azureml-dataprep-rslex, azureml-dataprep-native, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-identity, azure-graphrbac, webencodings, pygments, pyarrow, prompt-toolkit, pickleshare, pexpect, packaging, nest-asyncio, nbformat, MarkupSafe, jupyter-client, decorator, backcall, azureml-dataprep, azureml-core, async-generator, applicationinsights, testpath, pandocfilters, nbclient, mistune, jupyterlab-pygments, Jinja2, ipython, entrypoints, defusedxml, bleach, azureml-telemetry, azureml-dataset-runtime, terminado, Send2Trash, prometheus-client, nbconvert, ipykernel, azureml-train-restclients-hyperdrive, azureml-automl-core, argon2-cffi, notebook, azureml-train-core, azureml-train-automl-client, azureml-pipeline-core, widgetsnbextension, werkzeug, pandas, liac-arff, jupyterlab-widgets, itsdangerous, fusepy, dill, click, azureml-pipeline-steps, json-logging-py, ipywidgets, gunicorn, flask, configparser, azureml-train, azureml-pipeline, azureml-model-management-sdk, azureml-widgets, azureml-sdk, azureml-defaults
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.3.0 Send2Trash-1.5.0 adal-1.2.5 applicationinsights-0.11.9 argon2-cffi-20.1.0 async-generator-1.10 attrs-20.3.0 azure-common-1.1.26 azure-core-1.9.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.0.0 azure-mgmt-storage-11.2.0 azureml-automl-core-1.19.0 azureml-core-1.19.0 azureml-dataprep-2.6.4 azureml-dataprep-native-26.0.0 azureml-dataprep-rslex-1.4.0 azureml-dataset-runtime-1.19.0.post1 azureml-defaults-1.19.0 azureml-model-management-sdk-1.0.1b6.post1 azureml-pipeline-1.19.0 azureml-pipeline-core-1.19.0 azureml-pipeline-steps-1.19.0 azureml-sdk-1.19.0 azureml-telemetry-1.19.0 azureml-train-1.19.0 azureml-train-automl-client-1.19.0 azureml-train-core-1.19.0 azureml-train-restclients-hyperdrive-1.19.0 azureml-widgets-1.19.0 backcall-0.2.0 backports.tempfile-1.0 backports.weakref-1.0.post1 bleach-3.2.1 cffi-1.14.4 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.3.1 decorator-4.4.2 defusedxml-0.6.0 dill-0.3.3 distro-1.5.0 docker-4.4.1 dotnetcore2-2.1.20 entrypoints-0.3 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-3.3.0 ipykernel-5.4.2 ipython-7.19.0 ipython-genutils-0.2.0 ipywidgets-7.6.3 isodate-0.6.0 itsdangerous-1.1.0 jedi-0.17.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.4.2 jsonschema-3.2.0 jupyter-client-6.1.10 jupyter-core-4.7.0 jupyterlab-pygments-0.1.2 jupyterlab-widgets-1.0.0 liac-arff-2.5.0 mistune-0.8.4 msal-1.8.0 msal-extensions-0.2.2 msrest-0.6.19 msrestazure-0.6.4 nbclient-0.5.1 nbconvert-6.0.7 nbformat-5.0.8 ndg-httpsclient-0.5.1 nest-asyncio-1.4.3 notebook-6.1.6 oauthlib-3.1.0 packaging-20.8 pandas-1.2.0 pandocfilters-1.4.3 parso-0.8.1 pathspec-0.8.1 pexpect-4.8.0 pickleshare-0.7.5 portalocker-1.7.1 prometheus-client-0.9.0 prompt-toolkit-3.0.10 ptyprocess-0.7.0 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pygments-2.7.3 pyopenssl-19.1.0 pyparsing-2.4.7 pyrsistent-0.17.3 python-dateutil-2.8.1 pytz-2020.5 pyzmq-20.0.0 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 terminado-0.9.2 testpath-0.4.4 tornado-6.1 traitlets-5.0.5 urllib3-1.26.2 wcwidth-0.2.5 webencodings-0.5.1 websocket-client-0.57.0 werkzeug-1.0.1 widgetsnbextension-3.5.1 zipp-3.4.0
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_ee9b10de42be281b146461e2fba517f5
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container 66d561850d87
#  ---> 2c90fa91ac89
# Step 15/22 : ENV PATH /azureml-envs/azureml_ee9b10de42be281b146461e2fba517f5/bin:$PATH
#  ---> Running in 654b3e957dae
# Removing intermediate container 654b3e957dae
#  ---> 24fe64cae01d
# Step 16/22 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_ee9b10de42be281b146461e2fba517f5
#  ---> Running in 18495f407afb
# Removing intermediate container 18495f407afb
#  ---> 3a99b37e473e
# Step 17/22 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_ee9b10de42be281b146461e2fba517f5/lib:$LD_LIBRARY_PATH
#  ---> Running in 2a9c08ed1c6e
# Removing intermediate container 2a9c08ed1c6e
#  ---> e7a5ef82fac7
# Step 18/22 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> f4ffdc50629f
# Step 19/22 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 2d9f52b7c87e
# Removing intermediate container 2d9f52b7c87e
#  ---> 23c9845742aa
# Step 20/22 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in c372c9ab564d
# Removing intermediate container c372c9ab564d
#  ---> 7916cdc5c1ca
# Step 21/22 : CMD ["bash"]
#  ---> Running in 8b8528801a7a
# Removing intermediate container 8b8528801a7a
#  ---> 1c2b5db23a9e
# Step 22/22 : EXPOSE 5001 8883 8888
#  ---> Running in f234e6b2cfa5
# Removing intermediate container f234e6b2cfa5
#  ---> ebd50d993245
# Successfully built ebd50d993245
# Successfully tagged eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_3346e035349e95ce760b9dd66517c4a0:latest
# 2021/01/08 14:15:28 Successfully executed container: acb_step_1
# 2021/01/08 14:15:28 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/08 14:15:28 Pushing image: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_3346e035349e95ce760b9dd66517c4a0:latest, attempt 1
# The push refers to repository [eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_3346e035349e95ce760b9dd66517c4a0]
# 93fe12a84194: Preparing
# c6168103eeb5: Preparing
# ba9e93957c99: Preparing
# f30992280d33: Preparing
# b656cddec5fd: Preparing
# 7e26fcf224de: Preparing
# eb5afdcb2874: Preparing
# eb20a52a37fe: Preparing
# 1ea46509bfb9: Preparing
# 630330099f1e: Preparing
# 26346e33e93c: Preparing
# 65fd26c61dec: Preparing
# 8b72eff884fd: Preparing
# f06675a4a69e: Preparing
# 7117e7689e0f: Preparing
# d56ca49dab62: Preparing
# 09304b9c7c13: Preparing
# 9edaa71ce233: Preparing
# 62fdddf6a67c: Preparing
# eff16de3ff64: Preparing
# 61727f5e6796: Preparing
# 7e26fcf224de: Waiting
# eb5afdcb2874: Waiting
# eb20a52a37fe: Waiting
# 1ea46509bfb9: Waiting
# 630330099f1e: Waiting
# 26346e33e93c: Waiting
# 65fd26c61dec: Waiting
# 8b72eff884fd: Waiting
# f06675a4a69e: Waiting
# 7117e7689e0f: Waiting
# d56ca49dab62: Waiting
# 09304b9c7c13: Waiting
# 9edaa71ce233: Waiting
# 62fdddf6a67c: Waiting
# eff16de3ff64: Waiting
# 61727f5e6796: Waiting
# 93fe12a84194: Pushed
# ba9e93957c99: Pushed
# b656cddec5fd: Pushed
# f30992280d33: Pushed
# 7e26fcf224de: Pushed
# eb20a52a37fe: Pushed
# 1ea46509bfb9: Pushed
# 630330099f1e: Pushed
# 26346e33e93c: Pushed
# eb5afdcb2874: Pushed
# 65fd26c61dec: Pushed
# d56ca49dab62: Pushed
# 8b72eff884fd: Pushed
# 9edaa71ce233: Pushed
# 62fdddf6a67c: Pushed
# eff16de3ff64: Pushed
# 7117e7689e0f: Pushed
# f06675a4a69e: Pushed
# 61727f5e6796: Pushed
# 09304b9c7c13: Pushed
# c6168103eeb5: Pushed
# latest: digest: sha256:7f11418337ad8c189fa83df6eafb196593dd5579c69bc4eb7b7000592fcb7e68 size: 4727
# 2021/01/08 14:21:37 Successfully pushed image: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_3346e035349e95ce760b9dd66517c4a0:latest
# 2021/01/08 14:21:37 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 1.269349)
# 2021/01/08 14:21:37 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 362.285157)
# 2021/01/08 14:21:37 Populating digests for step ID: acb_step_1...
# 2021/01/08 14:21:39 Successfully populated digests for step ID: acb_step_1
# 2021/01/08 14:21:39 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 368.629281)
# 2021/01/08 14:21:39 The following dependencies were found:
# 2021/01/08 14:21:39
# - image:
#     registry: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io
#     repository: azureml/azureml_3346e035349e95ce760b9dd66517c4a0
#     tag: latest
#     digest: sha256:7f11418337ad8c189fa83df6eafb196593dd5579c69bc4eb7b7000592fcb7e68
#   runtime-dependency:
#     registry: sbirkacr.azurecr.io
#     repository: base/pytorch
#     digest: sha256:c9965db4542714161cec2bb1c7a118e9919a88ce8915e506846e8a831bf130ed
#   buildtime-dependency:
#   - registry: mcr.microsoft.com
#     repository: azureml/o16n-base/python-assets
#     tag: latest
#     digest: sha256:dd6373d9d31b52869f58057a54a321d43d6adef416f03f98a578277287eda7e8
#   git: {}
#
#
# Run ID: cbq was successful after 12m25s
# 2021/01/08 14:22:11 Downloading source code...
# 2021/01/08 14:22:12 Finished downloading source code
# 2021/01/08 14:22:13 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/01/08 14:22:13 Successfully set up Docker network: acb_default_network
# 2021/01/08 14:22:13 Setting up Docker configuration...
# 2021/01/08 14:22:14 Successfully set up Docker configuration
# 2021/01/08 14:22:14 Logging in to registry: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io
# 2021/01/08 14:22:15 Successfully logged into eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io
# 2021/01/08 14:22:15 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/08 14:22:15 Launching container with name: acb_step_0
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /acb/home/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# 2021/01/08 14:22:16 Successfully executed container: acb_step_0
# 2021/01/08 14:22:16 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/08 14:22:16 Scanning for dependencies...
# 2021/01/08 14:22:17 Successfully scanned dependencies
# 2021/01/08 14:22:17 Launching container with name: acb_step_1
# Sending build context to Docker daemon  65.54kB
# Step 1/7 : FROM eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# latest: Pulling from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# 2c11b7cecaa5: Already exists
# 04637fa56252: Already exists
# d6e6af23a0f3: Already exists
# b4a424de92ad: Already exists
# 3e5d9ee64909: Pulling fs layer
# 3a846111ff22: Pulling fs layer
# 93a5020c6e19: Pulling fs layer
# 360b353e68fd: Pulling fs layer
# ea4e2e1810f8: Pulling fs layer
# def12cf7de15: Pulling fs layer
# 3ae6adfbdb11: Pulling fs layer
# 2a21fbf2232e: Pulling fs layer
# 0b8c34a0b764: Pulling fs layer
# b011d91bd7a0: Pulling fs layer
# e4f73cd01d3f: Pulling fs layer
# 3179f45dfac9: Pulling fs layer
# 33889fff181a: Pulling fs layer
# a30002002f4c: Pulling fs layer
# a1cc3b32d6df: Pulling fs layer
# 682eb7c75a3e: Pulling fs layer
# 4f02a155770a: Pulling fs layer
# 360b353e68fd: Waiting
# ea4e2e1810f8: Waiting
# def12cf7de15: Waiting
# 3ae6adfbdb11: Waiting
# 2a21fbf2232e: Waiting
# 0b8c34a0b764: Waiting
# b011d91bd7a0: Waiting
# e4f73cd01d3f: Waiting
# 3179f45dfac9: Waiting
# 33889fff181a: Waiting
# a30002002f4c: Waiting
# a1cc3b32d6df: Waiting
# 682eb7c75a3e: Waiting
# 4f02a155770a: Waiting
# 3a846111ff22: Verifying Checksum
# 3a846111ff22: Download complete
# 93a5020c6e19: Verifying Checksum
# 93a5020c6e19: Download complete
# 3e5d9ee64909: Verifying Checksum
# 3e5d9ee64909: Download complete
# 360b353e68fd: Verifying Checksum
# 360b353e68fd: Download complete
# ea4e2e1810f8: Verifying Checksum
# ea4e2e1810f8: Download complete
# 2a21fbf2232e: Download complete
# 3ae6adfbdb11: Verifying Checksum
# 3ae6adfbdb11: Download complete
# 0b8c34a0b764: Verifying Checksum
# 0b8c34a0b764: Download complete
# def12cf7de15: Verifying Checksum
# def12cf7de15: Download complete
# b011d91bd7a0: Verifying Checksum
# b011d91bd7a0: Download complete
# 33889fff181a: Verifying Checksum
# 33889fff181a: Download complete
# 3179f45dfac9: Verifying Checksum
# 3179f45dfac9: Download complete
# a30002002f4c: Verifying Checksum
# a30002002f4c: Download complete
# a1cc3b32d6df: Verifying Checksum
# a1cc3b32d6df: Download complete
# e4f73cd01d3f: Verifying Checksum
# e4f73cd01d3f: Download complete
# 3e5d9ee64909: Pull complete
# 4f02a155770a: Verifying Checksum
# 4f02a155770a: Download complete
# 3a846111ff22: Pull complete
# 93a5020c6e19: Pull complete
# 360b353e68fd: Pull complete
# ea4e2e1810f8: Pull complete
# def12cf7de15: Pull complete
# 3ae6adfbdb11: Pull complete
# 2a21fbf2232e: Pull complete
# 0b8c34a0b764: Pull complete
# b011d91bd7a0: Pull complete
# e4f73cd01d3f: Pull complete
# 3179f45dfac9: Pull complete
# 33889fff181a: Pull complete
# a30002002f4c: Pull complete
# a1cc3b32d6df: Pull complete
# 682eb7c75a3e: Verifying Checksum
# 682eb7c75a3e: Download complete
# 682eb7c75a3e: Pull complete
# 4f02a155770a: Pull complete
# Digest: sha256:7f11418337ad8c189fa83df6eafb196593dd5579c69bc4eb7b7000592fcb7e68
# Status: Downloaded newer image for eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_3346e035349e95ce760b9dd66517c4a0:latest
#  ---> ebd50d993245
# Step 2/7 : ENV AZUREML_MODEL_DIR=azureml-models/cifar10-model/6
#  ---> Running in dd851a2c201d
# Removing intermediate container dd851a2c201d
#  ---> 11d25c4b1bab
# Step 3/7 : RUN mkdir -p '/var/azureml-app' && /var/azureml-util/download_asset.sh 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/LocalUpload/be435f39/tmplnkj3hw2.py?sv=2019-02-02&sr=b&sig=bAaBYSnfXbeOVN1D68xV178j%2BDc%2BYV6etlZ%2B0Dsteck%3D&st=2021-01-08T14%3A12%3A06Z&se=2021-01-08T22%3A22%3A06Z&sp=r' '/var/azureml-app/tmplnkj3hw2.py' && /var/azureml-util/download_asset.sh 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/LocalUpload/a0e98b48/score.py?sv=2019-02-02&sr=b&sig=zOi%2Bx6pckFvv%2Bt%2BYRH%2FGCUNsnHNLBjlqIwcnKTU8XaY%3D&st=2021-01-08T14%3A12%3A06Z&se=2021-01-08T22%3A22%3A06Z&sp=r' '/var/azureml-app/score.py'
#  ---> Running in 3758866eb2e0
# Downloading https://sbirkamlws3782852688.blob.core.windows.net/azureml/LocalUpload/be435f39/tmplnkj3hw2.py?sv=2019-02-02&sr=b&sig=bAaBYSnfXbeOVN1D68xV178j%2BDc%2BYV6etlZ%2B0Dsteck%3D&st=2021-01-08T14%3A12%3A06Z&se=2021-01-08T22%3A22%3A06Z&sp=r as /var/azureml-app/tmplnkj3hw2.py
# --2021-01-08 14:24:43--  https://sbirkamlws3782852688.blob.core.windows.net/azureml/LocalUpload/be435f39/tmplnkj3hw2.py?sv=2019-02-02&sr=b&sig=bAaBYSnfXbeOVN1D68xV178j%2BDc%2BYV6etlZ%2B0Dsteck%3D&st=2021-01-08T14%3A12%3A06Z&se=2021-01-08T22%3A22%3A06Z&sp=r
# Resolving sbirkamlws3782852688.blob.core.windows.net (sbirkamlws3782852688.blob.core.windows.net)... 52.166.80.100
# Connecting to sbirkamlws3782852688.blob.core.windows.net (sbirkamlws3782852688.blob.core.windows.net)|52.166.80.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1064 (1.0K) [application/octet-stream]
# Saving to: ‘/var/azureml-app/tmplnkj3hw2.py’
#
#      0K                                    100%  115M=0s
#
# 2021-01-08 14:24:43 (115 MB/s) - ‘/var/azureml-app/tmplnkj3hw2.py’ saved [1064/1064]
#
# Downloading https://sbirkamlws3782852688.blob.core.windows.net/azureml/LocalUpload/a0e98b48/score.py?sv=2019-02-02&sr=b&sig=zOi%2Bx6pckFvv%2Bt%2BYRH%2FGCUNsnHNLBjlqIwcnKTU8XaY%3D&st=2021-01-08T14%3A12%3A06Z&se=2021-01-08T22%3A22%3A06Z&sp=r as /var/azureml-app/score.py
# --2021-01-08 14:24:43--  https://sbirkamlws3782852688.blob.core.windows.net/azureml/LocalUpload/a0e98b48/score.py?sv=2019-02-02&sr=b&sig=zOi%2Bx6pckFvv%2Bt%2BYRH%2FGCUNsnHNLBjlqIwcnKTU8XaY%3D&st=2021-01-08T14%3A12%3A06Z&se=2021-01-08T22%3A22%3A06Z&sp=r
# Resolving sbirkamlws3782852688.blob.core.windows.net (sbirkamlws3782852688.blob.core.windows.net)... 52.166.80.100
# Connecting to sbirkamlws3782852688.blob.core.windows.net (sbirkamlws3782852688.blob.core.windows.net)|52.166.80.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1352 (1.3K) [application/octet-stream]
# Saving to: ‘/var/azureml-app/score.py’
#
#      0K                                    100% 3.86M=0s
#
# 2021-01-08 14:24:43 (3.86 MB/s) - ‘/var/azureml-app/score.py’ saved [1352/1352]
#
# Removing intermediate container 3758866eb2e0
#  ---> a5ea3eca87cb
# Step 4/7 : RUN mkdir -p '/var/azureml-app/azureml-models/cifar10-model/6' && /var/azureml-util/download_asset.sh 'https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/cifar_net.pt?sv=2019-02-02&sr=b&sig=0XIaa3q4XmzlMHL%2B9oE%2Fll7G1JVFiSeTWUK9XqOdaK4%3D&st=2021-01-08T14%3A12%3A05Z&se=2021-01-08T22%3A22%3A05Z&sp=r' '/var/azureml-app/azureml-models/cifar10-model/6/cifar_net.pt'
#  ---> Running in 8da30cf2870e
# Downloading https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/cifar_net.pt?sv=2019-02-02&sr=b&sig=0XIaa3q4XmzlMHL%2B9oE%2Fll7G1JVFiSeTWUK9XqOdaK4%3D&st=2021-01-08T14%3A12%3A05Z&se=2021-01-08T22%3A22%3A05Z&sp=r as /var/azureml-app/azureml-models/cifar10-model/6/cifar_net.pt
# --2021-01-08 14:24:47--  https://sbirkamlws3782852688.blob.core.windows.net/azureml/ExperimentRun/dcid.cifar-image-classification-pytorch_1610017830_827f96e5/cifar_net.pt?sv=2019-02-02&sr=b&sig=0XIaa3q4XmzlMHL%2B9oE%2Fll7G1JVFiSeTWUK9XqOdaK4%3D&st=2021-01-08T14%3A12%3A05Z&se=2021-01-08T22%3A22%3A05Z&sp=r
# Resolving sbirkamlws3782852688.blob.core.windows.net (sbirkamlws3782852688.blob.core.windows.net)... 52.166.80.100
# Connecting to sbirkamlws3782852688.blob.core.windows.net (sbirkamlws3782852688.blob.core.windows.net)|52.166.80.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 251401 (246K) [application/octet-stream]
# Saving to: ‘/var/azureml-app/azureml-models/cifar10-model/6/cifar_net.pt’
#
#      0K                                    100% 49.5M=0.005s
#
# 2021-01-08 14:24:47 (49.5 MB/s) - ‘/var/azureml-app/azureml-models/cifar10-model/6/cifar_net.pt’ saved [251401/251401]
#
# Removing intermediate container 8da30cf2870e
#  ---> 66a11a187769
# Step 5/7 : RUN mkdir -p '/var/azureml-app' && echo ... | base64 --decode > /var/azureml-app/model_config_map.json
#  ---> Running in 64ba7f3ca7d7
# Removing intermediate container 64ba7f3ca7d7
#  ---> d41b8b31210f
# Step 6/7 : RUN mv '/var/azureml-app/tmplnkj3hw2.py' /var/azureml-app/main.py
#  ---> Running in 4ae34b06fddc
# Removing intermediate container 4ae34b06fddc
#  ---> 73933624db33
# Step 7/7 : CMD ["runsvdir","/var/runit"]
#  ---> Running in 97895d67171a
# Removing intermediate container 97895d67171a
#  ---> b48cd84138ba
# Successfully built b48cd84138ba
# Successfully tagged eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_77ec732ed409d2179db42f8c47620f4c:latest
# 2021/01/08 14:25:02 Successfully executed container: acb_step_1
# 2021/01/08 14:25:02 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/01/08 14:25:02 Pushing image: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_77ec732ed409d2179db42f8c47620f4c:latest, attempt 1
# The push refers to repository [eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_77ec732ed409d2179db42f8c47620f4c]
# 844e3bc7837a: Preparing
# c5f125c45dba: Preparing
# b25d482a9985: Preparing
# b0e2702495b6: Preparing
# 93fe12a84194: Preparing
# c6168103eeb5: Preparing
# ba9e93957c99: Preparing
# f30992280d33: Preparing
# b656cddec5fd: Preparing
# 7e26fcf224de: Preparing
# eb5afdcb2874: Preparing
# eb20a52a37fe: Preparing
# 1ea46509bfb9: Preparing
# 630330099f1e: Preparing
# 26346e33e93c: Preparing
# 65fd26c61dec: Preparing
# 8b72eff884fd: Preparing
# f06675a4a69e: Preparing
# 7117e7689e0f: Preparing
# d56ca49dab62: Preparing
# 09304b9c7c13: Preparing
# 9edaa71ce233: Preparing
# 62fdddf6a67c: Preparing
# eff16de3ff64: Preparing
# 61727f5e6796: Preparing
# c6168103eeb5: Waiting
# ba9e93957c99: Waiting
# f30992280d33: Waiting
# b656cddec5fd: Waiting
# 7e26fcf224de: Waiting
# eb5afdcb2874: Waiting
# eb20a52a37fe: Waiting
# 1ea46509bfb9: Waiting
# 630330099f1e: Waiting
# 26346e33e93c: Waiting
# 65fd26c61dec: Waiting
# 8b72eff884fd: Waiting
# f06675a4a69e: Waiting
# 7117e7689e0f: Waiting
# d56ca49dab62: Waiting
# 09304b9c7c13: Waiting
# 9edaa71ce233: Waiting
# 62fdddf6a67c: Waiting
# eff16de3ff64: Waiting
# 61727f5e6796: Waiting
# b25d482a9985: Pushed
# c5f125c45dba: Pushed
# b0e2702495b6: Pushed
# 93fe12a84194: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# c6168103eeb5: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# ba9e93957c99: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# 844e3bc7837a: Pushed
# b656cddec5fd: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# f30992280d33: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# 7e26fcf224de: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# 1ea46509bfb9: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# 630330099f1e: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# eb5afdcb2874: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# 26346e33e93c: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# 8b72eff884fd: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# 65fd26c61dec: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# eb20a52a37fe: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# f06675a4a69e: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# 09304b9c7c13: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# d56ca49dab62: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# 7117e7689e0f: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# eff16de3ff64: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# 61727f5e6796: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# 62fdddf6a67c: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# 9edaa71ce233: Mounted from azureml/azureml_3346e035349e95ce760b9dd66517c4a0
# latest: digest: sha256:53cf97f53bd92ea106c497f5dfe86d883aa0f09ea3f03805a338f67f5757d2e6 size: 5559
# 2021/01/08 14:25:16 Successfully pushed image: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io/azureml/azureml_77ec732ed409d2179db42f8c47620f4c:latest
# 2021/01/08 14:25:16 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 1.359666)
# 2021/01/08 14:25:16 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 165.787780)
# 2021/01/08 14:25:16 Populating digests for step ID: acb_step_1...
# 2021/01/08 14:25:17 Successfully populated digests for step ID: acb_step_1
# 2021/01/08 14:25:17 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 13.457855)
# 2021/01/08 14:25:17 The following dependencies were found:
# 2021/01/08 14:25:17
# - image:
#     registry: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io
#     repository: azureml/azureml_77ec732ed409d2179db42f8c47620f4c
#     tag: latest
#     digest: sha256:53cf97f53bd92ea106c497f5dfe86d883aa0f09ea3f03805a338f67f5757d2e6
#   runtime-dependency:
#     registry: eafc0c3ef9714c74a4fa655ee90531ba.azurecr.io
#     repository: azureml/azureml_3346e035349e95ce760b9dd66517c4a0
#     tag: latest
#     digest: sha256:7f11418337ad8c189fa83df6eafb196593dd5579c69bc4eb7b7000592fcb7e68
#   git: {}
#
# Run ID: cbr was successful after 3m8s
# Package creation Succeeded

# %% [markdown]
# After you create a package, you can use package.pull() to pull the image to your local Docker environment. This can only be used if `generate_dockerfile` is set to `False`. When the package is pulled, use the `docker images` command to list the local images.

# %%
# package.pull()

# %% [markdown]
# To start a local container based on this image, use the following command to start a named container from the shell or command line. Replace the `<imageid>` value with the image ID returned by the docker images command.

# %% [markdown]
# `docker run -p 6789:5001 --name mycontainer <imageid>`

# %% [markdown]
# This command starts the latest version of the image named `myimage`. It maps local port 6789 to the port in the container on which the web service is listening (5001). It also assigns the name mycontainer to the container, which makes the container easier to stop. After the container is started, you can submit requests to http://localhost:6789/score.

# %% [markdown]
# After you create a Dockerfile, you can use package.save() to download the Dockerfile and corresponding artifacts to your local machine. This can only be used if `generate_dockerfile` is set to `True`.

# %%
# package.save("./docker")

# %% [markdown]
# ## Option 2: Deploy to Compute Target

# %% [markdown]
# ### Option 1: Azure Container Instances

# %%
# aci_config = AciWebservice.deploy_configuration(cpu_cores=1,
#                                                 memory_gb=1,
#                                                 tags={"data": "Cifar",  "method" : "Pytorch"},
#                                                 description="Predict cifar images with a Pytorch CNN")
# Out:
# 'aci_config = AciWebservice.deploy_configuration(cpu_cores=1, \n                                               memory_gb=1, \n                                               tags={"data": "Cifar",  "method" : "Pytorch"}, \n                                               description="Predict cifar images with a Pytorch CNN")'

# %% [markdown]
# ### Option 2: Azure Kubernetes Service

# %% [markdown]
# #### Option 2.1: Provisioning New AKS Cluster

# %%
# Choose a name for your AKS cluster
aks_name = "my-test-aks"

# Verify that cluster does not exist already
try:
    aks_target = ComputeTarget(workspace=ws, name=aks_name)
    print("Found existing cluster, use it.")
except ComputeTargetException:
    # Use the default configuration (you can also provide parameters to customize this).
    # For example, to create a dev/test cluster, use:
    prov_config = AksCompute.provisioning_configuration(cluster_purpose = AksCompute.ClusterPurpose.DEV_TEST)
    # prov_config = AksCompute.provisioning_configuration()

    # Example configuration to use an existing virtual network
    # prov_config.vnet_name = "mynetwork"
    # prov_config.vnet_resourcegroup_name = "mygroup"
    # prov_config.subnet_name = "default"
    # prov_config.service_cidr = "10.0.0.0/16"
    # prov_config.dns_service_ip = "10.0.0.10"
    # prov_config.docker_bridge_cidr = "172.17.0.1/16"

    # Create the cluster
    aks_target = ComputeTarget.create(workspace = ws,
                                      name = aks_name,
                                      provisioning_configuration = prov_config)

if aks_target.get_status() != "Succeeded":
    aks_target.wait_for_completion(show_output=True)
# Out:
# Creating..
# FailedProvisioning operation finished, operation "Failed"
# ---------------------------------------------------------------------------
# ComputeTargetException                    Traceback (most recent call last)
# <ipython-input-25-044c83ffe22c> in <module>
#      26
#      27 if aks_target.get_status() != "Succeeded":
# ---> 28     aks_target.wait_for_completion(show_output=True)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/core/compute/compute.py in wait_for_completion(self, show_output, is_delete_operation)
#     573                                              'Current state is {}'.format(self.provisioning_state))
#     574             else:
# --> 575                 raise e
#     576
#     577     def _wait_for_completion(self, show_output):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/core/compute/compute.py in wait_for_completion(self, show_output, is_delete_operation)
#     566                                              'state, current provisioning state: {}\n'
#     567                                              'Provisioning operation error:\n'
# --> 568                                              '{}'.format(self.provisioning_state, error_response))
#     569         except ComputeTargetException as e:
#     570             if e.message == 'No operation endpoint':
#
# ComputeTargetException: ComputeTargetException:
# 	Message: Compute object provisioning polling reached non-successful terminal state, current provisioning state: Failed
# Provisioning operation error:
# {'code': 'InvalidTemplateDeployment', 'message': "The template deployment '43e4aff2-41db-4acc-a8c9-12aec0bf6418' is not valid according to the validation procedure. The tracking id is '54694bd8-1f8d-4c3c-bc20-98d3105fcc9b'. See inner errors for details.", 'details': [{'code': 'InvalidParameter', 'message': 'Provisioning of resource(s) for container service my-test-aksa7061699d9 in resource group rg-msaiempmodeltrainingamlwsf1aplateng-dev-westeurope-01 failed. Message: {\n  "code": "InvalidParameter",\n  "message": "The length of the node resource group name is too long. The maximum length is 80 and the length of the value provided is 92. Please see https://aka.ms/aks-naming-rules for more details.",\n  "target": "name"\n }. Details: '}]}
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Compute object provisioning polling reached non-successful terminal state, current provisioning state: Failed\nProvisioning operation error:\n{'code': 'InvalidTemplateDeployment', 'message': \"The template deployment '43e4aff2-41db-4acc-a8c9-12aec0bf6418' is not valid according to the validation procedure. The tracking id is '54694bd8-1f8d-4c3c-bc20-98d3105fcc9b'. See inner errors for details.\", 'details': [{'code': 'InvalidParameter', 'message': 'Provisioning of resource(s) for container service my-test-aksa7061699d9 in resource group rg-msaiempmodeltrainingamlwsf1aplateng-dev-westeurope-01 failed. Message: {\\n  \"code\": \"InvalidParameter\",\\n  \"message\": \"The length of the node resource group name is too long. The maximum length is 80 and the length of the value provided is 92. Please see https://aka.ms/aks-naming-rules for more details.\",\\n  \"target\": \"name\"\\n }. Details: '}]}"
#     }
# }

# %% [markdown]
# ## Option 2: Attaching

# %%
aks_target_name = "newaksinf04"
aks_target = AksCompute(workspace=ws, name=aks_target_name)
print(aks_target.get_status())
# Out:
# Succeeded

# %%
aks_service_name ="newendpoint06"
aks_config = AksWebservice.deploy_configuration(cpu_cores = 1, memory_gb = 4)

# %%
# %%time
aks_service = Model.deploy(workspace=ws,
                           name=aks_service_name,
                           models=[model],
                           inference_config=inference_config,
                           deployment_config=aks_config,
                           deployment_target=aks_target)

aks_service.wait_for_deployment(show_output = True)
print(aks_service.state)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running..
# Failed
# ERROR - Service deployment polling reached non-successful terminal state, current service state: Failed
# Operation ID: 0d9dbf05-cd43-48fa-8d89-be54d7536287
# More information can be found using '.get_logs()'
# Error:
# {
#   "code": "Forbidden",
#   "statusCode": 403,
#   "message": "Forbidden",
#   "details": [
#     {
#       "code": "KubernetesError",
#       "message": "Kubernetes error: Forbidden. Reason: {\"kind\":\"Status\",\"apiVersion\":\"v1\",\"metadata\":{},\"status\":\"Failure\",\"message\":\"configmaps \\\"newendpoint06c6f00dadb1d747b6aafb199b6e6ea60c-config\\\" is forbidden: unable to create new content in namespace azureml-amls-msai-f1a-dev-westeurope-01 because it is being terminated\",\"reason\":\"Forbidden\",\"details\":{\"name\":\"newendpoint06c6f00dadb1d747b6aafb199b6e6ea60c-config\",\"kind\":\"configmaps\",\"causes\":[{\"reason\":\"NamespaceTerminating\",\"message\":\"namespace azureml-amls-msai-f1a-dev-westeurope-01 is being terminated\",\"field\":\"metadata.namespace\"}]},\"code\":403}\n"
#     }
#   ]
# }
# ---------------------------------------------------------------------------
# WebserviceException                       Traceback (most recent call last)
# <timed exec> in <module>
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/core/webservice/webservice.py in wait_for_deployment(self, show_output, timeout_sec)
#     810                                           'Error:\n'
#     811                                           '{}'.format(self.state, self._operation_endpoint.split('/')[-1],
# --> 812                                                       logs_response, error_response), logger=module_logger)
#     813             print('{} service creation operation finished, operation "{}"'.format(self._webservice_type,
#     814                                                                                   operation_state))
#
# WebserviceException: WebserviceException:
# 	Message: Service deployment polling reached non-successful terminal state, current service state: Failed
# Operation ID: 0d9dbf05-cd43-48fa-8d89-be54d7536287
# More information can be found using '.get_logs()'
# Error:
# {
#   "code": "Forbidden",
#   "statusCode": 403,
#   "message": "Forbidden",
#   "details": [
#     {
#       "code": "KubernetesError",
#       "message": "Kubernetes error: Forbidden. Reason: {\"kind\":\"Status\",\"apiVersion\":\"v1\",\"metadata\":{},\"status\":\"Failure\",\"message\":\"configmaps \\\"newendpoint06c6f00dadb1d747b6aafb199b6e6ea60c-config\\\" is forbidden: unable to create new content in namespace azureml-amls-msai-f1a-dev-westeurope-01 because it is being terminated\",\"reason\":\"Forbidden\",\"details\":{\"name\":\"newendpoint06c6f00dadb1d747b6aafb199b6e6ea60c-config\",\"kind\":\"configmaps\",\"causes\":[{\"reason\":\"NamespaceTerminating\",\"message\":\"namespace azureml-amls-msai-f1a-dev-westeurope-01 is being terminated\",\"field\":\"metadata.namespace\"}]},\"code\":403}\n"
#     }
#   ]
# }
# 	InnerException None
# 	ErrorResponse
# {
#     "error": {
#         "message": "Service deployment polling reached non-successful terminal state, current service state: Failed\nOperation ID: 0d9dbf05-cd43-48fa-8d89-be54d7536287\nMore information can be found using '.get_logs()'\nError:\n{\n  \"code\": \"Forbidden\",\n  \"statusCode\": 403,\n  \"message\": \"Forbidden\",\n  \"details\": [\n    {\n      \"code\": \"KubernetesError\",\n      \"message\": \"Kubernetes error: Forbidden. Reason: {\\\"kind\\\":\\\"Status\\\",\\\"apiVersion\\\":\\\"v1\\\",\\\"metadata\\\":{},\\\"status\\\":\\\"Failure\\\",\\\"message\\\":\\\"configmaps \\\\\\\"newendpoint06c6f00dadb1d747b6aafb199b6e6ea60c-config\\\\\\\" is forbidden: unable to create new content in namespace azureml-amls-msai-f1a-dev-westeurope-01 because it is being terminated\\\",\\\"reason\\\":\\\"Forbidden\\\",\\\"details\\\":{\\\"name\\\":\\\"newendpoint06c6f00dadb1d747b6aafb199b6e6ea60c-config\\\",\\\"kind\\\":\\\"configmaps\\\",\\\"causes\\\":[{\\\"reason\\\":\\\"NamespaceTerminating\\\",\\\"message\\\":\\\"namespace azureml-amls-msai-f1a-dev-westeurope-01 is being terminated\\\",\\\"field\\\":\\\"metadata.namespace\\\"}]},\\\"code\\\":403}\\n\"\n    }\n  ]\n}"
#     }
# }

# %%
# %%time
env = Environment.get(workspace=ws, name="pytorch-aml-env")

inference_config = InferenceConfig(entry_script="deployment/score.py",
                                   environment=env)

service_name = "Cifar-pytorch-service" + str(uuid.uuid4())[:4]

service = Model.deploy(workspace=ws, 
                       name=service_name, 
                       models=[model], 
                       inference_config=inference_config, 
                       deployment_config=aci_config)

service.wait_for_deployment(show_output=True)

# %%
print(service.scoring_uri)

# %% [markdown]
# # Test the model

# %%
from utils import load_data
import os
import glob

data_folder = os.path.join(os.getcwd(), 'data')
# note we also shrink the intensity values (X) from 0-255 to 0-1. This helps the neural network converge faster
X_test = load_data(glob.glob(os.path.join(data_folder,"**/t10k-images-idx3-ubyte.gz"), recursive=True)[0], False) / 255.0
y_test = load_data(glob.glob(os.path.join(data_folder,"**/t10k-labels-idx1-ubyte.gz"), recursive=True)[0], True).reshape(-1)

# %%
import os
from azureml.core import Dataset
from azureml.opendatasets import MNIST

data_folder = os.path.join(os.getcwd(), 'data')
os.makedirs(data_folder, exist_ok=True)

mnist_file_dataset = MNIST.get_file_dataset()
mnist_file_dataset.download(data_folder, overwrite=True)

# %%
import json
test = json.dumps({"data": X_test.tolist()})
test = bytes(test, encoding='utf8')
y_hat = service.run(input_data=test)

# %%
from sklearn.metrics import confusion_matrix

conf_mx = confusion_matrix(y_test, y_hat)
print(conf_mx)
print('Overall accuracy:', np.average(y_hat == y_test))

# %%
# normalize the diagonal cells so that they don't overpower the rest of the cells when visualized
row_sums = conf_mx.sum(axis=1, keepdims=True)
norm_conf_mx = conf_mx / row_sums
np.fill_diagonal(norm_conf_mx, 0)

fig = plt.figure(figsize=(8,5))
ax = fig.add_subplot(111)
cax = ax.matshow(norm_conf_mx, cmap=plt.cm.bone)
ticks = np.arange(0, 10, 1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(ticks)
ax.set_yticklabels(ticks)
fig.colorbar(cax)
plt.ylabel('true labels', fontsize=14)
plt.xlabel('predicted values', fontsize=14)
plt.savefig('conf.png')
plt.show()

# %%
import json

# find 30 random samples from test set
n = 30
sample_indices = np.random.permutation(X_test.shape[0])[0:n]

test_samples = json.dumps({"data": X_test[sample_indices].tolist()})
test_samples = bytes(test_samples, encoding='utf8')

# predict using the deployed model
result = service.run(input_data=test_samples)

# compare actual value vs. the predicted values:
i = 0
plt.figure(figsize = (20, 1))

for s in sample_indices:
    plt.subplot(1, n, i + 1)
    plt.axhline('')
    plt.axvline('')
    
    # use different color for misclassified sample
    font_color = 'red' if y_test[s] != result[i] else 'black'
    clr_map = plt.cm.gray if y_test[s] != result[i] else plt.cm.Greys
    
    plt.text(x=10, y =-10, s=result[i], fontsize=18, color=font_color)
    plt.imshow(X_test[s].reshape(28, 28), cmap=clr_map)
    
    i = i + 1
plt.show()

# %%
import requests

# send a random row from the test set to score
random_index = np.random.randint(0, len(X_test)-1)
input_data = "{\"data\": [" + str(list(X_test[random_index])) + "]}"

headers = {'Content-Type':'application/json'}

# for AKS deployment you'd need to the service key in the header as well
# api_key = service.get_key()
# headers = {'Content-Type':'application/json',  'Authorization':('Bearer '+ api_key)} 

resp = requests.post(service.scoring_uri, input_data, headers=headers)

print("POST to url", service.scoring_uri)
#print("input data:", input_data)
print("label:", y_test[random_index])
print("prediction:", resp.text)

# %%
service.delete()
