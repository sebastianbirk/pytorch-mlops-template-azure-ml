# %% [markdown]
# # TABLE OF CONTENTS:
# ---
# * [Notebook Summary](#Notebook-Summary)
# * [Setup](#Setup)
#     * [Notebook Parameters](#Notebook-Parameters)
#     * [Connect to Workspace](#Connect-to-Workspace)
# * [Retrieve the Registered Model](#Retrieve-the-Registered-Model)
# * [Retrieve the Registered Inference Environment](#Retrieve-the-Registered-Inference-Environment)
# * [Inference Artifacts & Configuration](#Inference-Artifacts-&-Configuration)
# * [Model Deployment (Local)](#Model-Deployment-(Local))
#     * [Initial Local Deployment](#Initial-Local-Deployment)
#     * [Update Local Deployment](#Update-Local-Deployment)
#     * [Local Webservice Testing](#Local-Webservice-Testing)
#     * [Local Webservice Clean Up](#Local-Webservice-Clean-Up)
# * [Model Deployment (Compute Target)](#Model-Deployment-(Compute-Target))
#     * [Option 1: Deploy to ACI (Azure Container Instances)](#Option-1:-Deploy-to-ACI-(Azure-Container-Instances))
#         * [ACI Webservice Testing](#ACI-Webservice-Testing)
#         * [ACI Webservice Clean Up](#ACI-Webservice-Clean-Up)
#     * [Option 2: Deploy to AKS (Azure Kubernetes Service)](#Option-2:-Deploy-to-AKS-(Azure-Kubernetes-Service))
#         * [AKS Webservice Testing](#AKS-Webservice-Testing)
#         * [AKS Webservice Clean Up](#AKS-Webservice-Clean-Up)
# * [Model Deployment (Docker Image)](#Model-Deployment-(Docker-Image))
#     * [Model Packaging](#Model-Packaging)
#         * [Option 1: Download a Packaged Model](#Option-1:-Download-a-Packaged-Model)
#         * [Option 2: Generate a Dockerfile](#Option-2:-Generate-a-Dockerfile)
#         * [Model Packaging Local Deployment](#Model-Packaging-Local-Deployment)
#         * [Model Packaging Local Webservice Testing](#Model-Packaging-Local-Webservice-Testing)
#         * [Model Packaging Clean Up](#Model-Packaging-Clean-Up)
#     * [Deploy Docker Image to AKS](#Deploy-Docker-Image-to-AKS)
#     * [Test the Deployed Webservice](#Test-the-Deployed-Webservice)
#     * [Model Packaging Webservice Clean Up](#Model-Packaging-Webservice-Clean-Up)
# * [Resource Clean Up](#Resource-Clean-Up)
# ---

# %% [markdown]
# # Notebook Summary

# %% [markdown]
# In this notebook, the Azure Machine Learning (AML) model that has been trained in the `02_model_training` notebook and evaluated in the `03_model_evaluation` notebook will be deployed. It is shown how the model can be deployed to different compute targets using different methods of the Azure Machine Learning (AML) Python SDK, one of them in combination with the Kubernetes CLI. The notebook will cover local deployment to the AML Compute Instance (CI), which is useful for debugging purposes, as well as deployment to Azure Container Instances (ACI) and Azure Kubernetes Service (AKS). ACI is a great solution for testing and debugging the MLOps workflow. For scalable production deployments, AKS should be used instead. In all of these cases, the model will be deployed as a web service, specifically as a Docker image that encapsulates the scoring logic and the model itself.

# %% [markdown]
# # Setup

# %% [markdown]
# Append parent directory to sys path to be able to import created modules from src directory.

# %%
import sys
sys.path.append(os.path.dirname(os.path.abspath("")))

# %% [markdown]
# Automatically reload modules when changes are made.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Import libraries and modules.

# %%
# Import libraries
import json
import matplotlib.pyplot as plt
import numpy as np
import requests
import torch
import torchvision
import torchvision.transforms as transforms
from azureml.core import Environment, Workspace
from azureml.core.compute import AksCompute, ComputeTarget
from azureml.core.compute_target import ComputeTargetException
from azureml.core.model import InferenceConfig, Model
from azureml.core.webservice import AciWebservice, AksWebservice, LocalWebservice, Webservice
from PIL import Image

# Import created modules
from src.utils import preprocess_image

print(f"azureml.core version: {azureml.core.VERSION}")
# Out:
# azureml.core version: 1.20.0

# %% [markdown]
# ### Notebook Parameters

# %% [markdown]
# Specify the notebook parameters which are used in the source code below.

# %%
# Specify the model name
model_name = "dog_clf_model"

# Specify the model version
model_version = None # None means latest

# Specify the inferencing environment name
env_name = "dogs_clf_deploy_env"

# Specify the local model path
local_model_path = "../outputs/dog_clf_model.pt"

# Specify the inference entry script path
inference_entry_script_path = "../src/deployment/score.py"

# Specify path to an example of model input data
data_example_path = "../data/val/n02085620-Chihuahua/n02085620_1152.jpg"

# Specify the local webservice name for local deployment
local_service_name = "dog-classification-service-local"

# Specify the ACI webservice name for ACI deployment
aci_service_name = "dog-classification-service-aci"

# Specify the webservice tags
service_tags = {"data": "dogs", "method": "transfer learning", "framework": "PyTorch"}

# Specify the webservice description
service_description = "Classify dogs using transfer learning with PyTorch"

# Specify the AKS cluster name
aks_name = "aks-cluster" 

# Specify the AKS webservice name for AKS deployment
aks_service_name = "dog-classification-service-aks"

# Specify the image name and image tag for model packaging 
image_name = "inference/dog_clf_model"
image_label = "1.0.0" # image tag

# %% [markdown]
# ### Connect to Workspace

# %% [markdown]
# In order to connect and communicate with the Azure Machine Learning (AML) workspace, a workspace object needs to be instantiated using the Azure ML SDK.

# %%
# Connect to the AML workspace with interactive authentication
ws = Workspace.from_config()

# %% [markdown]
# # Retrieve the Registered Model

# %% [markdown]
# Retrieve the registered model from the workspace.

# %%
model = Model(workspace=ws, name=model_name, version=model_version)

# %% [markdown]
# # Retrieve the Registered Inference Environment

# %% [markdown]
# Retrieve the inferencing environment from the workspace.

# %%
env = Environment.get(workspace=ws, name=env_name)

# %% [markdown]
# # Inference Artifacts & Configuration

# %% [markdown]
# A deployment folder for artifacts that are required for inference has been created (`<PROJECT_ROOT>/src/deployment`).
#
# This folder contains the scoring script, called score.py, which has to be created to enable inference and is used by the web service call to show how to use the model.
#
# Two functions are required in the scoring script:
# 1. an `init` function that executes once when the service starts - in this function you normally get the model from the model registry and set global variables
# 1. a `run(data)` function that executes each time a call is made to the service. In this function, you normally deserialize the json, run a prediction and output the predicted result.
#
# In addition, an inference configuration needs to be created which bundles the inference environment with the entry script and the source directory if multiple files are required for inference.

# %%
# Create Inference Config
inference_config = InferenceConfig(entry_script=inference_entry_script_path,
                                   environment=env)

# %% [markdown]
# # Model Deployment (Local)

# %% [markdown]
# Scenarios for local deployment include:
#
# * Quickly iterating data, scripts, and models early in a project.
# * Debugging and troubleshooting in later stages.
# * Final deployment on user-managed hardware.

# %% [markdown]
# ### Initial Local Deployment

# %% [markdown]
# Using Docker to deploy your model as a web service is the most common option (cell below). The other alternative is to run your code directly by using local Python scripts (load the PyTorch model file and use it for scoring similar as is done in the `03_model_evalation` notebook). For more info on this option check [here](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-local).

# %%
deployment_config = LocalWebservice.deploy_configuration(port=6789)

local_service = Model.deploy(workspace=ws,
                             name=local_service_name,
                             models=[model],
                             inference_config=inference_config,
                             deployment_config = deployment_config)

local_service.wait_for_deployment(show_output=True)
# Out:
# Downloading model dog_clf_model:1 to /tmp/azureml_xdv4y_c8/dog_clf_model/1
# Generating Docker build context.
# 2021/06/28 18:06:23 Downloading source code...
# 2021/06/28 18:06:24 Finished downloading source code
# 2021/06/28 18:06:25 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/06/28 18:06:25 Successfully set up Docker network: acb_default_network
# 2021/06/28 18:06:25 Setting up Docker configuration...
# 2021/06/28 18:06:26 Successfully set up Docker configuration
# 2021/06/28 18:06:26 Logging in to registry: 4d3602983f8547aa8deaeb9718806017.azurecr.io
# 2021/06/28 18:06:27 Successfully logged into 4d3602983f8547aa8deaeb9718806017.azurecr.io
# 2021/06/28 18:06:27 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/06/28 18:06:27 Scanning for dependencies...
# 2021/06/28 18:06:28 Successfully scanned dependencies
# 2021/06/28 18:06:28 Launching container with name: acb_step_0
# Sending build context to Docker daemon  67.07kB
# Step 1/25 : FROM mcr.microsoft.com/azureml/o16n-base/python-assets:latest AS inferencing-assets
# latest: Pulling from azureml/o16n-base/python-assets
# fa2459e9dafe: Pulling fs layer
# fa2459e9dafe: Verifying Checksum
# fa2459e9dafe: Download complete
# fa2459e9dafe: Pull complete
# Digest: sha256:7da855b76a4790e83c20b1f1d4cc0dd449cfdb4c9ced1c02fb2f8cf7f7456d1d
# Status: Downloaded newer image for mcr.microsoft.com/azureml/o16n-base/python-assets:latest
#  ---> f793d297180d
# Step 2/25 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1@sha256:c9965db4542714161cec2bb1c7a118e9919a88ce8915e506846e8a831bf130ed
# mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1@sha256:c9965db4542714161cec2bb1c7a118e9919a88ce8915e506846e8a831bf130ed: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# 2c11b7cecaa5: Already exists
# 04637fa56252: Already exists
# d6e6af23a0f3: Already exists
# b4a424de92ad: Already exists
# 3e5d9ee64909: Pulling fs layer
# 3a846111ff22: Pulling fs layer
# 93a5020c6e19: Pulling fs layer
# 360b353e68fd: Pulling fs layer
# ea4e2e1810f8: Pulling fs layer
# def12cf7de15: Pulling fs layer
# 3ae6adfbdb11: Pulling fs layer
# 2a21fbf2232e: Pulling fs layer
# 360b353e68fd: Waiting
# ea4e2e1810f8: Waiting
# def12cf7de15: Waiting
# 3ae6adfbdb11: Waiting
# 2a21fbf2232e: Waiting
# 93a5020c6e19: Verifying Checksum
# 93a5020c6e19: Download complete
# 3a846111ff22: Verifying Checksum
# 3a846111ff22: Download complete
# 3e5d9ee64909: Verifying Checksum
# 3e5d9ee64909: Download complete
# def12cf7de15: Verifying Checksum
# def12cf7de15: Download complete
# 3ae6adfbdb11: Verifying Checksum
# 3ae6adfbdb11: Download complete
# 2a21fbf2232e: Verifying Checksum
# 2a21fbf2232e: Download complete
# 360b353e68fd: Verifying Checksum
# 360b353e68fd: Download complete
# ea4e2e1810f8: Verifying Checksum
# ea4e2e1810f8: Download complete
# 3e5d9ee64909: Pull complete
# 3a846111ff22: Pull complete
# 93a5020c6e19: Pull complete
# 360b353e68fd: Pull complete
# ea4e2e1810f8: Pull complete
# def12cf7de15: Pull complete
# 3ae6adfbdb11: Pull complete
# 2a21fbf2232e: Pull complete
# Digest: sha256:c9965db4542714161cec2bb1c7a118e9919a88ce8915e506846e8a831bf130ed
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20201113.v1@sha256:c9965db4542714161cec2bb1c7a118e9919a88ce8915e506846e8a831bf130ed
#  ---> aec5c40a18a2
# Step 3/25 : USER root
#  ---> Running in a28fb3f1d00f
# Removing intermediate container a28fb3f1d00f
#  ---> 75d316e3bb52
# Step 4/25 : RUN mkdir -p $HOME/.cache
#  ---> Running in 3081eb246701
# Removing intermediate container 3081eb246701
#  ---> 5afa3380c2c7
# Step 5/25 : WORKDIR /
#  ---> Running in 5af74dcaaa40
# Removing intermediate container 5af74dcaaa40
#  ---> 834745404b04
# Step 6/25 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> c32a14b19fdd
# Step 7/25 : RUN true
#  ---> Running in f8a17ab229cb
# Removing intermediate container f8a17ab229cb
#  ---> ae84e16ce579
# Step 8/25 : COPY --from=inferencing-assets /artifacts /var/
#  ---> 689accaad490
# Step 9/25 : RUN /var/requirements/install_system_requirements.sh
#  ---> Running in 22fbeb6e3ca8
# Get:1 http://ppa.launchpad.net/adiscon/v8-stable/ubuntu xenial InRelease [17.5 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu xenial InRelease
# Get:3 http://archive.ubuntu.com/ubuntu xenial-updates InRelease [109 kB]
# Get:4 https://packages.microsoft.com/ubuntu/16.04/prod xenial InRelease [4003 B]
# Get:5 http://security.ubuntu.com/ubuntu xenial-security InRelease [109 kB]
# Get:6 http://archive.ubuntu.com/ubuntu xenial-backports InRelease [107 kB]
# Get:7 http://ppa.launchpad.net/adiscon/v8-stable/ubuntu xenial/main amd64 Packages [8494 B]
# Get:8 https://packages.microsoft.com/ubuntu/16.04/prod xenial/main amd64 Packages [233 kB]
# Get:9 http://archive.ubuntu.com/ubuntu xenial-updates/main amd64 Packages [2559 kB]
# Get:10 http://archive.ubuntu.com/ubuntu xenial-updates/universe amd64 Packages [1544 kB]
# Get:11 http://archive.ubuntu.com/ubuntu xenial-updates/multiverse amd64 Packages [26.2 kB]
# Get:12 http://archive.ubuntu.com/ubuntu xenial-backports/universe amd64 Packages [12.7 kB]
# Get:13 http://security.ubuntu.com/ubuntu xenial-security/main amd64 Packages [2051 kB]
# Get:14 http://security.ubuntu.com/ubuntu xenial-security/universe amd64 Packages [984 kB]
# Get:15 http://security.ubuntu.com/ubuntu xenial-security/multiverse amd64 Packages [8820 B]
# Fetched 7774 kB in 1s (4208 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   software-properties-common
# 0 upgraded, 1 newly installed, 0 to remove and 51 not upgraded.
# Need to get 9504 B of archives.
# After this operation, 193 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu xenial-updates/main amd64 software-properties-common all 0.96.20.10 [9504 B]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 9504 B in 0s (75.7 kB/s)
# Selecting previously unselected package software-properties-common.
# (Reading database ... 17913 files and directories currently installed.)
# Preparing to unpack .../software-properties-common_0.96.20.10_all.deb ...
# Unpacking software-properties-common (0.96.20.10) ...
# Processing triggers for dbus (1.10.6-1ubuntu3.6) ...
# Setting up software-properties-common (0.96.20.10) ...
# Processing triggers for dbus (1.10.6-1ubuntu3.6) ...
# gpg: keyring `/tmp/tmpxjg4hfid/secring.gpg' created
# gpg: keyring `/tmp/tmpxjg4hfid/pubring.gpg' created
# gpg: requesting key 5234BF2B from hkp server keyserver.ubuntu.com
# gpg: /tmp/tmpxjg4hfid/trustdb.gpg: trustdb created
# gpg: key 5234BF2B: public key "Launchpad PPA for Adiscon" imported
# gpg: Total number processed: 1
# gpg:               imported: 1  (RSA: 1)
# OK
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following packages were automatically installed and are no longer required:
#   dh-python distro-info-data file gir1.2-glib-2.0 iso-codes libapt-inst2.0
#   libdbus-glib-1-2 libgirepository-1.0-1 libmagic1 libmpdec2 libpython3-stdlib
#   libpython3.5-minimal libpython3.5-stdlib lsb-release mime-support
#   powermgmt-base python-apt-common python3 python3-apt python3-dbus python3-gi
#   python3-minimal python3-pycurl python3-software-properties python3.5
#   python3.5-minimal unattended-upgrades
# Use 'apt autoremove' to remove them.
# The following packages will be REMOVED:
#   software-properties-common*
# 0 upgraded, 0 newly installed, 1 to remove and 51 not upgraded.
# After this operation, 193 kB disk space will be freed.
# (Reading database ... 17928 files and directories currently installed.)
# Removing software-properties-common (0.96.20.10) ...
# Purging configuration files for software-properties-common (0.96.20.10) ...
# Processing triggers for dbus (1.10.6-1ubuntu3.6) ...
# Hit:1 http://ppa.launchpad.net/adiscon/v8-stable/ubuntu xenial InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu xenial InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu xenial-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu xenial-backports InRelease
# Hit:5 https://packages.microsoft.com/ubuntu/16.04/prod xenial InRelease
# Hit:6 http://security.ubuntu.com/ubuntu xenial-security InRelease
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libunwind8 is already the newest version (1.1-4.1).
# liblttng-ust0 is already the newest version (2.7.1-1).
# libxml++2.6-2v5 is already the newest version (2.40.1-1).
# runit is already the newest version (2.1.2-3ubuntu1).
# psmisc is already the newest version (22.21-2.1ubuntu0.1).
# wget is already the newest version (1.17.1-1ubuntu1.5).
# nginx-light is already the newest version (1.10.3-0ubuntu0.16.04.5).
# The following packages were automatically installed and are no longer required:
#   dh-python distro-info-data file gir1.2-glib-2.0 iso-codes libapt-inst2.0
#   libdbus-glib-1-2 libgirepository-1.0-1 libmagic1 libmpdec2 libpython3-stdlib
#   libpython3.5-minimal libpython3.5-stdlib lsb-release mime-support
#   powermgmt-base python-apt-common python3 python3-apt python3-dbus python3-gi
#   python3-minimal python3-pycurl python3-software-properties python3.5
#   python3.5-minimal unattended-upgrades
# Use 'apt autoremove' to remove them.
# Suggested packages:
#   rsyslog-mysql | rsyslog-pgsql rsyslog-doc rsyslog-relp rsyslog-elasticsearch
#   rsyslog-mmjsonparse rsyslog-imptcp rsyslog-gnutls rsyslog-openssl
#   rsyslog-udpspoof rsyslog-mmrm1stspace rsyslog-mmutf8fix rsyslog-kafka
#   rsyslog-omstdout apparmor zip
# The following packages will be upgraded:
#   libcurl3 rsyslog unzip
# 3 upgraded, 0 newly installed, 0 to remove and 48 not upgraded.
# Need to get 1008 kB of archives.
# After this operation, 35.8 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu xenial-updates/main amd64 libcurl3 amd64 7.47.0-1ubuntu2.19 [192 kB]
# Get:2 http://archive.ubuntu.com/ubuntu xenial-updates/main amd64 unzip amd64 6.0-20ubuntu1.1 [162 kB]
# Get:3 http://ppa.launchpad.net/adiscon/v8-stable/ubuntu xenial/main amd64 rsyslog amd64 8.2106.0-0adiscon1xenial1 [655 kB]
# debconf: delaying package configuration, since apt-utils is not installed
# Fetched 1008 kB in 0s (5623 kB/s)
# (Reading database ... 17913 files and directories currently installed.)
# Preparing to unpack .../rsyslog_8.2106.0-0adiscon1xenial1_amd64.deb ...
# Unpacking rsyslog (8.2106.0-0adiscon1xenial1) over (8.2010.0-0adiscon1xenial1) ...
# Preparing to unpack .../libcurl3_7.47.0-1ubuntu2.19_amd64.deb ...
# Unpacking libcurl3:amd64 (7.47.0-1ubuntu2.19) over (7.47.0-1ubuntu2.16) ...
# Preparing to unpack .../unzip_6.0-20ubuntu1.1_amd64.deb ...
# Unpacking unzip (6.0-20ubuntu1.1) over (6.0-20ubuntu1) ...
# Processing triggers for systemd (229-4ubuntu21.29) ...
# Processing triggers for libc-bin (2.23-0ubuntu11.2) ...
# Processing triggers for mime-support (3.59ubuntu1) ...
# Setting up rsyslog (8.2106.0-0adiscon1xenial1) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of restart.
# Setting up libcurl3:amd64 (7.47.0-1ubuntu2.19) ...
# Setting up unzip (6.0-20ubuntu1.1) ...
# Processing triggers for libc-bin (2.23-0ubuntu11.2) ...
# Removing intermediate container 22fbeb6e3ca8
#  ---> 8d965c90f16f
# Step 10/25 : RUN cp /var/configuration/rsyslog.conf /etc/rsyslog.conf && cp /var/configuration/nginx.conf /etc/nginx/sites-available/app && ln -sf /etc/nginx/sites-available/app /etc/nginx/sites-enabled/app && rm -f /etc/nginx/sites-enabled/default
#  ---> Running in 4a1bbc18671c
# Removing intermediate container 4a1bbc18671c
#  ---> 49cd9b722e51
# Step 11/25 : ENV SVDIR=/var/runit
#  ---> Running in a3419601d5ce
# Removing intermediate container a3419601d5ce
#  ---> c195466424aa
# Step 12/25 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in b8f416e04133
# Removing intermediate container b8f416e04133
#  ---> 292bf99d4723
# Step 13/25 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 10f0b1d74f2d
# Step 14/25 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_b090681661c04b45aeaa579d18649daf -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 2540d406ca3e
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
# torchvision-0.8.1    | 17.8 MB   | ########## | 100%
# openjpeg-2.4.0       | 444 KB    | ########## | 100%
# mkl-2021.2.0         | 223.7 MB  | #########6 |  97%
# mkl-2021.2.0         | 223.7 MB  | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# lcms2-2.12           | 443 KB    | ########## | 100%
# lerc-2.2.1           | 213 KB    | ########## | 100%
# libtiff-4.3.0        | 668 KB    | ########## | 100%
# setuptools-49.6.0    | 947 KB    | ########## | 100%
# pytorch-1.7.0        | 575.2 MB  | #######2   |  72%
# pytorch-1.7.0        | 575.2 MB  | #########9 | 100%
# pytorch-1.7.0        | 575.2 MB  | ########## | 100%
# libstdcxx-ng-9.3.0   | 4.0 MB    | ########## | 100%
# zlib-1.2.11          | 106 KB    | ########## | 100%
# sqlite-3.28.0        | 1.9 MB    | ########## | 100%
# libpng-1.6.37        | 306 KB    | ########## | 100%
# libcblas-3.9.0       | 11 KB     | ########## | 100%
# cudatoolkit-10.2.89  | 449.7 MB  | #########9 |  99%
# cudatoolkit-10.2.89  | 449.7 MB  | ########## | 100%
# blas-2.109           | 12 KB     | ########## | 100%
# zstd-1.5.0           | 490 KB    | ########## | 100%
# ca-certificates-2021 | 136 KB    | ########## | 100%
# jpeg-9d              | 264 KB    | ########## | 100%
# libgfortran5-9.3.0   | 2.0 MB    | ########## | 100%
# libffi-3.2.1         | 47 KB     | ########## | 100%
# mkl-include-2021.2.0 | 665 KB    | ########## | 100%
# freetype-2.10.4      | 890 KB    | ########## | 100%
# tbb-2021.2.0         | 2.1 MB    | ########## | 100%
# llvm-openmp-11.1.0   | 4.7 MB    | ########## | 100%
# blas-devel-3.9.0     | 11 KB     | ########## | 100%
# scipy-1.6.0          | 20.5 MB   | ########## | 100%
# ninja-1.10.2         | 2.4 MB    | ########## | 100%
# olefile-0.46         | 32 KB     | ########## | 100%
# libdeflate-1.7       | 67 KB     | ########## | 100%
# libgcc-ng-9.3.0      | 7.8 MB    | ########## | 100%
# readline-7.0         | 391 KB    | ########## | 100%
# libuv-1.41.0         | 1.0 MB    | ########## | 100%
# certifi-2021.5.30    | 141 KB    | ########## | 100%
# pillow-8.2.0         | 684 KB    | ########## | 100%
# lz4-c-1.9.3          | 179 KB    | ########## | 100%
# libwebp-base-1.2.0   | 815 KB    | ########## | 100%
# liblapacke-3.9.0     | 11 KB     | ########## | 100%
# _openmp_mutex-4.5    | 5 KB      | ########## | 100%
# typing_extensions-3. | 28 KB     | ########## | 100%
# joblib-0.13.2        | 180 KB    | ########## | 100%
# bzip2-1.0.8          | 484 KB    | ########## | 100%
# libblas-3.9.0        | 12 KB     | ########## | 100%
# libgfortran-ng-9.3.0 | 22 KB     | ########## | 100%
# python-3.7.1         | 36.4 MB   | ########## | 100%
# pip-21.0.1           | 1.1 MB    | ########## | 100%
# mkl-devel-2021.2.0   | 25 KB     | ########## | 100%
# python_abi-3.7       | 4 KB      | ########## | 100%
# numpy-1.21.0         | 6.1 MB    | ########## | 100%
# liblapack-3.9.0      | 11 KB     | ########## | 100%
# ncurses-6.2          | 985 KB    | ########## | 100%
# xz-5.2.5             | 343 KB    | ########## | 100%
# wheel-0.36.2         | 31 KB     | ########## | 100%
# openssl-1.1.1k       | 2.1 MB    | ########## | 100%
# jbig-2.1             | 43 KB     | ########## | 100%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... b'By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html\n'
# done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_b090681661c04b45aeaa579d18649daf/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.lfg_i2br.requirements.txt']
# Pip subprocess output:
# Collecting azure-cli==2.3.1
#   Downloading azure_cli-2.3.1-py3-none-any.whl (1.5 MB)
# Collecting azureml-core==1.20.0
#   Downloading azureml_core-1.20.0-py3-none-any.whl (2.1 MB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.31.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.31.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-widgets
#   Downloading azureml_widgets-1.31.0-py3-none-any.whl (14.1 MB)
# Collecting scp~=0.13.2
#   Downloading scp-0.13.4-py2.py3-none-any.whl (8.2 kB)
# Collecting azure-mgmt-sqlvirtualmachine~=0.5.0
#   Downloading azure_mgmt_sqlvirtualmachine-0.5.0-py2.py3-none-any.whl (34 kB)
# Collecting azure-mgmt-search~=2.0
#   Downloading azure_mgmt_search-2.1.0-py2.py3-none-any.whl (41 kB)
# Collecting jsondiff==1.2.0
#   Downloading jsondiff-1.2.0.tar.gz (8.0 kB)
# Collecting pyOpenSSL>=17.1.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting azure-mgmt-cosmosdb~=0.12.0
#   Downloading azure_mgmt_cosmosdb-0.12.0-py2.py3-none-any.whl (103 kB)
# Collecting azure-keyvault~=1.1
#   Downloading azure_keyvault-1.1.0-py2.py3-none-any.whl (352 kB)
# Collecting pygments~=2.4
#   Downloading Pygments-2.9.0-py3-none-any.whl (1.0 MB)
# Collecting azure-mgmt-reservations==0.6.0
#   Downloading azure_mgmt_reservations-0.6.0-py2.py3-none-any.whl (33 kB)
# Collecting azure-mgmt-managedservices~=1.0
#   Downloading azure_mgmt_managedservices-1.0.0-py2.py3-none-any.whl (38 kB)
# Collecting azure-mgmt-web~=0.44.0
#   Downloading azure_mgmt_web-0.44.0-py2.py3-none-any.whl (1.0 MB)
# Collecting azure-functions-devops-build~=0.0.22
#   Downloading azure_functions_devops_build-0.0.22-py3-none-any.whl (47 kB)
# Collecting pytz==2019.1
#   Downloading pytz-2019.1-py2.py3-none-any.whl (510 kB)
# Collecting azure-mgmt-containerservice~=9.0.0
#   Downloading azure_mgmt_containerservice-9.0.1-py2.py3-none-any.whl (499 kB)
# Collecting azure-mgmt-network~=10.0.0
#   Downloading azure_mgmt_network-10.0.0-py2.py3-none-any.whl (7.6 MB)
# Collecting websocket-client~=0.56.0
#   Downloading websocket_client-0.56.0-py2.py3-none-any.whl (200 kB)
# Collecting azure-cli-nspkg>=2.0.0
#   Downloading azure_cli_nspkg-3.0.4-py3-none-any.whl (1.8 kB)
# Collecting cryptography<3.0.0,>=2.3.1
#   Downloading cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting azure-mgmt-netapp~=0.8.0
#   Downloading azure_mgmt_netapp-0.8.0-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-apimanagement~=0.1.0
#   Downloading azure_mgmt_apimanagement-0.1.0-py2.py3-none-any.whl (542 kB)
# Collecting azure-mgmt-containerinstance~=1.4
#   Downloading azure_mgmt_containerinstance-1.5.0-py2.py3-none-any.whl (96 kB)
# Collecting xmltodict~=0.12
#   Downloading xmltodict-0.12.0-py2.py3-none-any.whl (9.2 kB)
# Collecting azure-mgmt-consumption~=2.0
#   Downloading azure_mgmt_consumption-2.0.0-py2.py3-none-any.whl (46 kB)
# Collecting azure-mgmt-datalake-store~=0.5.0
#   Downloading azure_mgmt_datalake_store-0.5.0-py2.py3-none-any.whl (88 kB)
# Collecting fabric~=2.4
#   Downloading fabric-2.6.0-py2.py3-none-any.whl (53 kB)
# Collecting colorama~=0.4.1
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting azure-mgmt-rdbms~=2.2.0
#   Downloading azure_mgmt_rdbms-2.2.0-py2.py3-none-any.whl (231 kB)
# Collecting azure-mgmt-appconfiguration~=0.4.0
#   Downloading azure_mgmt_appconfiguration-0.4.0-py2.py3-none-any.whl (28 kB)
# Collecting azure-mgmt-maps~=0.1.0
#   Downloading azure_mgmt_maps-0.1.0-py2.py3-none-any.whl (31 kB)
# Collecting azure-mgmt-eventgrid~=2.2
#   Downloading azure_mgmt_eventgrid-2.2.0-py2.py3-none-any.whl (109 kB)
# Collecting azure-batch~=8.0
#   Downloading azure_batch-8.0.0-py2.py3-none-any.whl (227 kB)
# Collecting azure-mgmt-billing~=0.2
#   Downloading azure_mgmt_billing-0.2.0-py2.py3-none-any.whl (25 kB)
# Collecting azure-mgmt-cdn==4.1.0rc1
#   Downloading azure_mgmt_cdn-4.1.0rc1-py2.py3-none-any.whl (73 kB)
# Collecting azure-mgmt-imagebuilder~=0.2.1
#   Downloading azure_mgmt_imagebuilder-0.2.1-py2.py3-none-any.whl (66 kB)
# Collecting azure-mgmt-iotcentral~=3.0.0
#   Downloading azure_mgmt_iotcentral-3.0.0-py2.py3-none-any.whl (18 kB)
# Collecting azure-datalake-store~=0.0.48
#   Downloading azure_datalake_store-0.0.52-py2.py3-none-any.whl (61 kB)
# Collecting azure-storage-blob<2.0.0,>=1.3.1
#   Downloading azure_storage_blob-1.5.0-py2.py3-none-any.whl (75 kB)
# Collecting azure-mgmt-privatedns~=0.1.0
#   Downloading azure_mgmt_privatedns-0.1.0-py2.py3-none-any.whl (44 kB)
# Collecting azure-mgmt-sql~=0.17.0
#   Downloading azure_mgmt_sql-0.17.0-py2.py3-none-any.whl (372 kB)
# Collecting azure-mgmt-media>=1.1.1,~=1.1
#   Downloading azure_mgmt_media-1.1.1-py2.py3-none-any.whl (341 kB)
# Collecting azure-mgmt-recoveryservices~=0.4.0
#   Downloading azure_mgmt_recoveryservices-0.4.0-py2.py3-none-any.whl (77 kB)
# Collecting azure-mgmt-monitor~=0.7.0
#   Downloading azure_mgmt_monitor-0.7.0-py2.py3-none-any.whl (317 kB)
# Collecting knack==0.7.0rc1
#   Downloading knack-0.7.0rc1-py2.py3-none-any.whl (57 kB)
# Collecting azure-mgmt-datamigration~=0.1.0
#   Downloading azure_mgmt_datamigration-0.1.0-py2.py3-none-any.whl (219 kB)
# Collecting azure-mgmt-trafficmanager~=0.51.0
#   Downloading azure_mgmt_trafficmanager-0.51.0-py2.py3-none-any.whl (58 kB)
# Collecting azure-mgmt-loganalytics~=0.2
#   Downloading azure_mgmt_loganalytics-0.7.0-py2.py3-none-any.whl (79 kB)
# Collecting azure-mgmt-policyinsights~=0.4.0
#   Downloading azure_mgmt_policyinsights-0.4.0-py2.py3-none-any.whl (41 kB)
# Collecting azure-mgmt-iothub~=0.11.0
#   Downloading azure_mgmt_iothub-0.11.0-py2.py3-none-any.whl (401 kB)
# Collecting azure-mgmt-containerregistry~=3.0.0rc11
#   Downloading azure_mgmt_containerregistry-3.0.0rc17-py2.py3-none-any.whl (660 kB)
# Collecting six~=1.12
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting azure-loganalytics~=0.1.0
#   Downloading azure_loganalytics-0.1.0-py2.py3-none-any.whl (16 kB)
# Collecting azure-cosmos>=3.0.2,~=3.0
#   Downloading azure_cosmos-3.2.0-py2.py3-none-any.whl (106 kB)
# Collecting azure-mgmt-applicationinsights~=0.1.1
#   Downloading azure_mgmt_applicationinsights-0.1.1-py2.py3-none-any.whl (42 kB)
# Collecting azure-mgmt-msi~=0.2
#   Downloading azure_mgmt_msi-0.2.0-py2.py3-none-any.whl (17 kB)
# Collecting azure-mgmt-eventhub~=3.0.0
#   Downloading azure_mgmt_eventhub-3.0.0-py2.py3-none-any.whl (95 kB)
# Collecting azure-mgmt-hdinsight~=1.4.0
#   Downloading azure_mgmt_hdinsight-1.4.0-py2.py3-none-any.whl (54 kB)
# Collecting azure-mgmt-relay~=0.1.0
#   Downloading azure_mgmt_relay-0.1.0-py2.py3-none-any.whl (36 kB)
# Collecting azure-mgmt-batchai~=2.0
#   Downloading azure_mgmt_batchai-2.0.0-py2.py3-none-any.whl (174 kB)
# Collecting azure-cli-core==2.3.1.*
#   Downloading azure_cli_core-2.3.1-py3-none-any.whl (135 kB)
# Collecting azure-mgmt-deploymentmanager~=0.2.0
#   Downloading azure_mgmt_deploymentmanager-0.2.0-py2.py3-none-any.whl (41 kB)
# Collecting sshtunnel~=0.1.4
#   Downloading sshtunnel-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting azure-mgmt-keyvault~=2.2.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-mgmt-security~=0.1.0
#   Downloading azure_mgmt_security-0.1.0-py2.py3-none-any.whl (144 kB)
# Collecting azure-mgmt-cognitiveservices~=5.0.0
#   Downloading azure_mgmt_cognitiveservices-5.0.0-py2.py3-none-any.whl (31 kB)
# Collecting azure-cli-command-modules-nspkg~=2.0
#   Downloading azure_cli_command_modules_nspkg-2.0.3-py3-none-any.whl (1.9 kB)
# Collecting azure-multiapi-storage~=0.2.4
#   Downloading azure_multiapi_storage-0.2.4-py2.py3-none-any.whl (1.2 MB)
# Collecting azure-mgmt-marketplaceordering~=0.1
#   Downloading azure_mgmt_marketplaceordering-0.2.1-py2.py3-none-any.whl (21 kB)
# Collecting azure-mgmt-redis~=7.0.0rc1
#   Downloading azure_mgmt_redis-7.0.0rc2-py2.py3-none-any.whl (35 kB)
# Collecting pyyaml~=5.2
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Collecting azure-mgmt-dns~=2.1
#   Downloading azure_mgmt_dns-2.1.0-py2.py3-none-any.whl (134 kB)
# Collecting azure-mgmt-datalake-analytics~=0.2.1
#   Downloading azure_mgmt_datalake_analytics-0.2.1-py2.py3-none-any.whl (146 kB)
# Collecting azure-mgmt-recoveryservicesbackup~=0.6.0
#   Downloading azure_mgmt_recoveryservicesbackup-0.6.0-py2.py3-none-any.whl (194 kB)
# Collecting azure-mgmt-storage~=8.0.0
#   Downloading azure_mgmt_storage-8.0.0-py2.py3-none-any.whl (524 kB)
# Collecting azure-mgmt-servicebus~=0.6.0
#   Downloading azure_mgmt_servicebus-0.6.0-py2.py3-none-any.whl (120 kB)
# Collecting azure-mgmt-advisor<3.0.0,>=2.0.1
#   Downloading azure_mgmt_advisor-2.0.1-py2.py3-none-any.whl (34 kB)
# Collecting azure-mgmt-batch~=7.0
#   Downloading azure_mgmt_batch-7.0.0-py2.py3-none-any.whl (81 kB)
# Collecting azure-mgmt-compute~=12.0
#   Downloading azure_mgmt_compute-12.1.0-py2.py3-none-any.whl (1.6 MB)
# Collecting azure-mgmt-servicefabric~=0.4.0
#   Downloading azure_mgmt_servicefabric-0.4.0-py2.py3-none-any.whl (62 kB)
# Collecting azure-cli-telemetry<2.0,>=1.0.2
#   Downloading azure_cli_telemetry-1.0.6-py3-none-any.whl (10 kB)
# Collecting azure-mgmt-botservice~=0.2.0
#   Downloading azure_mgmt_botservice-0.2.0-py2.py3-none-any.whl (109 kB)
# Collecting azure-mgmt-kusto~=0.3.0
#   Downloading azure_mgmt_kusto-0.3.0-py2.py3-none-any.whl (73 kB)
# Collecting azure-mgmt-authorization~=0.52.0
#   Downloading azure_mgmt_authorization-0.52.0-py2.py3-none-any.whl (112 kB)
# Collecting requests~=2.22
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting azure-mgmt-managementgroups~=0.1
#   Downloading azure_mgmt_managementgroups-0.2.0-py2.py3-none-any.whl (59 kB)
# Collecting jsmin~=2.2.2
#   Downloading jsmin-2.2.2.tar.gz (12 kB)
# Collecting urllib3[secure]~=1.18
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# Collecting azure-graphrbac~=0.60.0
#   Downloading azure_graphrbac-0.60.0-py2.py3-none-any.whl (139 kB)
# Collecting mock~=4.0
#   Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Collecting azure-mgmt-resource==8.0.1
#   Downloading azure_mgmt_resource-8.0.1-py2.py3-none-any.whl (758 kB)
# Collecting azure-mgmt-signalr~=0.3.0
#   Downloading azure_mgmt_signalr-0.3.0-py2.py3-none-any.whl (53 kB)
# Collecting azure-mgmt-devtestlabs~=2.2
#   Downloading azure_mgmt_devtestlabs-2.2.0-py2.py3-none-any.whl (194 kB)
# Collecting javaproperties==0.5.1
#   Downloading javaproperties-0.5.1-py2.py3-none-any.whl (19 kB)
# Collecting vsts-cd-manager>=1.0.2,~=1.0.0
#   Downloading vsts-cd-manager-1.0.2.tar.gz (13 kB)
# Collecting azure-mgmt-iothubprovisioningservices~=0.2.0
#   Downloading azure_mgmt_iothubprovisioningservices-0.2.0-py2.py3-none-any.whl (60 kB)
# Collecting paramiko<3.0.0,>=2.0.8
#   Downloading paramiko-2.7.2-py2.py3-none-any.whl (206 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting docker
#   Downloading docker-5.0.0-py2.py3-none-any.whl (146 kB)
# Collecting contextlib2
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.17.10-py3-none-any.whl (108 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting PyJWT<2.0.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting pyOpenSSL>=17.1.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting pkginfo
#   Downloading pkginfo-1.7.0-py2.py3-none-any.whl (25 kB)
# Collecting humanfriendly<9.0,>=4.7
#   Downloading humanfriendly-8.2-py2.py3-none-any.whl (86 kB)
# Collecting argcomplete~=1.8
#   Downloading argcomplete-1.12.3-py2.py3-none-any.whl (38 kB)
# Collecting antlr4-python3-runtime
#   Downloading antlr4-python3-runtime-4.9.2.tar.gz (117 kB)
# Collecting wheel==0.30.0
#   Downloading wheel-0.30.0-py2.py3-none-any.whl (49 kB)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting importlib-metadata<5,>=0.23
#   Downloading importlib_metadata-4.6.0-py3-none-any.whl (17 kB)
# Collecting azure-nspkg>=2.0.0
#   Downloading azure_nspkg-3.0.2-py3-none-any.whl (1.5 kB)
# Collecting applicationinsights<0.12,>=0.11.1
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting portalocker~=1.2
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting cffi
#   Downloading cffi-1.14.5-cp37-cp37m-manylinux1_x86_64.whl (402 kB)
# Collecting vsts
#   Downloading vsts-0.1.25-py3-none-any.whl (2.3 MB)
# Collecting jinja2
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Collecting azure-mgmt-nspkg>=2.0.0
#   Downloading azure_mgmt_nspkg-3.0.2-py3-none-any.whl (1.6 kB)
# Collecting azure-mgmt-datalake-nspkg>=2.0.0
#   Downloading azure_mgmt_datalake_nspkg-3.0.1-py3-none-any.whl (1.7 kB)
# Collecting azure-storage-common~=1.4
#   Downloading azure_storage_common-1.4.2-py2.py3-none-any.whl (47 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting pathlib2
#   Downloading pathlib2-2.3.5-py2.py3-none-any.whl (18 kB)
# Collecting invoke<2.0,>=1.3
#   Downloading invoke-1.5.0-py3-none-any.whl (211 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: typing-extensions>=3.6.4 in /azureml-envs/azureml_b090681661c04b45aeaa579d18649daf/lib/python3.7/site-packages (from importlib-metadata<5,>=0.23->argcomplete~=1.8->azure-cli-core==2.3.1.*->azure-cli==2.3.1->-r /azureml-environment-setup/condaenv.lfg_i2br.requirements.txt (line 1)) (3.10.0.0)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_b090681661c04b45aeaa579d18649daf/lib/python3.7/site-packages (from msrest>=0.5.1->azureml-core==1.20.0->-r /azureml-environment-setup/condaenv.lfg_i2br.requirements.txt (line 2)) (2021.5.30)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting bcrypt>=3.1.3
#   Downloading bcrypt-3.2.0-cp36-abi3-manylinux2010_x86_64.whl (63 kB)
# Collecting pynacl>=1.0.1
#   Downloading PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.4-cp37-cp37m-manylinux1_x86_64.whl (546 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.31.0
#   Downloading azureml_dataset_runtime-1.31.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.30.0-py3-none-any.whl (3.1 kB)
#   Downloading azureml_defaults-1.29.0-py3-none-any.whl (3.1 kB)
#   Downloading azureml_defaults-1.28.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.28.0
#   Downloading azureml_dataset_runtime-1.28.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.27.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.27.0
#   Downloading azureml_dataset_runtime-1.27.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.26.0-py3-none-any.whl (3.1 kB)
#   Downloading azureml_defaults-1.25.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.25.0
#   Downloading azureml_dataset_runtime-1.25.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.24.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.24.0
#   Downloading azureml_dataset_runtime-1.24.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.23.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.23.0
#   Downloading azureml_dataset_runtime-1.23.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.22.0-py3-none-any.whl (3.1 kB)
#   Downloading azureml_defaults-1.21.0-py3-none-any.whl (3.1 kB)
#   Downloading azureml_defaults-1.20.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.20.0
#   Downloading azureml_dataset_runtime-1.20.0-py3-none-any.whl (3.4 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Requirement already satisfied: numpy>=1.13.0 in /azureml-envs/azureml_b090681661c04b45aeaa579d18649daf/lib/python3.7/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.lfg_i2br.requirements.txt (line 3)) (1.21.0)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.2.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (9.9 MB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting click>=5.1
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Collecting azureml-dataprep<2.8.0a,>=2.7.0a
#   Downloading azureml_dataprep-2.7.4-py3-none-any.whl (39.4 MB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp37-cp37m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-rslex<1.6.0a,>=1.5.0dev0
#   Downloading azureml_dataprep_rslex-1.5.0-cp37-cp37m-manylinux2010_x86_64.whl (8.1 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-native<28.0.0,>=27.0.0
#   Downloading azureml_dataprep_native-27.0.0-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.12.0-py2.py3-none-any.whl (66 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.15.0-py2.py3-none-any.whl (138 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp37-cp37m-manylinux2010_x86_64.whl (31 kB)
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
#   Downloading PyJWT-2.0.1-py3-none-any.whl (15 kB)
#   Downloading PyJWT-2.0.0-py3-none-any.whl (15 kB)
# Collecting azureml-train~=1.31.0
#   Downloading azureml_train-1.31.0-py3-none-any.whl (3.3 kB)
# Collecting azureml-train-automl-client~=1.31.0
#   Downloading azureml_train_automl_client-1.31.0-py3-none-any.whl (120 kB)
# Collecting azureml-pipeline~=1.31.0
#   Downloading azureml_pipeline-1.31.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.30.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-train~=1.30.0
#   Downloading azureml_train-1.30.0-py3-none-any.whl (3.3 kB)
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.29.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-train-automl-client~=1.29.0
#   Downloading azureml_train_automl_client-1.29.0-py3-none-any.whl (120 kB)
# Collecting azureml-pipeline~=1.29.0
#   Downloading azureml_pipeline-1.29.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-train~=1.29.0
#   Downloading azureml_train-1.29.0-py3-none-any.whl (3.3 kB)
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.28.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-train-automl-client~=1.28.0
#   Downloading azureml_train_automl_client-1.28.0-py3-none-any.whl (120 kB)
# Collecting azureml-train~=1.28.0
#   Downloading azureml_train-1.28.0-py3-none-any.whl (3.3 kB)
# Collecting azureml-pipeline~=1.28.0
#   Downloading azureml_pipeline-1.28.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.27.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-train-automl-client~=1.27.0
#   Downloading azureml_train_automl_client-1.27.0-py3-none-any.whl (120 kB)
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.26.0-py3-none-any.whl (4.4 kB)
#   Downloading azureml_sdk-1.25.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-pipeline~=1.25.0
#   Downloading azureml_pipeline-1.25.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.24.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-pipeline~=1.24.0
#   Downloading azureml_pipeline-1.24.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.23.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-train~=1.23.0
#   Downloading azureml_train-1.23.0-py3-none-any.whl (3.3 kB)
# Collecting azureml-pipeline~=1.23.0
#   Downloading azureml_pipeline-1.23.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.22.0-py3-none-any.whl (4.4 kB)
#   Downloading azureml_sdk-1.21.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-train-automl-client~=1.21.0
#   Downloading azureml_train_automl_client-1.21.0-py3-none-any.whl (115 kB)
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.20.0-py3-none-any.whl (4.4 kB)
# Collecting azureml-pipeline~=1.20.0
#   Downloading azureml_pipeline-1.20.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-train~=1.20.0
#   Downloading azureml_train-1.20.0-py3-none-any.whl (3.3 kB)
# Collecting azureml-train-automl-client~=1.20.0
#   Downloading azureml_train_automl_client-1.20.0-py3-none-any.whl (111 kB)
# Collecting azureml-pipeline-steps~=1.20.0
#   Downloading azureml_pipeline_steps-1.20.0-py3-none-any.whl (66 kB)
# Collecting azureml-pipeline-core~=1.20.0
#   Downloading azureml_pipeline_core-1.20.0-py3-none-any.whl (307 kB)
# Collecting azureml-train-core~=1.20.0
#   Downloading azureml_train_core-1.20.0-py3-none-any.whl (8.6 MB)
# Collecting azureml-automl-core~=1.20.0
#   Downloading azureml_automl_core-1.20.0-py3-none-any.whl (190 kB)
# Collecting azureml-telemetry~=1.20.0
#   Downloading azureml_telemetry-1.20.0-py3-none-any.whl (30 kB)
# Collecting azureml-train-restclients-hyperdrive~=1.20.0
#   Downloading azureml_train_restclients_hyperdrive-1.20.0-py3-none-any.whl (19 kB)
# Collecting azureml-widgets
#   Downloading azureml_widgets-1.30.0-py3-none-any.whl (14.1 MB)
#   Downloading azureml_widgets-1.29.0.post1-py3-none-any.whl (14.1 MB)
# Collecting ipywidgets>=7.0.0
#   Downloading ipywidgets-7.6.3-py2.py3-none-any.whl (121 kB)
# Collecting azureml-widgets
#   Downloading azureml_widgets-1.29.0-py3-none-any.whl (14.1 MB)
#   Downloading azureml_widgets-1.28.0-py3-none-any.whl (14.1 MB)
#   Downloading azureml_widgets-1.27.0-py3-none-any.whl (14.1 MB)
#   Downloading azureml_widgets-1.26.0-py3-none-any.whl (14.1 MB)
#   Downloading azureml_widgets-1.25.0-py3-none-any.whl (14.1 MB)
#   Downloading azureml_widgets-1.24.0-py3-none-any.whl (14.1 MB)
#   Downloading azureml_widgets-1.23.0-py3-none-any.whl (14.1 MB)
#   Downloading azureml_widgets-1.22.0-py3-none-any.whl (14.1 MB)
#   Downloading azureml_widgets-1.21.0-py3-none-any.whl (14.1 MB)
#   Downloading azureml_widgets-1.20.0-py3-none-any.whl (14.1 MB)
# Collecting traitlets>=4.3.1
#   Downloading traitlets-5.0.5-py3-none-any.whl (100 kB)
# Collecting nbformat>=4.2.0
#   Downloading nbformat-5.1.3-py3-none-any.whl (178 kB)
# Collecting ipython>=4.0.0
#   Downloading ipython-7.25.0-py3-none-any.whl (786 kB)
# Collecting ipykernel>=4.5.1
#   Downloading ipykernel-5.5.5-py3-none-any.whl (120 kB)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.0.0-py3-none-any.whl (243 kB)
# Collecting tornado>=4.2
#   Downloading tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
# Collecting jupyter-client
#   Downloading jupyter_client-6.1.12-py3-none-any.whl (112 kB)
# Requirement already satisfied: setuptools>=18.5 in /azureml-envs/azureml_b090681661c04b45aeaa579d18649daf/lib/python3.7/site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->azureml-widgets->-r /azureml-environment-setup/condaenv.lfg_i2br.requirements.txt (line 5)) (49.6.0.post20210108)
# Collecting pexpect>4.3
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.19-py3-none-any.whl (368 kB)
# Collecting matplotlib-inline
#   Downloading matplotlib_inline-0.1.2-py3-none-any.whl (8.2 kB)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.0-py2.py3-none-any.whl (1.4 MB)
# Collecting decorator
#   Downloading decorator-5.0.9-py3-none-any.whl (8.9 kB)
# Collecting parso<0.9.0,>=0.8.0
#   Downloading parso-0.8.2-py2.py3-none-any.whl (94 kB)
# Collecting jupyter-core
#   Downloading jupyter_core-4.7.1-py3-none-any.whl (82 kB)
# Collecting jsonschema!=2.5.0,>=2.4
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting pyrsistent>=0.14.0
#   Downloading pyrsistent-0.17.3.tar.gz (106 kB)
# Collecting attrs>=17.4.0
#   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting notebook>=4.4.1
#   Downloading notebook-6.4.0-py3-none-any.whl (9.5 MB)
# Collecting Send2Trash>=1.5.0
#   Downloading Send2Trash-1.7.1-py3-none-any.whl (17 kB)
# Collecting nbconvert
#   Downloading nbconvert-6.1.0-py3-none-any.whl (551 kB)
# Collecting prometheus-client
#   Downloading prometheus_client-0.11.0-py2.py3-none-any.whl (56 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.10.1-py3-none-any.whl (14 kB)
# Collecting argon2-cffi
#   Downloading argon2_cffi-20.1.0-cp35-abi3-manylinux1_x86_64.whl (97 kB)
# Collecting pyzmq>=17
#   Downloading pyzmq-22.1.0-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.4.3.tar.gz (16 kB)
# Collecting mistune<2,>=0.8.1
#   Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting bleach
#   Downloading bleach-3.3.0-py2.py3-none-any.whl (283 kB)
# Collecting testpath
#   Downloading testpath-0.5.0-py3-none-any.whl (84 kB)
# Collecting entrypoints>=0.2.2
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting nbclient<0.6.0,>=0.5.0
#   Downloading nbclient-0.5.3-py3-none-any.whl (82 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting async-generator
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.5.1-py3-none-any.whl (5.0 kB)
# Collecting packaging
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Building wheels for collected packages: jsondiff, jsmin, vsts-cd-manager, json-logging-py, fusepy, liac-arff, pyrsistent, antlr4-python3-runtime, pandocfilters
#   Building wheel for jsondiff (setup.py): started
#   Building wheel for jsondiff (setup.py): finished with status 'done'
#   Created wheel for jsondiff: filename=jsondiff-1.2.0-py3-none-any.whl size=6539 sha256=27fd5c9854f7e0d3126ba7b4995aa0a49aabc2f83ad15419384ee30b67f88e0b
#   Stored in directory: /root/.cache/pip/wheels/13/19/b3/9065e430a7cd8215f03a27af9d3352b8b4833a22204856c1bd
#   Building wheel for jsmin (setup.py): started
#   Building wheel for jsmin (setup.py): finished with status 'done'
#   Created wheel for jsmin: filename=jsmin-2.2.2-py3-none-any.whl size=13920 sha256=6d28ea00ee37558f9c3e712116d3f0dc6359fe17b7b4a5103f9d093638004f40
#   Stored in directory: /root/.cache/pip/wheels/00/71/93/3a6bba7e9ca923c4d7e950673b3a823d89b71e0d2cae1c2192
#   Building wheel for vsts-cd-manager (setup.py): started
#   Building wheel for vsts-cd-manager (setup.py): finished with status 'done'
#   Created wheel for vsts-cd-manager: filename=vsts_cd_manager-1.0.2-py3-none-any.whl size=26727 sha256=06cd88089a1baa60bc05972c02a173a9950191b5e09bacbd919ae2101d545ed8
#   Stored in directory: /root/.cache/pip/wheels/8c/72/eb/3bc74103d25f098fe852ba91a6a8db8cea7aa96c0c2e2b36ab
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=26c23c508d044fdc6dfae711186f844c77a766a1e5a134ff9e51fb444d8c660e
#   Stored in directory: /root/.cache/pip/wheels/2b/2c/0b/56aba27cc60071c52f66346a1abc22ee9db8c7376549aa4910
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=7d6e5c2bce9800c135862c065c03898cd9b77aa8c4f4c4bd3fd58712c1b0e285
#   Stored in directory: /root/.cache/pip/wheels/89/07/84/a5ebfafeefbbc56ceda9d6935a54a8be7a4eccf4ea7e9bf980
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11731 sha256=384972d7e0de3016f37687c45354a75d88c7fc2260186eeeaaf58700b98c28e0
#   Stored in directory: /root/.cache/pip/wheels/1f/0f/15/332ca86cbebf25ddf98518caaf887945fbe1712b97a0f2493b
#   Building wheel for pyrsistent (setup.py): started
#   Building wheel for pyrsistent (setup.py): finished with status 'done'
#   Created wheel for pyrsistent: filename=pyrsistent-0.17.3-cp37-cp37m-linux_x86_64.whl size=113838 sha256=6d449ed1a1c602f102ff5be1bfb624d8f6a12843f22728ba8b26d818e1ba7d98
#   Stored in directory: /root/.cache/pip/wheels/a5/52/bf/71258a1d7b3c8cbe1ee53f9314c6f65f20385481eaee573cc5
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.2-py3-none-any.whl size=144566 sha256=2b2a0833492f301cad5a12ee20bad1d3763237c4b989bdbf3c0b6bac92a63c14
#   Stored in directory: /root/.cache/pip/wheels/14/4c/18/1dbbc9875a2547d2063400ea9f404da4af3331965a71061029
# ...
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.36.2
#     Uninstalling wheel-0.36.2:
#       Successfully uninstalled wheel-0.36.2
# Successfully installed MarkupSafe-2.0.1 PyJWT-1.7.1 SecretStorage-3.3.1 Send2Trash-1.7.1 adal-1.2.7 antlr4-python3-runtime-4.9.2 applicationinsights-0.11.10 argcomplete-1.12.3 argon2-cffi-20.1.0 async-generator-1.10 attrs-21.2.0 azure-batch-8.0.0 azure-cli-2.3.1 azure-cli-command-modules-nspkg-2.0.3 azure-cli-core-2.3.1 azure-cli-nspkg-3.0.4 azure-cli-telemetry-1.0.6 azure-common-1.1.27 azure-core-1.15.0 azure-cosmos-3.2.0 azure-datalake-store-0.0.52 azure-functions-devops-build-0.0.22 azure-graphrbac-0.60.0 azure-identity-1.4.1 azure-keyvault-1.1.0 azure-loganalytics-0.1.0 azure-mgmt-advisor-2.0.1 azure-mgmt-apimanagement-0.1.0 azure-mgmt-appconfiguration-0.4.0 azure-mgmt-applicationinsights-0.1.1 azure-mgmt-authorization-0.52.0 azure-mgmt-batch-7.0.0 azure-mgmt-batchai-2.0.0 azure-mgmt-billing-0.2.0 azure-mgmt-botservice-0.2.0 azure-mgmt-cdn-4.1.0rc1 azure-mgmt-cognitiveservices-5.0.0 azure-mgmt-compute-12.1.0 azure-mgmt-consumption-2.0.0 azure-mgmt-containerinstance-1.5.0 azure-mgmt-containerregistry-3.0.0rc17 azure-mgmt-containerservice-9.0.1 azure-mgmt-cosmosdb-0.12.0 azure-mgmt-datalake-analytics-0.2.1 azure-mgmt-datalake-nspkg-3.0.1 azure-mgmt-datalake-store-0.5.0 azure-mgmt-datamigration-0.1.0 azure-mgmt-deploymentmanager-0.2.0 azure-mgmt-devtestlabs-2.2.0 azure-mgmt-dns-2.1.0 azure-mgmt-eventgrid-2.2.0 azure-mgmt-eventhub-3.0.0 azure-mgmt-hdinsight-1.4.0 azure-mgmt-imagebuilder-0.2.1 azure-mgmt-iotcentral-3.0.0 azure-mgmt-iothub-0.11.0 azure-mgmt-iothubprovisioningservices-0.2.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-kusto-0.3.0 azure-mgmt-loganalytics-0.7.0 azure-mgmt-managedservices-1.0.0 azure-mgmt-managementgroups-0.2.0 azure-mgmt-maps-0.1.0 azure-mgmt-marketplaceordering-0.2.1 azure-mgmt-media-1.1.1 azure-mgmt-monitor-0.7.0 azure-mgmt-msi-0.2.0 azure-mgmt-netapp-0.8.0 azure-mgmt-network-10.0.0 azure-mgmt-nspkg-3.0.2 azure-mgmt-policyinsights-0.4.0 azure-mgmt-privatedns-0.1.0 azure-mgmt-rdbms-2.2.0 azure-mgmt-recoveryservices-0.4.0 azure-mgmt-recoveryservicesbackup-0.6.0 azure-mgmt-redis-7.0.0rc2 azure-mgmt-relay-0.1.0 azure-mgmt-reservations-0.6.0 azure-mgmt-resource-8.0.1 azure-mgmt-search-2.1.0 azure-mgmt-security-0.1.0 azure-mgmt-servicebus-0.6.0 azure-mgmt-servicefabric-0.4.0 azure-mgmt-signalr-0.3.0 azure-mgmt-sql-0.17.0 azure-mgmt-sqlvirtualmachine-0.5.0 azure-mgmt-storage-8.0.0 azure-mgmt-trafficmanager-0.51.0 azure-mgmt-web-0.44.0 azure-multiapi-storage-0.2.4 azure-nspkg-3.0.2 azure-storage-blob-1.5.0 azure-storage-common-1.4.2 azureml-automl-core-1.20.0 azureml-core-1.20.0 azureml-dataprep-2.7.4 azureml-dataprep-native-27.0.0 azureml-dataprep-rslex-1.5.0 azureml-dataset-runtime-1.20.0 azureml-defaults-1.20.0 azureml-model-management-sdk-1.0.1b6.post1 azureml-pipeline-1.20.0 azureml-pipeline-core-1.20.0 azureml-pipeline-steps-1.20.0 azureml-sdk-1.20.0 azureml-telemetry-1.20.0 azureml-train-1.20.0 azureml-train-automl-client-1.20.0 azureml-train-core-1.20.0 azureml-train-restclients-hyperdrive-1.20.0 azureml-widgets-1.20.0 backcall-0.2.0 backports.tempfile-1.0 backports.weakref-1.0.post1 bcrypt-3.2.0 bleach-3.3.0 cffi-1.14.5 chardet-4.0.0 click-8.0.1 cloudpickle-1.6.0 colorama-0.4.4 configparser-3.7.4 contextlib2-21.6.0 cryptography-2.9.2 decorator-5.0.9 defusedxml-0.7.1 dill-0.3.4 distro-1.5.0 docker-5.0.0 dotnetcore2-2.1.21 entrypoints-0.3 fabric-2.6.0 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 humanfriendly-8.2 idna-2.10 importlib-metadata-4.6.0 invoke-1.5.0 ipykernel-5.5.5 ipython-7.25.0 ipython-genutils-0.2.0 ipywidgets-7.6.3 isodate-0.6.0 itsdangerous-2.0.1 javaproperties-0.5.1 jedi-0.18.0 jeepney-0.6.0 jinja2-3.0.1 jmespath-0.10.0 jsmin-2.2.2 json-logging-py-0.2 jsondiff-1.2.0 jsonpickle-2.0.0 jsonschema-3.2.0 jupyter-client-6.1.12 jupyter-core-4.7.1 jupyterlab-pygments-0.1.2 jupyterlab-widgets-1.0.0 knack-0.7.0rc1 liac-arff-2.5.0 matplotlib-inline-0.1.2 mistune-0.8.4 mock-4.0.3 msal-1.12.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 nbclient-0.5.3 nbconvert-6.1.0 nbformat-5.1.3 ndg-httpsclien ...
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_b090681661c04b45aeaa579d18649daf
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 2540d406ca3e
#  ---> 73f4f9b6263e
# Step 15/25 : ENV PATH /azureml-envs/azureml_b090681661c04b45aeaa579d18649daf/bin:$PATH
#  ---> Running in e687100a4884
# Removing intermediate container e687100a4884
#  ---> 949efe557564
# Step 16/25 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 20ed9ba7b326
# Step 17/25 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> d39833f36e5b
# Step 18/25 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_b090681661c04b45aeaa579d18649daf
#  ---> Running in e19e801839f1
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container e19e801839f1
#  ---> 355e71e00def
# Step 19/25 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_b090681661c04b45aeaa579d18649daf
#  ---> Running in f18746ca0494
# Removing intermediate container f18746ca0494
#  ---> 4579cbf0188a
# Step 20/25 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_b090681661c04b45aeaa579d18649daf/lib:$LD_LIBRARY_PATH
#  ---> Running in 3b72e88ba93e
# Removing intermediate container 3b72e88ba93e
#  ---> e3476827354e
# Step 21/25 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 268747c1093b
# Step 22/25 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in a27e077538e2
# Removing intermediate container a27e077538e2
#  ---> 1e01c69d2fb6
# Step 23/25 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 4aec2c18b40b
# Removing intermediate container 4aec2c18b40b
#  ---> 70a7b9d096a2
# Step 24/25 : CMD ["bash"]
#  ---> Running in eaf3ef4c9332
# Removing intermediate container eaf3ef4c9332
#  ---> 67870f3eb850
# Step 25/25 : EXPOSE 5001 8883 8888
#  ---> Running in 4007c0db15dd
# Removing intermediate container 4007c0db15dd
#  ---> a6d60cf57bfc
# Successfully built a6d60cf57bfc
# Successfully tagged 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b:latest
# Successfully tagged 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b:1
# 2021/06/28 18:16:25 Successfully executed container: acb_step_0
# 2021/06/28 18:16:25 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/06/28 18:16:25 Pushing image: 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b:1, attempt 1
# The push refers to repository [4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b]
# 44cd31926492: Preparing
# bc5ec647cc4e: Preparing
# 3003bab43957: Preparing
# d5be40cb7a91: Preparing
# ecba82263a10: Preparing
# 900803f163dc: Preparing
# 849000fcceba: Preparing
# 6cc44774fa32: Preparing
# 15d3efb76e30: Preparing
# 8aa0cefff129: Preparing
# c0bf52624a8b: Preparing
# fa5f62c9cc40: Preparing
# 630330099f1e: Preparing
# 26346e33e93c: Preparing
# 65fd26c61dec: Preparing
# 8b72eff884fd: Preparing
# f06675a4a69e: Preparing
# 7117e7689e0f: Preparing
# d56ca49dab62: Preparing
# 09304b9c7c13: Preparing
# 9edaa71ce233: Preparing
# 62fdddf6a67c: Preparing
# eff16de3ff64: Preparing
# 61727f5e6796: Preparing
# 900803f163dc: Waiting
# 849000fcceba: Waiting
# 6cc44774fa32: Waiting
# 15d3efb76e30: Waiting
# 8aa0cefff129: Waiting
# c0bf52624a8b: Waiting
# fa5f62c9cc40: Waiting
# 630330099f1e: Waiting
# 26346e33e93c: Waiting
# 65fd26c61dec: Waiting
# 8b72eff884fd: Waiting
# f06675a4a69e: Waiting
# 7117e7689e0f: Waiting
# d56ca49dab62: Waiting
# 09304b9c7c13: Waiting
# 9edaa71ce233: Waiting
# 62fdddf6a67c: Waiting
# eff16de3ff64: Waiting
# 61727f5e6796: Waiting
# d5be40cb7a91: Pushed
# 44cd31926492: Pushed
# 3003bab43957: Pushed
# bc5ec647cc4e: Pushed
# 6cc44774fa32: Pushed
# 849000fcceba: Pushed
# 900803f163dc: Pushed
# c0bf52624a8b: Pushed
# fa5f62c9cc40: Pushed
# 15d3efb76e30: Pushed
# 630330099f1e: Pushed
# 26346e33e93c: Pushed
# 8aa0cefff129: Pushed
# 65fd26c61dec: Pushed
# d56ca49dab62: Pushed
# 8b72eff884fd: Pushed
# 7117e7689e0f: Pushed
# 9edaa71ce233: Pushed
# 62fdddf6a67c: Pushed
# eff16de3ff64: Pushed
# f06675a4a69e: Pushed
# 61727f5e6796: Pushed
# 09304b9c7c13: Pushed
#
# ecba82263a10: Pushed
# 1: digest: sha256:4c820153dc704f8203742de7514a5208a7f181e24892735cb87b54e8e51eceb2 size: 5353
# 2021/06/28 18:21:23 Successfully pushed image: 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b:1
# 2021/06/28 18:21:23 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/06/28 18:21:23 Pushing image: 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b:latest, attempt 1
# The push refers to repository [4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b]
# 44cd31926492: Preparing
# bc5ec647cc4e: Preparing
# 3003bab43957: Preparing
# d5be40cb7a91: Preparing
# ecba82263a10: Preparing
# 900803f163dc: Preparing
# 849000fcceba: Preparing
# 6cc44774fa32: Preparing
# 15d3efb76e30: Preparing
# 8aa0cefff129: Preparing
# c0bf52624a8b: Preparing
# fa5f62c9cc40: Preparing
# 630330099f1e: Preparing
# 26346e33e93c: Preparing
# 65fd26c61dec: Preparing
# 8b72eff884fd: Preparing
# f06675a4a69e: Preparing
# 7117e7689e0f: Preparing
# d56ca49dab62: Preparing
# 09304b9c7c13: Preparing
# 9edaa71ce233: Preparing
# 62fdddf6a67c: Preparing
# eff16de3ff64: Preparing
# 61727f5e6796: Preparing
# 900803f163dc: Waiting
# 8b72eff884fd: Waiting
# f06675a4a69e: Waiting
# 849000fcceba: Waiting
# 6cc44774fa32: Waiting
# 7117e7689e0f: Waiting
# 15d3efb76e30: Waiting
# 8aa0cefff129: Waiting
# d56ca49dab62: Waiting
# c0bf52624a8b: Waiting
# 09304b9c7c13: Waiting
# fa5f62c9cc40: Waiting
# 630330099f1e: Waiting
# 26346e33e93c: Waiting
# 9edaa71ce233: Waiting
# 65fd26c61dec: Waiting
# 62fdddf6a67c: Waiting
# eff16de3ff64: Waiting
# 61727f5e6796: Waiting
# d5be40cb7a91: Layer already exists
# 44cd31926492: Layer already exists
# bc5ec647cc4e: Layer already exists
# 3003bab43957: Layer already exists
# 900803f163dc: Layer already exists
# ecba82263a10: Layer already exists
# 849000fcceba: Layer already exists
# 15d3efb76e30: Layer already exists
# 8aa0cefff129: Layer already exists
# 6cc44774fa32: Layer already exists
# fa5f62c9cc40: Layer already exists
# c0bf52624a8b: Layer already exists
# 65fd26c61dec: Layer already exists
# 630330099f1e: Layer already exists
# 26346e33e93c: Layer already exists
# 8b72eff884fd: Layer already exists
# f06675a4a69e: Layer already exists
# d56ca49dab62: Layer already exists
# 7117e7689e0f: Layer already exists
# 09304b9c7c13: Layer already exists
# 9edaa71ce233: Layer already exists
# 62fdddf6a67c: Layer already exists
# eff16de3ff64: Layer already exists
# 61727f5e6796: Layer already exists
# latest: digest: sha256:4c820153dc704f8203742de7514a5208a7f181e24892735cb87b54e8e51eceb2 size: 5353
# 2021/06/28 18:21:30 Successfully pushed image: 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b:latest
# 2021/06/28 18:21:30 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 598.023725)
# 2021/06/28 18:21:30 Populating digests for step ID: acb_step_0...
# 2021/06/28 18:21:36 Successfully populated digests for step ID: acb_step_0
# 2021/06/28 18:21:36 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 297.462695)
# 2021/06/28 18:21:36 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 7.792456)
# 2021/06/28 18:21:36 The following dependencies were found:
# 2021/06/28 18:21:36
# - image:
#     registry: 4d3602983f8547aa8deaeb9718806017.azurecr.io
#     repository: azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
#     tag: latest
#     digest: sha256:4c820153dc704f8203742de7514a5208a7f181e24892735cb87b54e8e51eceb2
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20201113.v1
#     digest: sha256:c9965db4542714161cec2bb1c7a118e9919a88ce8915e506846e8a831bf130ed
#   buildtime-dependency:
#   - registry: mcr.microsoft.com
#     repository: azureml/o16n-base/python-assets
#     tag: latest
#     digest: sha256:7da855b76a4790e83c20b1f1d4cc0dd449cfdb4c9ced1c02fb2f8cf7f7456d1d
#   git: {}
# - image:
#     registry: 4d3602983f8547aa8deaeb9718806017.azurecr.io
#     repository: azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
#     tag: "1"
#     digest: sha256:4c820153dc704f8203742de7514a5208a7f181e24892735cb87b54e8e51eceb2
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20201113.v1
#     digest: sha256:c9965db4542714161cec2bb1c7a118e9919a88ce8915e506846e8a831bf130ed
#   buildtime-dependency:
#   - registry: mcr.microsoft.com
#     repository: azureml/o16n-base/python-assets
#     tag: latest
#     digest: sha256:7da855b76a4790e83c20b1f1d4cc0dd449cfdb4c9ced1c02fb2f8cf7f7456d1d
#   git: {}
#
#
# Run ID: cb2 was successful after 15m14s
# Package creation Succeeded
# Logging into Docker registry 4d3602983f8547aa8deaeb9718806017.azurecr.io
# Logging into Docker registry 4d3602983f8547aa8deaeb9718806017.azurecr.io
# Building Docker image from Dockerfile...
# Step 1/5 : FROM 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
#  ---> a6d60cf57bfc
# Step 2/5 : COPY azureml-app /var/azureml-app
#  ---> 513218c8fae5
# Step 3/5 : RUN mkdir -p '/var/azureml-app' && echo  | base64 --decode > /var/azureml-app/model_config_map.json
#  ---> Running in d4e9bc541bb2
#  ---> 72bcaf72667b
# Step 4/5 : RUN mv '/var/azureml-app/tmpow7rvo1_.py' /var/azureml-app/main.py
#  ---> Running in bee4abccec34
#  ---> e15e231f4fc8
# Step 5/5 : CMD ["runsvdir","/var/runit"]
#  ---> Running in bb4a66efa22f
#  ---> de496f6ffe0e
# Successfully built de496f6ffe0e
# Successfully tagged dog-classification-service-local:latest
# Starting Docker container...
# Docker container running.
# Checking container health...
# Local webservice is running at http://localhost:6789

# %% [markdown]
# The local deployment will build the inferencing image on your local compute target (e.g. AML CI) with the name of the local_service_name parameter and run it inside a container.
#
# In order to see all docker images on your AML CI run the following command from the terminal:
#
# `docker images`
#
# In order to see all running containers run the following:
#
# `docker ps`

# %% [markdown]
# ### Update Local Deployment

# %% [markdown]
# After the web service has been initially deployed, it's more efficient to use the update() method rather than starting from scratch. For more details about updating models check [this](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-update-web-service).

# %%
# Update to new model
local_service.update(models=[model], inference_config=inference_config)
local_service.wait_for_deployment(show_output=True)

print(local_service.state)
print(local_service.get_logs())
# Out:
# Downloading model dog_clf_model:1 to /tmp/azureml_a9dtxco2/dog_clf_model/1
# Generating Docker build context.
# Package creation Succeeded
# Logging into Docker registry 4d3602983f8547aa8deaeb9718806017.azurecr.io
# Logging into Docker registry 4d3602983f8547aa8deaeb9718806017.azurecr.io
# Building Docker image from Dockerfile...
# Step 1/5 : FROM 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
#  ---> a6d60cf57bfc
# Step 2/5 : COPY azureml-app /var/azureml-app
#  ---> 81c7b4b8f65b
# Step 3/5 : RUN mkdir -p '/var/azureml-app' && echo  | base64 --decode > /var/azureml-app/model_config_map.json
#  ---> Running in d0efe61f0c41
#  ---> ffe6ad0b40b4
# Step 4/5 : RUN mv '/var/azureml-app/tmpvbtdzsqb.py' /var/azureml-app/main.py
#  ---> Running in 6b341da8b73f
#  ---> 436b0695009d
# Step 5/5 : CMD ["runsvdir","/var/runit"]
#  ---> Running in ac7be10f480c
#  ---> b06ef4da7ec6
# Successfully built b06ef4da7ec6
# Successfully tagged dog-classification-service-local:latest
# Container has been successfully cleaned up.
# Image sha256:de496f6ffe0e31877e4026e7c7988b13a24bc14593be9c34f7e43a2a22247e59 successfully removed.
# Starting Docker container...
# Docker container running.
# Checking container health...
# Local webservice is running at http://localhost:6789
# running
# 2021-06-28T18:35:14,347015642+00:00 - rsyslog/run
# 2021-06-28T18:35:14,347396942+00:00 - iot-server/run
# 2021-06-28T18:35:14,354856853+00:00 - nginx/run
# 2021-06-28T18:35:14,355629654+00:00 - gunicorn/run
# Dynamic Python package installation is disabled.
# Starting HTTP server
# EdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...
# 2021-06-28T18:35:14,428733961+00:00 - iot-server/finish 1 0
# 2021-06-28T18:35:14,430043463+00:00 - Exit code 1 is normal. Not restarting iot-server.
# Starting gunicorn 19.9.0
# Listening at: http://127.0.0.1:31311 (11)
# Using worker: sync
# worker timeout is set to 300
# Booting worker with pid: 41
# SPARK_HOME not set. Skipping PySpark Initialization.
# Initializing logger
# 2021-06-28 18:35:16,532 | root | INFO | Starting up app insights client
# logging socket was found. logging is available.
# logging socket was found. logging is available.
# 2021-06-28 18:35:16,533 | root | INFO | Starting up request id generator
# 2021-06-28 18:35:16,533 | root | INFO | Starting up app insight hooks
# 2021-06-28 18:35:16,533 | root | INFO | Invoking user's init function
# 2021-06-28 18:35:16,683 | root | INFO | Users's init has completed successfully
# 2021-06-28 18:35:16,686 | root | INFO | Skipping middleware: dbg_model_info as it's not enabled.
# 2021-06-28 18:35:16,686 | root | INFO | Skipping middleware: dbg_resource_usage as it's not enabled.
# 2021-06-28 18:35:16,686 | root | INFO | Scoring timeout setting is not found. Use default timeout: 3600000 ms

# %% [markdown]
# ### Local Webservice Testing

# %% [markdown]
# Test the local webservice using an HTTP request with the requests library.

# %%
# Display the test image
# %matplotlib inline
plt.imshow(Image.open(data_example_path))

# Preprocess the image
input_data = preprocess_image(data_example_path)

# Get header and body for POST request
input_data = "{\"data\": " + str(input_data.tolist()) + "}"
headers = {"Content-Type": "application/json"}

# Get scoring URI
local_scoring_uri = local_service.scoring_uri

# Make POST request
resp = requests.post(local_scoring_uri, input_data, headers=headers)

print("POST to url", local_scoring_uri)
print("Result:", resp.text)
# Out:
# POST to url http://localhost:6789/score
# Result: {"label": "n02085620-Chihuahua", "probability": "0.9995623"}

# %% [markdown]
# If something goes wrong with the deployment, the first thing to look at is the logs from the service by running the following command:

# %%
local_service.get_logs()
# Out:
# '2021-06-28T18:35:14,347015642+00:00 - rsyslog/run \n2021-06-28T18:35:14,347396942+00:00 - iot-server/run \n2021-06-28T18:35:14,354856853+00:00 - nginx/run \n2021-06-28T18:35:14,355629654+00:00 - gunicorn/run \nDynamic Python package installation is disabled.\nStarting HTTP server\nEdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...\n2021-06-28T18:35:14,428733961+00:00 - iot-server/finish 1 0\n2021-06-28T18:35:14,430043463+00:00 - Exit code 1 is normal. Not restarting iot-server.\nStarting gunicorn 19.9.0\nListening at: http://127.0.0.1:31311 (11)\nUsing worker: sync\nworker timeout is set to 300\nBooting worker with pid: 41\nSPARK_HOME not set. Skipping PySpark Initialization.\nInitializing logger\n2021-06-28 18:35:16,532 | root | INFO | Starting up app insights client\nlogging socket was found. logging is available.\nlogging socket was found. logging is available.\n2021-06-28 18:35:16,533 | root | INFO | Starting up request id generator\n2021-06-28 18:35:16,533 | root | INFO | Starting up app insight hooks\n2021-06-28 18:35:16,533 | root | INFO | Invoking user\'s init function\n2021-06-28 18:35:16,683 | root | INFO | Users\'s init has completed successfully\n2021-06-28 18:35:16,686 | root | INFO | Skipping middleware: dbg_model_info as it\'s not enabled.\n2021-06-28 18:35:16,686 | root | INFO | Skipping middleware: dbg_resource_usage as it\'s not enabled.\n2021-06-28 18:35:16,686 | root | INFO | Scoring timeout setting is not found. Use default timeout: 3600000 ms\n2021-06-28 19:52:48,146 | root | INFO | Scoring Timer is set to 3600.0 seconds\n2021-06-28 19:52:48,350 | root | INFO | 200\n127.0.0.1 - - [28/Jun/2021:19:52:48 +0000] "POST /score HTTP/1.0" 200 60 "-" "python-requests/2.25.1"\n'

# %% [markdown]
# ### Local Webservice Clean Up

# %%
# Delete the local webservice
try:
    local_service.delete()
    print("Local service deleted.")
except:
    print("No local service.")
# Out:
# Container has been successfully cleaned up.
# Local service deleted.

# %% [markdown]
# **Note**: Above SDK call will stop the container but not delete the image. When you do not require your image anymore, you should delete your images as too many images might lead your AML CI to enter an unusable state due to full disk storage.
#
# In order to remove an image run:
#
# `docker image rmi <IMAGE_ID> --force`
#
# In order to prune the docker system (e.g. remove cache) run:
#
# `docker system prune`

# %% [markdown]
# # Model Deployment (Compute Target)

# %% [markdown]
# ### Option 1: Deploy to ACI (Azure Container Instances)

# %% [markdown]
# Create new ACI Webservice.

# %%
aci_config = AciWebservice.deploy_configuration(cpu_cores=1,
                                                memory_gb=1,
                                                tags=service_tags,
                                                description=service_description)

aci_service = Model.deploy(workspace=ws,
                           name=aci_service_name,
                           models=[model],
                           inference_config=inference_config,
                           deployment_config=aci_config)

aci_service.wait_for_deployment(True)
print(aci_service.state)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running....................................................
# Succeeded
# ACI service creation operation finished, operation "Succeeded"
# Healthy

# %% [markdown]
# Retrieve existing ACI Webservice.

# %%
aci_service = Webservice(ws, aci_service_name)

# %% [markdown]
# #### ACI Webservice Testing

# %% [markdown]
# Test the ACI webservice using an HTTP request with the requests library.

# %%
# Display the test image
# %matplotlib inline
plt.imshow(Image.open(data_example_path))

# Preprocess the image
input_data = preprocess_image(data_example_path)

# Get header and body for POST request
input_data = "{\"data\": " + str(input_data.tolist()) + "}"
headers = {"Content-Type": "application/json"}

# Get scoring URI
aci_scoring_uri = aci_service.scoring_uri

# Make POST request
resp = requests.post(aci_scoring_uri, input_data, headers=headers)

print("POST to url", aci_scoring_uri)
print("Result:", resp.text)
# Out:
# POST to url http://f0be8c9c-2244-498d-a55b-87f2e28b9578.westeurope.azurecontainer.io/score
# Result: {"label": "n02085620-Chihuahua", "probability": "0.9995623"}

# %% [markdown]
# If something goes wrong with the deployment, the first thing to look at is the logs from the service by running the following command:

# %%
aci_service.get_logs()
# Out:
# '2021-06-28T19:59:40,172047499+00:00 - gunicorn/run \n2021-06-28T19:59:40,172707946+00:00 - iot-server/run \nDynamic Python package installation is disabled.\nStarting HTTP server\n2021-06-28T19:59:40,172264815+00:00 - rsyslog/run \n2021-06-28T19:59:40,240077467+00:00 - nginx/run \nEdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...\n2021-06-28T19:59:40,523900974+00:00 - iot-server/finish 1 0\n2021-06-28T19:59:40,530221126+00:00 - Exit code 1 is normal. Not restarting iot-server.\nStarting gunicorn 19.9.0\nListening at: http://127.0.0.1:31311 (11)\nUsing worker: sync\nworker timeout is set to 300\nBooting worker with pid: 37\nSPARK_HOME not set. Skipping PySpark Initialization.\nInitializing logger\n2021-06-28 19:59:44,905 | root | INFO | Starting up app insights client\nlogging socket was found. logging is available.\nlogging socket was found. logging is available.\n2021-06-28 19:59:44,905 | root | INFO | Starting up request id generator\n2021-06-28 19:59:44,906 | root | INFO | Starting up app insight hooks\n2021-06-28 19:59:44,906 | root | INFO | Invoking user\'s init function\n2021-06-28 19:59:45,869 | root | INFO | Users\'s init has completed successfully\n2021-06-28 19:59:45,872 | root | INFO | Skipping middleware: dbg_model_info as it\'s not enabled.\n2021-06-28 19:59:45,872 | root | INFO | Skipping middleware: dbg_resource_usage as it\'s not enabled.\n2021-06-28 19:59:45,873 | root | INFO | Scoring timeout is found from os.environ: 60000 ms\n2021-06-28 19:59:52,223 | root | INFO | Swagger file not present\n2021-06-28 19:59:52,223 | root | INFO | 404\n127.0.0.1 - - [28/Jun/2021:19:59:52 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "Go-http-client/1.1"\n2021-06-28 19:59:56,093 | root | INFO | Swagger file not present\n2021-06-28 19:59:56,093 | root | INFO | 404\n127.0.0.1 - - [28/Jun/2021:19:59:56 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "Go-http-client/1.1"\n2021-06-28 19:59:57,040 | root | INFO | Swagger file not present\n2021-06-28 19:59:57,041 | root | INFO | 404\n127.0.0.1 - - [28/Jun/2021:19:59:57 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "Go-http-client/1.1"\n2021-06-28 19:59:57,820 | root | INFO | Scoring Timer is set to 60.0 seconds\n2021-06-28 19:59:58,079 | root | INFO | 200\n127.0.0.1 - - [28/Jun/2021:19:59:58 +0000] "POST /score HTTP/1.0" 200 60 "-" "python-requests/2.25.1"\n'

# %% [markdown]
# ### ACI Webservice Clean Up

# %%
# Delete the ACI webservice
try:    
    aci_service.delete()
    print("ACI service deleted.")
except:
    print("No ACI service.")
# Out:
# ACI service deleted.

# %% [markdown]
# ### Option 2: Deploy to AKS (Azure Kubernetes Service)

# %% [markdown]
# Retrieve existing AKS cluster or provision a new one.

# %%
# Retrieve all computes from workspace
cts = ws.compute_targets

# Use existing cluster if available, else create a new one
if aks_name in cts and cts[aks_name].type == "AKS":
    print("Found existing AKS cluster, will use it!")
    aks_target = cts[aks_name]
else:
    print("Creating a new AKS cluster...")
    # Use the default provisioning config (no input parameters) or provide parameters to customize
    # For example, to create a dev/test cluster, use:
    prov_config = AksCompute.provisioning_configuration(cluster_purpose = AksCompute.ClusterPurpose.DEV_TEST)
    # Example configuration to use an existing virtual network
    # prov_config.vnet_name = "mynetwork"
    # prov_config.vnet_resourcegroup_name = "myresourcegroup"
    # prov_config.subnet_name = "default"
    # prov_config.service_cidr = "10.0.0.0/16"
    # prov_config.dns_service_ip = "10.0.0.10"
    # prov_config.docker_bridge_cidr = "172.17.0.1/16"
    aks_target = ComputeTarget.create(workspace = ws,
                                      name = aks_name,
                                      provisioning_configuration = prov_config)
    
    print("Waiting for cluster creation completion...")
    aks_target.wait_for_completion(show_output=True)

print("Cluster state:", aks_target.provisioning_state)
print("Cluster is ready!", aks_target)
# Out:
# Found existing AKS cluster, will use it!
# Cluster state: Succeeded
# Cluster is ready! AksCompute(workspace=Workspace.create(name='mlopstemplatewsbfdc24', subscription_id='e58a23da-421e-4b52-99d5-e615f2f8be41', resource_group='mlopstemplaterg'), name=aks-cluster, id=/subscriptions/e58a23da-421e-4b52-99d5-e615f2f8be41/resourceGroups/mlopstemplaterg/providers/Microsoft.MachineLearningServices/workspaces/mlopstemplatewsbfdc24/computes/aks-cluster, type=AKS, provisioning_state=Succeeded, location=westeurope, tags=None)

# %% [markdown]
# Create new AKS Webservice.

# %%
aks_config = AksWebservice.deploy_configuration(collect_model_data=True,
                                                enable_app_insights=True)

aks_webservices = Webservice.list(workspace = ws, compute_type="AKS")

if any(aks_webservice.name == aks_service_name for aks_webservice in aks_webservices):
    print("Model with same name already deployed")
else:
    if aks_target.provisioning_state == "Succeeded":
        aks_service = Model.deploy(workspace=ws,
                                   name=aks_service_name,
                                   models=[model],
                                   inference_config=inference_config,
                                   deployment_config=aks_config,
                                   deployment_target=aks_target)
        
        aks_service.wait_for_deployment(show_output = True)
        print("Service state:", aks_service.state)
        print("Service details:", aks_service)
    else: 
        raise ValueError("Failed to deploy service to AKS - Error: ", aks_service.error)
# Out:
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running.............................
# Succeeded
# AKS service creation operation finished, operation "Succeeded"
# Service state: Healthy
# Service details: AksWebservice(workspace=Workspace.create(name='mlopstemplatewsbfdc24', subscription_id='e58a23da-421e-4b52-99d5-e615f2f8be41', resource_group='mlopstemplaterg'), name=dog-classification-service-aks, image_id=None, compute_type=None, state=AKS, scoring_uri=Healthy, tags=http://20.101.27.17:80/api/v1/service/dog-classification-service-aks/score, properties={}, created_by={'azureml.git.repository_uri': 'https://github.com/sebastianbirk/pytorch-mlops-template-azure-ml.git', 'mlflow.source.git.repoURL': 'https://github.com/sebastianbirk/pytorch-mlops-template-azure-ml.git', 'azureml.git.branch': 'develop', 'mlflow.source.git.branch': 'develop', 'azureml.git.commit': '075cce4e199150fd848c6330bb0ff13afe3be3a1', 'mlflow.source.git.commit': '075cce4e199150fd848c6330bb0ff13afe3be3a1', 'azureml.git.dirty': 'True', 'hasInferenceSchema': 'False', 'hasHttps': 'False'})

# %% [markdown]
# Retrieve existing AKS webservice.

# %%
aks_service = Webservice(ws, aks_service_name)

# %% [markdown]
# ### AKS Webservice Testing

# %% [markdown]
# Test the AKS webservice using an HTTP request with the requests library.

# %%
# Display the test image
# %matplotlib inline
plt.imshow(Image.open(data_example_path))

# Preprocess the image
input_data = preprocess_image(data_example_path)

# Get body and header for POST request
# For AKS deployment the service key needs to be in the header as well
# AML generate two keys if key auth is enabled
input_data = "{\"data\": " + str(input_data.tolist()) + "}"
api_key1, api_key2 = aks_service.get_keys()
headers = {"Content-Type": "application/json", "Authorization":("Bearer "+ api_key1)} 

# Get scoring URI
aks_scoring_uri = aks_service.scoring_uri

# Make POST request
resp = requests.post(aks_scoring_uri, input_data, headers=headers)

print("POST to url", aks_scoring_uri)
print("Result:", resp.text)
# Out:
# POST to url http://20.101.27.17:80/api/v1/service/dog-classification-service-aks/score
# Result: {"label": "n02085620-Chihuahua", "probability": "0.9995623"}

# %% [markdown]
# If something goes wrong with the deployment, the first thing to look at is the logs from the service by running the following command:

# %%
aks_service.get_logs()
# Out:
# '2021-06-28T20:02:49,396743047+00:00 - gunicorn/run \n2021-06-28T20:02:49,396741847+00:00 - rsyslog/run \nDynamic Python package installation is disabled.\nStarting HTTP server\n2021-06-28T20:02:49,401748619+00:00 - iot-server/run \n2021-06-28T20:02:49,404764963+00:00 - nginx/run \nEdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...\n2021-06-28T20:02:49,512320021+00:00 - iot-server/finish 1 0\n2021-06-28T20:02:49,513628540+00:00 - Exit code 1 is normal. Not restarting iot-server.\nStarting gunicorn 19.9.0\nListening at: http://127.0.0.1:31311 (12)\nUsing worker: sync\nworker timeout is set to 300\nBooting worker with pid: 38\nSPARK_HOME not set. Skipping PySpark Initialization.\nInitializing logger\n2021-06-28 20:02:51,191 | root | INFO | Starting up app insights client\nlogging socket was found. logging is available.\nlogging socket was found. logging is available.\n2021-06-28 20:02:51,265 | root | INFO | Starting up request id generator\n2021-06-28 20:02:51,265 | root | INFO | Starting up app insight hooks\n2021-06-28 20:02:51,265 | root | INFO | Invoking user\'s init function\n2021-06-28 20:02:51,575 | root | INFO | Users\'s init has completed successfully\n2021-06-28 20:02:51,577 | root | INFO | Skipping middleware: dbg_model_info as it\'s not enabled.\n2021-06-28 20:02:51,577 | root | INFO | Skipping middleware: dbg_resource_usage as it\'s not enabled.\n2021-06-28 20:02:51,578 | root | INFO | Scoring timeout setting is not found. Use default timeout: 3600000 ms\n2021-06-28 20:02:56,739 | root | INFO | Swagger file not present\n2021-06-28 20:02:56,740 | root | INFO | 404\n127.0.0.1 - - [28/Jun/2021:20:02:56 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "hackney/1.17.4"\n2021-06-28 20:02:56,930 | root | INFO | Swagger file not present\n2021-06-28 20:02:56,930 | root | INFO | 404\n127.0.0.1 - - [28/Jun/2021:20:02:56 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "curl/7.67.0"\n2021-06-28 20:03:04,995 | root | INFO | Swagger file not present\n2021-06-28 20:03:04,995 | root | INFO | 404\n127.0.0.1 - - [28/Jun/2021:20:03:04 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "hackney/1.17.4"\n2021-06-28 20:03:05,200 | root | INFO | Swagger file not present\n2021-06-28 20:03:05,200 | root | INFO | 404\n127.0.0.1 - - [28/Jun/2021:20:03:05 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "curl/7.67.0"\n2021-06-28 20:03:07,504 | root | INFO | Swagger file not present\n2021-06-28 20:03:07,505 | root | INFO | 404\n127.0.0.1 - - [28/Jun/2021:20:03:07 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "hackney/1.17.4"\n2021-06-28 20:03:07,699 | root | INFO | Swagger file not present\n2021-06-28 20:03:07,699 | root | INFO | 404\n127.0.0.1 - - [28/Jun/2021:20:03:07 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "curl/7.67.0"\n2021-06-28 20:03:08,964 | root | INFO | Scoring Timer is set to 3600.0 seconds\n2021-06-28 20:03:09,233 | root | INFO | 200\n127.0.0.1 - - [28/Jun/2021:20:03:09 +0000] "POST /score HTTP/1.0" 200 60 "-" "python-requests/2.25.1"\n'

# %% [markdown]
# ### AKS Webservice Clean Up

# %%
# Delete the AKS Webservice
try:    
    aks_service.delete()
    print("AKS service deleted.")
except:
    print("No AKS service.")
# Out:
# AKS service deleted.

# %% [markdown]
# # Model Deployment (Docker Image)

# %% [markdown]
# ### Model Packaging

# %% [markdown]
# In some cases, you might want to create a Docker image without deploying the model directly to a compute target such as ACI or AKS (if, for example, you plan to deploy to Azure App Service). Or you might want to download the image and run it on a local Docker installation. You might even want to download the files used to build the image, inspect them, modify them, and build the image manually.
#
# Model packaging enables you to do these things. It packages all the assets needed to host a model as a web service and allows you to download either a fully built Docker image or the files needed to build one. There are two ways to use model packaging:
#
# **Option 1: Download a Packaged Model:** Download a Docker image that contains the model and other files needed to host it as a web service.
#
# **Option 2: Generate a Dockerfile:** Download the Dockerfile, model, entry script, and other assets needed to build a Docker image. You can then inspect the files or make changes before you build the image locally.
#
# Creating a package is similar to deploying a model. You use a registered model and an inference configuration.
#
# For more information on model packaging, check the [Microsoft documentation](https://docs.microsoft.com/en-us/azure/machine-learning/how-to-deploy-package-models).

# %% [markdown]
# ### Option 1: Download a Packaged Model

# %% [markdown]
# The following code builds an image, which is registered in the Azure Container Registry of your AML workspace.
#
# If the generate_dockerfile flag is set to False, then an Azure Container Registry (ACR) build task will be triggered and the image will be built on the workspace-native ACR.

# %%
# Creating package
package = Model.package(ws, 
                        [model], 
                        inference_config=inference_config, 
                        generate_dockerfile=False, # Build image on ACR
                        image_name=image_name,
                        image_label=image_label)

package.wait_for_creation(show_output=True)
# Out:
# 2021/06/28 20:04:15 Downloading source code...
# 2021/06/28 20:04:18 Finished downloading source code
# 2021/06/28 20:04:18 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/06/28 20:04:19 Successfully set up Docker network: acb_default_network
# 2021/06/28 20:04:19 Setting up Docker configuration...
# 2021/06/28 20:04:19 Successfully set up Docker configuration
# 2021/06/28 20:04:19 Logging in to registry: 4d3602983f8547aa8deaeb9718806017.azurecr.io
# 2021/06/28 20:04:20 Successfully logged into 4d3602983f8547aa8deaeb9718806017.azurecr.io
# 2021/06/28 20:04:20 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/06/28 20:04:20 Launching container with name: acb_step_0
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# Login Succeeded
# WARNING! Your password will be stored unencrypted in /acb/home/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# 2021/06/28 20:04:21 Successfully executed container: acb_step_0
# 2021/06/28 20:04:21 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/06/28 20:04:21 Scanning for dependencies...
# 2021/06/28 20:04:22 Successfully scanned dependencies
# 2021/06/28 20:04:22 Launching container with name: acb_step_1
# Sending build context to Docker daemon  66.05kB
# Step 1/7 : FROM 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# latest: Pulling from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 2c11b7cecaa5: Already exists
# 04637fa56252: Already exists
# d6e6af23a0f3: Already exists
# b4a424de92ad: Already exists
# 3e5d9ee64909: Pulling fs layer
# 3a846111ff22: Pulling fs layer
# 93a5020c6e19: Pulling fs layer
# 360b353e68fd: Pulling fs layer
# ea4e2e1810f8: Pulling fs layer
# def12cf7de15: Pulling fs layer
# 3ae6adfbdb11: Pulling fs layer
# 2a21fbf2232e: Pulling fs layer
# 1ef948e4af08: Pulling fs layer
# 2884e50fecf0: Pulling fs layer
# ef1126a3f0ef: Pulling fs layer
# 71b767dbb69c: Pulling fs layer
# 9ceb021587db: Pulling fs layer
# bf4f7cfc5a76: Pulling fs layer
# 6f7cc2038c49: Pulling fs layer
# 4ef44254dd51: Pulling fs layer
# 1d40236ff4d0: Pulling fs layer
# 529650b82c29: Pulling fs layer
# 4825efdc50fc: Pulling fs layer
# 18dc5c333c4d: Pulling fs layer
# ea4e2e1810f8: Waiting
# def12cf7de15: Waiting
# 3ae6adfbdb11: Waiting
# 2a21fbf2232e: Waiting
# 1ef948e4af08: Waiting
# 2884e50fecf0: Waiting
# ef1126a3f0ef: Waiting
# 71b767dbb69c: Waiting
# 9ceb021587db: Waiting
# bf4f7cfc5a76: Waiting
# 6f7cc2038c49: Waiting
# 1d40236ff4d0: Waiting
# 529650b82c29: Waiting
# 4825efdc50fc: Waiting
# 18dc5c333c4d: Waiting
# 4ef44254dd51: Waiting
# 360b353e68fd: Waiting
# 3a846111ff22: Verifying Checksum
# 3a846111ff22: Download complete
# 93a5020c6e19: Verifying Checksum
# 93a5020c6e19: Download complete
# 3e5d9ee64909: Verifying Checksum
# 3e5d9ee64909: Download complete
# 360b353e68fd: Verifying Checksum
# 360b353e68fd: Download complete
# def12cf7de15: Verifying Checksum
# def12cf7de15: Download complete
# 3ae6adfbdb11: Verifying Checksum
# 3ae6adfbdb11: Download complete
# 2a21fbf2232e: Verifying Checksum
# 2a21fbf2232e: Download complete
# 1ef948e4af08: Verifying Checksum
# 1ef948e4af08: Download complete
# 2884e50fecf0: Verifying Checksum
# 2884e50fecf0: Download complete
# 71b767dbb69c: Verifying Checksum
# 71b767dbb69c: Download complete
# 9ceb021587db: Verifying Checksum
# 9ceb021587db: Download complete
# ea4e2e1810f8: Verifying Checksum
# ea4e2e1810f8: Download complete
# bf4f7cfc5a76: Verifying Checksum
# bf4f7cfc5a76: Download complete
# ef1126a3f0ef: Verifying Checksum
# ef1126a3f0ef: Download complete
# 6f7cc2038c49: Verifying Checksum
# 6f7cc2038c49: Download complete
# 1d40236ff4d0: Verifying Checksum
# 1d40236ff4d0: Download complete
# 529650b82c29: Verifying Checksum
# 529650b82c29: Download complete
# 18dc5c333c4d: Verifying Checksum
# 18dc5c333c4d: Download complete
# 4825efdc50fc: Verifying Checksum
# 4825efdc50fc: Download complete
# 3e5d9ee64909: Pull complete
# 3a846111ff22: Pull complete
# 93a5020c6e19: Pull complete
# 360b353e68fd: Pull complete
# 4ef44254dd51: Verifying Checksum
# 4ef44254dd51: Download complete
# ea4e2e1810f8: Pull complete
# def12cf7de15: Pull complete
# 3ae6adfbdb11: Pull complete
# 2a21fbf2232e: Pull complete
# 1ef948e4af08: Pull complete
# 2884e50fecf0: Pull complete
# ef1126a3f0ef: Pull complete
# 71b767dbb69c: Pull complete
# 9ceb021587db: Pull complete
# bf4f7cfc5a76: Pull complete
# 6f7cc2038c49: Pull complete
#
# 4ef44254dd51: Pull complete
# 1d40236ff4d0: Pull complete
# 529650b82c29: Pull complete
# 4825efdc50fc: Pull complete
# 18dc5c333c4d: Pull complete
# Digest: sha256:4c820153dc704f8203742de7514a5208a7f181e24892735cb87b54e8e51eceb2
# Status: Downloaded newer image for 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b:latest
#  ---> a6d60cf57bfc
# Step 2/7 : ENV AZUREML_MODEL_DIR=/var/azureml-app/azureml-models/dog_clf_model/1
#  ---> Running in 0594b7b96679
# Removing intermediate container 0594b7b96679
#  ---> 246c067c3865
# Step 3/7 : RUN mkdir -p '/var/azureml-app' && /var/azureml-util/download_asset.sh 'https://mlopstemplatesabfdc24.blob.core.windows.net/azureml/LocalUpload/b911487d/tmpc9se92ts.py?sv=2019-02-02&sr=b&sig=UmIV3fYCoqe9qEpknF%2BSaHoLsFmSnH%2B6q8azThwrWKA%3D&st=2021-06-28T19%3A54%3A12Z&se=2021-06-29T04%3A04%3A12Z&sp=r' '/var/azureml-app/tmpc9se92ts.py' && /var/azureml-util/download_asset.sh 'https://mlopstemplatesabfdc24.blob.core.windows.net/azureml/LocalUpload/5e9c019b/score.py?sv=2019-02-02&sr=b&sig=BJ3SJOIpzGALo2SgqpWPcJbQuithYMYvIdIkBDMWb6w%3D&st=2021-06-28T19%3A54%3A12Z&se=2021-06-29T04%3A04%3A12Z&sp=r' '/var/azureml-app/score.py'
#  ---> Running in 514f15b1d4a2
# Downloading https://mlopstemplatesabfdc24.blob.core.windows.net/azureml/LocalUpload/b911487d/tmpc9se92ts.py?sv=2019-02-02&sr=b&sig=UmIV3fYCoqe9qEpknF%2BSaHoLsFmSnH%2B6q8azThwrWKA%3D&st=2021-06-28T19%3A54%3A12Z&se=2021-06-29T04%3A04%3A12Z&sp=r as /var/azureml-app/tmpc9se92ts.py
# --2021-06-28 20:06:25--  https://mlopstemplatesabfdc24.blob.core.windows.net/azureml/LocalUpload/b911487d/tmpc9se92ts.py?sv=2019-02-02&sr=b&sig=UmIV3fYCoqe9qEpknF%2BSaHoLsFmSnH%2B6q8azThwrWKA%3D&st=2021-06-28T19%3A54%3A12Z&se=2021-06-29T04%3A04%3A12Z&sp=r
# Resolving mlopstemplatesabfdc24.blob.core.windows.net (mlopstemplatesabfdc24.blob.core.windows.net)... 52.239.143.164
# Connecting to mlopstemplatesabfdc24.blob.core.windows.net (mlopstemplatesabfdc24.blob.core.windows.net)|52.239.143.164|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1064 (1.0K) [application/octet-stream]
# Saving to: ‘/var/azureml-app/tmpc9se92ts.py’
#
#      0K                                    100% 83.2M=0s
#
# 2021-06-28 20:06:25 (83.2 MB/s) - ‘/var/azureml-app/tmpc9se92ts.py’ saved [1064/1064]
#
# Downloading https://mlopstemplatesabfdc24.blob.core.windows.net/azureml/LocalUpload/5e9c019b/score.py?sv=2019-02-02&sr=b&sig=BJ3SJOIpzGALo2SgqpWPcJbQuithYMYvIdIkBDMWb6w%3D&st=2021-06-28T19%3A54%3A12Z&se=2021-06-29T04%3A04%3A12Z&sp=r as /var/azureml-app/score.py
# --2021-06-28 20:06:25--  https://mlopstemplatesabfdc24.blob.core.windows.net/azureml/LocalUpload/5e9c019b/score.py?sv=2019-02-02&sr=b&sig=BJ3SJOIpzGALo2SgqpWPcJbQuithYMYvIdIkBDMWb6w%3D&st=2021-06-28T19%3A54%3A12Z&se=2021-06-29T04%3A04%3A12Z&sp=r
# Resolving mlopstemplatesabfdc24.blob.core.windows.net (mlopstemplatesabfdc24.blob.core.windows.net)... 52.239.143.164
# Connecting to mlopstemplatesabfdc24.blob.core.windows.net (mlopstemplatesabfdc24.blob.core.windows.net)|52.239.143.164|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6556 (6.4K) [application/octet-stream]
# Saving to: ‘/var/azureml-app/score.py’
#
#      0K                                    100%  595M=0s
#
# 2021-06-28 20:06:25 (595 MB/s) - ‘/var/azureml-app/score.py’ saved [6556/6556]
#
# Removing intermediate container 514f15b1d4a2
#  ---> 5101ee148e99
# Step 4/7 : RUN mkdir -p '/var/azureml-app/azureml-models/dog_clf_model/1' && /var/azureml-util/download_asset.sh 'https://mlopstemplatesabfdc24.blob.core.windows.net/azureml/ExperimentRun/dcid.stanford_dogs_classifier_train_1624881248_acfcc866/outputs/dog_clf_model.pt?sv=2019-02-02&sr=b&sig=k9EmFs0DsJz5R8yHqoKct0aPkGgsDdkk5XS84bdulPo%3D&st=2021-06-28T19%3A54%3A12Z&se=2021-06-29T04%3A04%3A12Z&sp=r' '/var/azureml-app/azureml-models/dog_clf_model/1/dog_clf_model.pt'
#  ---> Running in eb4078e53946
# Downloading https://mlopstemplatesabfdc24.blob.core.windows.net/azureml/ExperimentRun/dcid.stanford_dogs_classifier_train_1624881248_acfcc866/outputs/dog_clf_model.pt?sv=2019-02-02&sr=b&sig=k9EmFs0DsJz5R8yHqoKct0aPkGgsDdkk5XS84bdulPo%3D&st=2021-06-28T19%3A54%3A12Z&se=2021-06-29T04%3A04%3A12Z&sp=r as /var/azureml-app/azureml-models/dog_clf_model/1/dog_clf_model.pt
# --2021-06-28 20:06:29--  https://mlopstemplatesabfdc24.blob.core.windows.net/azureml/ExperimentRun/dcid.stanford_dogs_classifier_train_1624881248_acfcc866/outputs/dog_clf_model.pt?sv=2019-02-02&sr=b&sig=k9EmFs0DsJz5R8yHqoKct0aPkGgsDdkk5XS84bdulPo%3D&st=2021-06-28T19%3A54%3A12Z&se=2021-06-29T04%3A04%3A12Z&sp=r
# Resolving mlopstemplatesabfdc24.blob.core.windows.net (mlopstemplatesabfdc24.blob.core.windows.net)... 52.239.143.164
# Connecting to mlopstemplatesabfdc24.blob.core.windows.net (mlopstemplatesabfdc24.blob.core.windows.net)|52.239.143.164|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101226350 (97M) [application/octet-stream]
# Saving to: ‘/var/azureml-app/azureml-models/dog_clf_model/1/dog_clf_model.pt’
#
#      0K ........ ........ ........ ........ 33% 67.8M 1s
#  32768K ........ ........ ........ ........ 66% 72.6M 0s
#  65536K ........ ........ ........ ........ 99% 69.8M 0s
#  98304K                                    100% 58.6M=1.4s
#
# 2021-06-28 20:06:31 (69.9 MB/s) - ‘/var/azureml-app/azureml-models/dog_clf_model/1/dog_clf_model.pt’ saved [101226350/101226350]
#
# Removing intermediate container eb4078e53946
#  ---> a9708b789ed3
# Step 5/7 : RUN mkdir -p '/var/azureml-app' && echo ... | base64 --decode > /var/azureml-app/model_config_map.json
#  ---> Running in d5f4420fb041
# Removing intermediate container d5f4420fb041
#  ---> 7b027fec58b0
# Step 6/7 : RUN mv '/var/azureml-app/tmpc9se92ts.py' /var/azureml-app/main.py
#  ---> Running in ed3964ec23cd
# Removing intermediate container ed3964ec23cd
#  ---> ca35f6d95261
# Step 7/7 : CMD ["runsvdir","/var/runit"]
#  ---> Running in 468193fa66c1
# Removing intermediate container 468193fa66c1
#  ---> 956cd943bf15
# Successfully built 956cd943bf15
# Successfully tagged 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25:latest
# Successfully tagged 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25:1
# Successfully tagged 4d3602983f8547aa8deaeb9718806017.azurecr.io/inference/dog_clf_model:1.0.0
# 2021/06/28 20:06:49 Successfully executed container: acb_step_1
# 2021/06/28 20:06:49 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/06/28 20:06:49 Pushing image: 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25:1, attempt 1
# The push refers to repository [4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25]
# 83c3a51a13c1: Preparing
# 87e96f9d8f87: Preparing
# d8dfabdb120e: Preparing
# f2d92d9768f0: Preparing
# 44cd31926492: Preparing
# bc5ec647cc4e: Preparing
# 3003bab43957: Preparing
# d5be40cb7a91: Preparing
# ecba82263a10: Preparing
# 900803f163dc: Preparing
# 849000fcceba: Preparing
# 6cc44774fa32: Preparing
# 15d3efb76e30: Preparing
# 8aa0cefff129: Preparing
# c0bf52624a8b: Preparing
# fa5f62c9cc40: Preparing
# 630330099f1e: Preparing
# 26346e33e93c: Preparing
# 65fd26c61dec: Preparing
# 8b72eff884fd: Preparing
# f06675a4a69e: Preparing
# 7117e7689e0f: Preparing
# d56ca49dab62: Preparing
# 09304b9c7c13: Preparing
# 9edaa71ce233: Preparing
# 62fdddf6a67c: Preparing
# eff16de3ff64: Preparing
# 61727f5e6796: Preparing
# bc5ec647cc4e: Waiting
# 3003bab43957: Waiting
# d5be40cb7a91: Waiting
# ecba82263a10: Waiting
# 900803f163dc: Waiting
# 849000fcceba: Waiting
# 6cc44774fa32: Waiting
# 15d3efb76e30: Waiting
# 8aa0cefff129: Waiting
# c0bf52624a8b: Waiting
# fa5f62c9cc40: Waiting
# 630330099f1e: Waiting
# 26346e33e93c: Waiting
# 65fd26c61dec: Waiting
# 8b72eff884fd: Waiting
# f06675a4a69e: Waiting
# 7117e7689e0f: Waiting
# d56ca49dab62: Waiting
# 09304b9c7c13: Waiting
# 9edaa71ce233: Waiting
# 62fdddf6a67c: Waiting
# eff16de3ff64: Waiting
# 61727f5e6796: Waiting
# 44cd31926492: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# f2d92d9768f0: Pushed
# 83c3a51a13c1: Pushed
# 87e96f9d8f87: Pushed
# bc5ec647cc4e: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 3003bab43957: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# d5be40cb7a91: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# ecba82263a10: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 849000fcceba: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 900803f163dc: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 6cc44774fa32: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 15d3efb76e30: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# c0bf52624a8b: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# fa5f62c9cc40: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 8aa0cefff129: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 630330099f1e: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 26346e33e93c: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 8b72eff884fd: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# f06675a4a69e: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 65fd26c61dec: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 7117e7689e0f: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 09304b9c7c13: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 9edaa71ce233: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 62fdddf6a67c: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# eff16de3ff64: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# 61727f5e6796: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# d56ca49dab62: Mounted from azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
# d8dfabdb120e: Pushed
# 1: digest: sha256:2e87c809583e724cea35b05d47f8bea8c7852293abdc17359dcd740ef59017f7 size: 6187
# 2021/06/28 20:06:57 Successfully pushed image: 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25:1
# 2021/06/28 20:06:57 Executing step ID: acb_step_3. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/06/28 20:06:57 Pushing image: 4d3602983f8547aa8deaeb9718806017.azurecr.io/inference/dog_clf_model:1.0.0, attempt 1
# The push refers to repository [4d3602983f8547aa8deaeb9718806017.azurecr.io/inference/dog_clf_model]
# 83c3a51a13c1: Preparing
# 87e96f9d8f87: Preparing
# d8dfabdb120e: Preparing
# f2d92d9768f0: Preparing
# 44cd31926492: Preparing
# bc5ec647cc4e: Preparing
# 3003bab43957: Preparing
# d5be40cb7a91: Preparing
# ecba82263a10: Preparing
# 900803f163dc: Preparing
# 849000fcceba: Preparing
# 6cc44774fa32: Preparing
# 15d3efb76e30: Preparing
# 8aa0cefff129: Preparing
# c0bf52624a8b: Preparing
# fa5f62c9cc40: Preparing
# 630330099f1e: Preparing
# 26346e33e93c: Preparing
# 65fd26c61dec: Preparing
# 8b72eff884fd: Preparing
# f06675a4a69e: Preparing
# 7117e7689e0f: Preparing
# d56ca49dab62: Preparing
# 09304b9c7c13: Preparing
# 9edaa71ce233: Preparing
# 62fdddf6a67c: Preparing
# eff16de3ff64: Preparing
# 61727f5e6796: Preparing
# bc5ec647cc4e: Waiting
# 3003bab43957: Waiting
# d5be40cb7a91: Waiting
# ecba82263a10: Waiting
# 900803f163dc: Waiting
# 849000fcceba: Waiting
# 6cc44774fa32: Waiting
# 15d3efb76e30: Waiting
# 8aa0cefff129: Waiting
# c0bf52624a8b: Waiting
# fa5f62c9cc40: Waiting
# 630330099f1e: Waiting
# 26346e33e93c: Waiting
# 65fd26c61dec: Waiting
# 8b72eff884fd: Waiting
# f06675a4a69e: Waiting
# 7117e7689e0f: Waiting
# d56ca49dab62: Waiting
# 09304b9c7c13: Waiting
# 9edaa71ce233: Waiting
# 62fdddf6a67c: Waiting
# eff16de3ff64: Waiting
# 83c3a51a13c1: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 44cd31926492: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 87e96f9d8f87: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# d8dfabdb120e: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# f2d92d9768f0: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 3003bab43957: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# ecba82263a10: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# bc5ec647cc4e: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# d5be40cb7a91: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 900803f163dc: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 849000fcceba: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 6cc44774fa32: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 15d3efb76e30: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 8aa0cefff129: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# c0bf52624a8b: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 26346e33e93c: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 630330099f1e: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 65fd26c61dec: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 8b72eff884fd: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# f06675a4a69e: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 7117e7689e0f: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 09304b9c7c13: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# d56ca49dab62: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 9edaa71ce233: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 62fdddf6a67c: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# eff16de3ff64: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 61727f5e6796: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# fa5f62c9cc40: Mounted from azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
# 1.0.0: digest: sha256:2e87c809583e724cea35b05d47f8bea8c7852293abdc17359dcd740ef59017f7 size: 6187
# 2021/06/28 20:07:06 Successfully pushed image: 4d3602983f8547aa8deaeb9718806017.azurecr.io/inference/dog_clf_model:1.0.0
# 2021/06/28 20:07:06 Executing step ID: acb_step_4. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/06/28 20:07:06 Pushing image: 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25:latest, attempt 1
# The push refers to repository [4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25]
# 83c3a51a13c1: Preparing
# 87e96f9d8f87: Preparing
# d8dfabdb120e: Preparing
# f2d92d9768f0: Preparing
# 44cd31926492: Preparing
# bc5ec647cc4e: Preparing
# 3003bab43957: Preparing
# d5be40cb7a91: Preparing
# ecba82263a10: Preparing
# 900803f163dc: Preparing
# 849000fcceba: Preparing
# 6cc44774fa32: Preparing
# 15d3efb76e30: Preparing
# 8aa0cefff129: Preparing
# c0bf52624a8b: Preparing
# fa5f62c9cc40: Preparing
# 630330099f1e: Preparing
# 26346e33e93c: Preparing
# 65fd26c61dec: Preparing
# 8b72eff884fd: Preparing
# f06675a4a69e: Preparing
# 7117e7689e0f: Preparing
# d56ca49dab62: Preparing
# 09304b9c7c13: Preparing
# 9edaa71ce233: Preparing
# 62fdddf6a67c: Preparing
# eff16de3ff64: Preparing
# 61727f5e6796: Preparing
# c0bf52624a8b: Waiting
# fa5f62c9cc40: Waiting
# 630330099f1e: Waiting
# 26346e33e93c: Waiting
# 65fd26c61dec: Waiting
# 8b72eff884fd: Waiting
# f06675a4a69e: Waiting
# 7117e7689e0f: Waiting
# d56ca49dab62: Waiting
# 09304b9c7c13: Waiting
# 9edaa71ce233: Waiting
# 62fdddf6a67c: Waiting
# eff16de3ff64: Waiting
# 61727f5e6796: Waiting
# bc5ec647cc4e: Waiting
# 3003bab43957: Waiting
# d5be40cb7a91: Waiting
# ecba82263a10: Waiting
# 900803f163dc: Waiting
# 849000fcceba: Waiting
# 6cc44774fa32: Waiting
# 15d3efb76e30: Waiting
# 8aa0cefff129: Waiting
# f2d92d9768f0: Layer already exists
# 83c3a51a13c1: Layer already exists
# 87e96f9d8f87: Layer already exists
# 44cd31926492: Layer already exists
# d8dfabdb120e: Layer already exists
# bc5ec647cc4e: Layer already exists
# d5be40cb7a91: Layer already exists
# 3003bab43957: Layer already exists
# 900803f163dc: Layer already exists
# ecba82263a10: Layer already exists
# 849000fcceba: Layer already exists
# 6cc44774fa32: Layer already exists
# 15d3efb76e30: Layer already exists
# c0bf52624a8b: Layer already exists
# 8aa0cefff129: Layer already exists
# 65fd26c61dec: Layer already exists
# 630330099f1e: Layer already exists
# 8b72eff884fd: Layer already exists
# fa5f62c9cc40: Layer already exists
# 26346e33e93c: Layer already exists
# 7117e7689e0f: Layer already exists
# d56ca49dab62: Layer already exists
# f06675a4a69e: Layer already exists
# 09304b9c7c13: Layer already exists
# 9edaa71ce233: Layer already exists
# eff16de3ff64: Layer already exists
# 62fdddf6a67c: Layer already exists
# 61727f5e6796: Layer already exists
# latest: digest: sha256:2e87c809583e724cea35b05d47f8bea8c7852293abdc17359dcd740ef59017f7 size: 6187
# 2021/06/28 20:07:12 Successfully pushed image: 4d3602983f8547aa8deaeb9718806017.azurecr.io/azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25:latest
# 2021/06/28 20:07:12 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 1.084825)
# 2021/06/28 20:07:12 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 147.967275)
# 2021/06/28 20:07:12 Populating digests for step ID: acb_step_1...
# 2021/06/28 20:07:17 Successfully populated digests for step ID: acb_step_1
# 2021/06/28 20:07:17 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 7.891035)
# 2021/06/28 20:07:17 Step ID: acb_step_3 marked as successful (elapsed time in seconds: 8.430215)
# 2021/06/28 20:07:17 Step ID: acb_step_4 marked as successful (elapsed time in seconds: 6.410491)
# 2021/06/28 20:07:17 The following dependencies were found:
# 2021/06/28 20:07:17
# - image:
#     registry: 4d3602983f8547aa8deaeb9718806017.azurecr.io
#     repository: azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
#     tag: latest
#     digest: sha256:2e87c809583e724cea35b05d47f8bea8c7852293abdc17359dcd740ef59017f7
#   runtime-dependency:
#     registry: 4d3602983f8547aa8deaeb9718806017.azurecr.io
#     repository: azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
#     tag: latest
#     digest: sha256:4c820153dc704f8203742de7514a5208a7f181e24892735cb87b54e8e51eceb2
#   git: {}
# - image:
#     registry: 4d3602983f8547aa8deaeb9718806017.azurecr.io
#     repository: azureml/azureml_dfaf2b2857f5bcc43dfddca890accc25
#     tag: "1"
#     digest: sha256:2e87c809583e724cea35b05d47f8bea8c7852293abdc17359dcd740ef59017f7
#   runtime-dependency:
#     registry: 4d3602983f8547aa8deaeb9718806017.azurecr.io
#     repository: azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
#     tag: latest
#     digest: sha256:4c820153dc704f8203742de7514a5208a7f181e24892735cb87b54e8e51eceb2
#   git: {}
# - image:
#     registry: 4d3602983f8547aa8deaeb9718806017.azurecr.io
#     repository: inference/dog_clf_model
#     tag: 1.0.0
#     digest: sha256:2e87c809583e724cea35b05d47f8bea8c7852293abdc17359dcd740ef59017f7
#   runtime-dependency:
#     registry: 4d3602983f8547aa8deaeb9718806017.azurecr.io
#     repository: azureml/azureml_6a37a53f7e2a047b2229daa462a37c7b
#     tag: latest
#     digest: sha256:4c820153dc704f8203742de7514a5208a7f181e24892735cb87b54e8e51eceb2
#   git: {}
#
#
# Run ID: cb3 was successful after 3m3s
# Package creation Succeeded

# %%
# Retrieve ACR details
acr = package.get_container_registry()
print("Address:", acr.address)
print("Username:", acr.username)
print("Password:", acr.password)
# Out:
# Address: 4d3602983f8547aa8deaeb9718806017.azurecr.io
# Username: 4d3602983f8547aa8deaeb9718806017
# Password: /dG0bng3nYJiPHQnZrzCYjFi=XQ9CkWd

# %% [markdown]
# After a package is created, you can use package.pull() to pull the image to your local Docker environment. This can only be used if `generate_dockerfile` is set to `False`. When the package is pulled, use the `docker images` command to list the local images.

# %%
package.pull()
# Out:
# Pulling image from ACR (this may take a few minutes depending on image size)...
#
# 4d3602983f8547aa8deaeb9718806017.azurecr.io/inference/dog_clf_model@sha256:2e87c809583e724cea35b05d47f8bea8c7852293abdc17359dcd740ef59017f7: Pulling from inference/dog_clf_model
# 2c11b7cecaa5: Already exists
# 04637fa56252: Already exists
# d6e6af23a0f3: Already exists
# b4a424de92ad: Already exists
# 3e5d9ee64909: Already exists
# 3a846111ff22: Already exists
# 93a5020c6e19: Already exists
# 360b353e68fd: Already exists
# ea4e2e1810f8: Already exists
# def12cf7de15: Already exists
# 3ae6adfbdb11: Already exists
# 2a21fbf2232e: Already exists
# 1ef948e4af08: Already exists
# 2884e50fecf0: Already exists
# ef1126a3f0ef: Already exists
# 71b767dbb69c: Already exists
# 9ceb021587db: Already exists
# bf4f7cfc5a76: Already exists
# 6f7cc2038c49: Already exists
# 4ef44254dd51: Already exists
# 1d40236ff4d0: Already exists
# 529650b82c29: Already exists
# 4825efdc50fc: Already exists
# 18dc5c333c4d: Already exists
# 8041096ebae1: Pulling fs layer
# b01d9c5b6634: Pulling fs layer
# d5d329e37b0d: Pulling fs layer
# a558c6ca2ece: Pulling fs layer
# a558c6ca2ece: Waiting
# 8041096ebae1: Download complete
# 8041096ebae1: Extracting
# 8041096ebae1: Extracting
# d5d329e37b0d: Downloading
# d5d329e37b0d: Verifying Checksum
# d5d329e37b0d: Download complete
# a558c6ca2ece: Downloading
# a558c6ca2ece: Verifying Checksum
# a558c6ca2ece: Download complete
# b01d9c5b6634: Downloading
# 8041096ebae1: Pull complete
# b01d9c5b6634: Downloading
# b01d9c5b6634: Downloading
# b01d9c5b6634: Downloading
# b01d9c5b6634: Downloading
# b01d9c5b6634: Downloading
# b01d9c5b6634: Downloading
# b01d9c5b6634: Downloading
# b01d9c5b6634: Verifying Checksum
# b01d9c5b6634: Download complete
# b01d9c5b6634: Extracting
# b01d9c5b6634: Extracting
# b01d9c5b6634: Extracting
# b01d9c5b6634: Extracting
# b01d9c5b6634: Extracting
# b01d9c5b6634: Extracting
# b01d9c5b6634: Extracting
# b01d9c5b6634: Extracting
# b01d9c5b6634: Pull complete
# d5d329e37b0d: Extracting
# d5d329e37b0d: Extracting
# d5d329e37b0d: Pull complete
# a558c6ca2ece: Extracting
# a558c6ca2ece: Extracting
# a558c6ca2ece: Pull complete
# Digest: sha256:2e87c809583e724cea35b05d47f8bea8c7852293abdc17359dcd740ef59017f7
# Status: Downloaded newer image for 4d3602983f8547aa8deaeb9718806017.azurecr.io/inference/dog_clf_model@sha256:2e87c809583e724cea35b05d47f8bea8c7852293abdc17359dcd740ef59017f7

# %% [markdown]
# ### Option 2: Generate a Dockerfile

# %%
# Creating package
package = Model.package(ws, 
                        [model], 
                        inference_config=inference_config, 
                        generate_dockerfile=True, # Do not build image but create a Dockerfile and deployment assets instead
                        image_name=image_name,
                        image_label=image_label)

package.wait_for_creation(show_output=True)
# Out:
# Package creation Succeeded

# %% [markdown]
# After you create a Dockerfile, you can use package.save() to download the Dockerfile and corresponding artifacts to your local machine. This can only be used if `generate_dockerfile` is set to `True`.

# %%
package.save("../environments/docker/inferencing_image")
# Out:
# Logging into Docker registry 4d3602983f8547aa8deaeb9718806017.azurecr.io

# %% [markdown]
# In order to build the image, to push it to the ACR of the AML workspace and to run it inside a container, run the following commands from the project root directory:
#
# Login to the Azure CLI using your device code:
#
# `az login`
#
# Login to the ACR:
#
# `az acr login -n <ACR_NAME>`
#
# Build the image:
#
# `cd environments/docker/inferencing_image`
#
# `docker build -t inference/dog_clf_model:1.0.0 .`
#
# Tag the image:
#
# `docker tag inference/dog_clf_model:1.0.0 <ACR_NAME>.azurecr.io/inference/dog_clf_model:1.0.0`
#
# Push the image:
#
# `docker push <ACR_NAME>.azurecr.io/inference/dog_clf_model:1.0.0`
#
# Alternatively to the previous three steps, build the image on the ACR:
#
# `az acr build --image inference/dog_clf_model:1.0.0 --registry <ACR_NAME> .`

# %% [markdown]
# ### Model Packaging Local Deployment

# %% [markdown]
# To run the image on your local compute target (e.g. AML CI), run the following:
#
# `docker run -p 6789:5001 --name dog-clf-container -it inference/dog_clf_model:1.0.0`
#
# This command starts a container with the 1.0.0 version of the image named `inference/dog_clf_model` (in interactive mode). It maps local port 6789 to the port in the container on which the web service is listening (5001). It also assigns the name dog-clf-container to the container, which makes the container easier to stop. After the container is started, you can submit requests to http://localhost:6789/score.
#
# To see the running container run:
#
# `docker ps`

# %% [markdown]
# ### Model Packaging Local Webservice Testing

# %%
# Display the test image
# %matplotlib inline
plt.imshow(Image.open(data_example_path))

# Preprocess the image
input_data = preprocess_image(data_example_path)

# Get header and body for POST request
input_data = "{\"data\": " + str(input_data.tolist()) + "}"
headers = {"Content-Type": "application/json"}

# Make POST request
resp = requests.post("http://localhost:6789/score", input_data, headers=headers)

print("POST to url", local_scoring_uri)
print("Result:", resp.text)
# Out:
# POST to url http://localhost:6789/score
# Result: {"label": "n02085620-Chihuahua", "probability": "0.9995623"}

# %% [markdown]
# ### Model Packaging Clean Up

# %% [markdown]
# To stop the running container run:
#
# `docker stop dog-clf-container`
#
# Do not forget to clean up the image:
#
# `docker images`
#
# `docker image rmi <IMAGE_ID> --force`

# %% [markdown]
# Test the local webservice using an HTTP request with the requests library.

# %% [markdown]
# ### Deploy Docker Image to AKS

# %% [markdown]
# We will use kubectl (the Kubernetes CLI) to deploy the image to AKS.

# %% [markdown]
# First, create a Kubernetes manifest to deploy the stanford dogs inferencing image to AKS. Replace `<ACR_NAME>` with the name of your ACR.

# %%
# %%writefile ../infrastructure/aks_deployment/aks_deployment_manifest.yml
# apiVersion: apps/v1
# kind: Deployment
# metadata:
#   name: dog-clf-deployment
# spec:
#   replicas: 1
#   selector:
#     matchLabels:
#       app: dog-clf-app
#   template:
#     metadata:
#       labels:
#         app: dog-clf-app
#     spec:
#       containers:
#       - image: <ACR_NAME>.azurecr.io/inference/dog_clf_model:1.0.0
#         name: dog-clf-container
# ---
# apiVersion: v1
# kind: Service
# metadata:
#   labels:
#     app: dog-clf-service
#   name: dog-clf-service
# spec:
#   ports:
#   - targetPort: 5001
#     port: 80
#     protocol: TCP
#   selector:
#     app: dog-clf-app
#   type: LoadBalancer
# Out:
# Overwriting ../infrastructure/aks_deployment/aks_deployment_manifest.yml

# %% [markdown]
# Create a shell script to attach the ACR to AKS, configure kubectl to connect to AKS and run the deployment manifest:

# %%
# %%writefile ../infrastructure/aks_deployment/execute_aks_deployment.sh
# # Define parameters
# resourceGroupName=mlopstemplaterg
# region=westeurope
#
# # Install kubectl
# sudo az aks install-cli
#
# # Attach ACR to AKS cluster
# az aks update \
#     --resource-group $resourceGroupName \
#     --name $aksClusterName \
#     --attach-acr $acrName
#
# # Configure kubectl to connect to the AKS cluster
# az aks get-credentials \
#     --resource-group $resourceGroupName \
#     --name $aksClusterName
#
# # Apply kubernetes manifest
# kubectl apply -f aks_deployment_manifest.yml
# Out:
# Overwriting ../infrastructure/aks_deployment/execute_aks_deployment.sh

# %% [markdown]
# Define two environment variables:
#
# `export aksClusterName=<AKS_CLUSTER_NAME>` and `export acrName=<ACR_NAME>`
#
# where `<AKS_CLUSTER_NAME>` and `<ACR_NAME>` are replaced by your template-specific values.

# %% [markdown]
# Then run the following from the project root directory to deploy the image to AKS:
#
# `cd infrastructure/aks_deployment`
#
# `bash execute_aks_deployment.sh`

# %% [markdown]
# Check whether the container was successfully deployed:
#
# `kubectl get pods`
#
# Check webservice status and retrieve external IP:
#
# `kubectl get service dog-clf-service --watch`

# %% [markdown]
# ### Test the Deployed Webservice

# %% [markdown]
# Insert the external IP from above command into the POST request below.

# %%
# Display the test image
# %matplotlib inline
plt.imshow(Image.open(data_example_path))

# Preprocess the image
input_data = preprocess_image(data_example_path)

# Get header and body for POST request
input_data = "{\"data\": " + str(input_data.tolist()) + "}"
headers = {"Content-Type": "application/json"}

# Make the request and display the response.
# Add the external IP from above watch command in below web request
resp = requests.post("http://<EXTERNAL_IP>/score", input_data, headers=headers)
print(resp.text)
# Out:
# {"label": "n02085620-Chihuahua", "probability": "0.9995623"}

# %% [markdown]
# ### Model Packaging Webservice Clean Up

# %% [markdown]
# To remove the AKS deployment and service, you can run:
#
# `kubectl delete deployment dog-clf-deployment`
#
# `kubectl delete service dog-clf-service`

# %% [markdown]
# # Resource Clean Up

# %% [markdown]
# Delete the AKS cluster.

# %%
# aks_target.delete()
